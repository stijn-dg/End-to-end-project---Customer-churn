# %%
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from sklearn.metrics import roc_curve
import collections
from scipy.spatial import ConvexHull
from scipy.special import betainc
import scipy.special as ss
import sys

sys.path.append("../")

from src.common_functions import *

# %%
# sample data
# RAW_DATA_PATH1 = "../datasets/fraud/fraudTrain.csv"
# RAW_DATA_PATH2 = "../datasets/fraud/fraudTest.csv"
SAMPLED_DATA_PATH = "../datasets/fraud/cc_fraud_2.csv"
DATASET_NAME = Path(SAMPLED_DATA_PATH).stem
# raw_data1 = pd.read_csv("../datasets/fraud/fraudTrain.csv", index_col='Unnamed: 0')
# raw_data2 = pd.read_csv("../datasets/fraud/fraudTest.csv", index_col='Unnamed: 0')
# raw_data = pd.concat([raw_data1, raw_data2])
# raw_data = raw_data.rename(columns=dict(zip(raw_data.columns, list(map(to_snake_case, raw_data.columns)))))
# raw_data.head()
# _to_drop, df = train_test_split(raw_data, test_size=0.055, random_state=42, stratify=raw_data["is_fraud"])
# df.to_csv(SAMPLED_DATA_PATH, header=True, sep=",")
# del _to_drop
df = pd.read_csv(SAMPLED_DATA_PATH, index_col='Unnamed: 0')
print(df.shape[0])
df["is_fraud"].value_counts()/df.shape[0]*100
# Out:
# 101882
# is_fraud
# 0    99.478809
# 1     0.521191
# Name: count, dtype: float64

# %%
ratio = df["is_fraud"].value_counts()[0]/df["is_fraud"].value_counts()[1]
print(ratio)
# Out:
# 190.86817325800376

# %%
df["is_fraud"].value_counts()
# Out:
# is_fraud
# 0    101351
# 1       531
# Name: count, dtype: int64

# %%
df.isna().any()
# Out:
# trans_date_trans_time    False
# cc_num                   False
# merchant                 False
# category                 False
# amt                      False
# first                    False
# last                     False
# gender                   False
# street                   False
# city                     False
# state                    False
# zip                      False
# lat                      False
# long                     False
# city_pop                 False
# job                      False
# dob                      False
# trans_num                False
# unix_time                False
# merch_lat                False
# merch_long               False
# is_fraud                 False
# dtype: bool

# %%
numerical_columns = df.select_dtypes(
        include='number').columns.to_list()
numerical_columns
# Out:
# ['cc_num',
#  'amt',
#  'zip',
#  'lat',
#  'long',
#  'city_pop',
#  'unix_time',
#  'merch_lat',
#  'merch_long',
#  'is_fraud']

# %%
pd.set_option('display.max_columns', None)

df.head()
# Out:
#        trans_date_trans_time               cc_num                merchant  \
# 81955    2019-02-18 05:13:53       30442439074871   fraud_Prohaska-Murray
# 105389   2020-07-27 21:39:15  4599735407877245080    fraud_Crona and Sons
# 442525   2020-12-07 04:50:50      375848982312810  fraud_Erdman-Kertzmann
# 916621   2019-12-30 03:31:10      375237305371366        fraud_Sawayn PLC
# 117618   2019-03-07 18:03:51     4607072969078276    fraud_Abbott-Steuber
#
#              category     amt   first      last gender  \
# 81955   gas_transport   84.50   Linda   Sanchez      F
# 105389      kids_pets  141.70    Mary     Myers      F
# 442525  gas_transport   92.17    Dale     Smith      M
# 916621   shopping_pos    9.89   David  Erickson      M
# 117618  personal_care   13.98  Brenda     Perez      F
#
#                                     street            city state    zip  \
# 81955           6574 William Hill Apt. 375          Jermyn    PA  18433
# 105389         39787 Pamela Fall Suite 639     Tiptonville    TN  38079
# 442525  25036 Contreras Turnpike Suite 270         Purmela    TX  76566
# 916621         616 Jimenez Meadow Apt. 701  East Rochester    NY  14445
# 117618            033 Tara Brook Suite 523           Coyle    OK  73027
#
#             lat     long  city_pop                               job  \
# 81955   41.5744 -75.5881      6508  Training and development officer
# 105389  36.3846 -89.4649      5577                        Geochemist
# 442525  31.4841 -97.9903       258                      Web designer
# 916621  43.1128 -77.4906      8019                      Retail buyer
# 117618  35.8985 -97.2607      1493            Amenity horticulturist
#
#                dob                         trans_num   unix_time  merch_lat  \
# 81955   1981-06-22  e87d0600784494b1fa22cc39ee43a664  1329542033  41.415102
# 105389  1964-12-30  aa521d71ed29b262ed53702992785426  1374961155  35.532554
# 442525  1943-12-15  ebdbe410178c5365013842e9555aac59  1386391850  30.521008
# 916621  1928-06-26  ff86e07988b326802e76ef0db08dc994  1356838270  42.571261
# 117618  1985-03-21  bff6baa0a339d57d105bd587012d35a9  1331143431  36.858453
#
#         merch_long  is_fraud
# 81955   -74.742120         0
# 105389  -89.097033         0
# 442525  -97.837087         0
# 916621  -78.185175         0
# 117618  -97.334306         0

# %%
df.dtypes
# Out:
# trans_date_trans_time     object
# cc_num                     int64
# merchant                  object
# category                  object
# amt                      float64
# first                     object
# last                      object
# gender                    object
# street                    object
# city                      object
# state                     object
# zip                        int64
# lat                      float64
# long                     float64
# city_pop                   int64
# job                       object
# dob                       object
# trans_num                 object
# unix_time                  int64
# merch_lat                float64
# merch_long               float64
# is_fraud                   int64
# dtype: object

# %%
import numpy as np

def preprocess_lat_lon(df:pd.DataFrame, lat_col_name:str="latitude", lon_col_name:str="longitude") -> pd.DataFrame:
    """
    Preprocesses latitude and longitude columns.

    Parameters
    ----------
    df : pd.DataFrame
        The dataframe to preprocess.
    lat_col_name : str
        The name of the latitude column.
    lon_col_name : str
        The name of the longitude column.
        
    Returns
    -------
    pd.DataFrame
        The preprocessed dataframe.
    """
    # Convert to radians
    df[f"{lat_col_name}_x"] = np.cos(df[lat_col_name]) * np.cos(df[lon_col_name])
    df[f"{lon_col_name}_y"] = np.cos(df[lat_col_name]) * np.sin(df[lon_col_name])
    df[f"{lat_col_name}_z"] = np.sin(df[lat_col_name])
    return df.drop([lat_col_name, lon_col_name], axis=1)

# %%
y = "is_fraud"

# some generic cleaning
# Amt - amount of the transaction in local currency
# otherwise unrecognized cases in test set
counts = df.value_counts([y, "job"])
jobs_to_filter = counts[counts==1].reset_index()["job"].unique()
df = df.loc[~df.job.isin(jobs_to_filter)]

COLUMNS_TO_DROP = ["city", "trans_date_trans_time", "merchant", "first", "last", "street", "zip", "trans_num", "dob"]
assert df[y].isna().any() == False
raw_features = df.drop(COLUMNS_TO_DROP, axis=1)

raw_features = raw_features.transform(preprocess_lat_lon, lat_col_name="lat", lon_col_name="long")
raw_features = raw_features.transform(preprocess_lat_lon, lat_col_name="merch_lat", lon_col_name="merch_long")

# ML tuning
train, test = train_test_split(
    raw_features, test_size=0.2, random_state=0, stratify=df[[y, "job"]])

fit_le = LabelEncoder().fit(train[y])

# %%
train['is_fraud']
# Out:
# 206194     0
# 493703     0
# 159        0
# 1270652    0
# 703338     0
#           ..
# 157596     0
# 137950     0
# 1170743    0
# 262918     0
# 7781       0
# Name: is_fraud, Length: 54081, dtype: int64

# %%
class_weights = compute_class_weight(
                                        class_weight = "balanced",
                                        classes = np.unique(train['is_fraud']),
                                        y = train['is_fraud']                                                    
                                    )
class_weights = dict(zip(np.unique(train['is_fraud']), class_weights))
class_weights
# Out:
# {0: 0.5028451882845189, 1: 88.36764705882354}

# %%
class_weights_5 = [{0: 1, 1: 1}, {0: 1, 1: 5}, {0: 1, 1: 10}, {0: 1, 1: 20}]

# %%
pipeline = build_sklearn_pipeline(train, y, "logistic", LogisticRegression())
pipeline.fit(train.drop(y, axis=1), train[y])
print(Pipeline(pipeline.steps[:-1]).transform(train.drop(y, axis=1)).shape)
pipeline.predict(train.drop(y, axis=1))
# Out:
# (54081, 384)
# array([0, 0, 0, ..., 0, 0, 1], dtype=int64)

# %%
balance = [{0:100,1:1}, {0:10,1:1}, {0:1,1:1}, {0:1,1:10}, {0:1,1:100}]

# %%
param_grid = {
    'logistic__penalty': ['l2'],
    'logistic__C': [1, 10, 100, 1000],
    'pca__n_components': [10, 20,30],
    # 'under__sampling_strategy': [0.1, 0.2, 0.3, 0.5, 0.7, 1],
    # 'over__sampling_strategy': [0.2, 0.3, 0.4, 0.5, 0.7, 1]
    'logistic__class_weight': [{0: 0.5028451882845189, 1: 88.36764705882354}, {0:1,1:1}, {0:1,1:10}, {0:1,1:100}]
    # 'class_weight': ['balanced', {0: 1, 1: 5}]

}

# param_grid = {
#     'logistic__penalty': ['l2'],
#     'logistic__C': [10],
#     'pca__n_components': [10, 20,30],
#     # 'under__sampling_strategy': [0.1, 0.2, 0.3, 0.5, 0.7, 1],
#     # 'over__sampling_strategy': [0.2, 0.3, 0.4, 0.5, 0.7, 1]
#     'logistic__class_weight': [{0:1,1:10}]
#     # 'class_weight': ['balanced', {0: 1, 1: 5}]

# }

model = LogisticRegression()
# model = LogisticRegression(class_weight= class_weights)

MODEL_NAME = 'logistic'

grid = sklearn_gridsearch_using_pipeline(
    train, y_col_name=y, model=model, fit_le=fit_le, model_name='logistic', param_grid=param_grid, verbose=1,
    step_names_to_remove=['under', 'over'])

best_pipeline_log_reg = grid.best_estimator_
best_pipeline_log_reg
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# Best score: 0.899509842771705
# Best parameters: {'logistic__C': 10, 'logistic__class_weight': {0: 0.5028451882845189, 1: 88.36764705882354}, 'logistic__penalty': 'l2', 'pca__n_components': 30}
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('num_imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['cc_num', 'amt', 'city_pop',
#                                                    'unix_time', 'lat_x',
#                                                    'long_y', 'lat_z',
#                                                    'merch_lat_x',
#                                                    'merch_long_y',
#                                                    'merch_lat_z']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('cat_imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(sparse_output=False))]),
#                                                   ['category', 'gender',
#                                                    'state', 'job'])])),
#                 ('pca', PCA(n_components=30)),
#                 ('logistic',
#                  LogisticRegression(C=10,
#                                     class_weight={0: 0.5028451882845189,
#                                                   1: 88.36764705882354}))])

# %%
write_pipeline(best_pipeline_log_reg, MODEL_NAME, DATASET_NAME)

# %%
COLUMNS = ["pca__n_components", "logistic__class_weight", f"{MODEL_NAME}__C", f"{MODEL_NAME}__penalty", "roc_auc_mean", "roc_auc_std"]

pd.concat([
    pd.DataFrame(grid.cv_results_["params"]),
    pd.DataFrame(grid.cv_results_["mean_test_score"], columns=["roc_auc_mean"]),
    pd.DataFrame(grid.cv_results_["std_test_score"], columns=["roc_auc_std"])
    ],axis=1).dropna(subset=["roc_auc_mean", "roc_auc_std"])[COLUMNS] #.sort_values(by=COLUMNS)
# Out:
#     pca__n_components                         logistic__class_weight  \
# 0                  10  {0: 0.5028451882845189, 1: 88.36764705882354}
# 1                  20  {0: 0.5028451882845189, 1: 88.36764705882354}
# 2                  30  {0: 0.5028451882845189, 1: 88.36764705882354}
# 3                  10                                   {0: 1, 1: 1}
# 4                  20                                   {0: 1, 1: 1}
# 5                  30                                   {0: 1, 1: 1}
# 6                  10                                  {0: 1, 1: 10}
# 7                  20                                  {0: 1, 1: 10}
# 8                  30                                  {0: 1, 1: 10}
# 9                  10                                 {0: 1, 1: 100}
# 10                 20                                 {0: 1, 1: 100}
# 11                 30                                 {0: 1, 1: 100}
# 12                 10  {0: 0.5028451882845189, 1: 88.36764705882354}
# 13                 20  {0: 0.5028451882845189, 1: 88.36764705882354}
# 14                 30  {0: 0.5028451882845189, 1: 88.36764705882354}
# 15                 10                                   {0: 1, 1: 1}
# 16                 20                                   {0: 1, 1: 1}
# 17                 30                                   {0: 1, 1: 1}
# 18                 10                                  {0: 1, 1: 10}
# 19                 20                                  {0: 1, 1: 10}
# 20                 30                                  {0: 1, 1: 10}
# 21                 10                                 {0: 1, 1: 100}
# 22                 20                                 {0: 1, 1: 100}
# 23                 30                                 {0: 1, 1: 100}
# 24                 10  {0: 0.5028451882845189, 1: 88.36764705882354}
# 25                 20  {0: 0.5028451882845189, 1: 88.36764705882354}
# 26                 30  {0: 0.5028451882845189, 1: 88.36764705882354}
# 27                 10                                   {0: 1, 1: 1}
# 28                 20                                   {0: 1, 1: 1}
# 29                 30                                   {0: 1, 1: 1}
# 30                 10                                  {0: 1, 1: 10}
# 31                 20                                  {0: 1, 1: 10}
# 32                 30                                  {0: 1, 1: 10}
# 33                 10                                 {0: 1, 1: 100}
# 34                 20                                 {0: 1, 1: 100}
# 35                 30                                 {0: 1, 1: 100}
# 36                 10  {0: 0.5028451882845189, 1: 88.36764705882354}
# 37                 20  {0: 0.5028451882845189, 1: 88.36764705882354}
# 38                 30  {0: 0.5028451882845189, 1: 88.36764705882354}
# 39                 10                                   {0: 1, 1: 1}
# 40                 20                                   {0: 1, 1: 1}
# 41                 30                                   {0: 1, 1: 1}
# 42                 10                                  {0: 1, 1: 10}
# 43                 20                                  {0: 1, 1: 10}
# 44                 30                                  {0: 1, 1: 10}
# 45                 10                                 {0: 1, 1: 100}
# 46                 20                                 {0: 1, 1: 100}
# 47                 30                                 {0: 1, 1: 100}
#
#     logistic__C logistic__penalty  roc_auc_mean  roc_auc_std
# 0             1                l2      0.845495     0.041389
# 1             1                l2      0.897942     0.023415
# 2             1                l2      0.898961     0.027131
# 3             1                l2      0.829932     0.040578
# 4             1                l2      0.803685     0.030932
# 5             1                l2      0.807135     0.042061
# 6             1                l2      0.853581     0.043879
# 7             1                l2      0.882421     0.027314
# 8             1                l2      0.873917     0.034773
# 9             1                l2      0.846042     0.041751
# 10            1                l2      0.895172     0.024375
# 11            1                l2      0.896066     0.027890
# 12           10                l2      0.845494     0.041389
# 13           10                l2      0.897963     0.023441
# 14           10                l2      0.899510     0.026156
# 15           10                l2      0.829677     0.040562
# 16           10                l2      0.801715     0.031849
# 17           10                l2      0.804273     0.044611
# 18           10                l2      0.853578     0.043884
# 19           10                l2      0.882514     0.027242
# 20           10                l2      0.874274     0.033896
# 21           10                l2      0.846038     0.041752
# 22           10                l2      0.895252     0.024410
# 23           10                l2      0.896283     0.028091
# 24          100                l2      0.845493     0.041389
# 25          100                l2      0.897949     0.023458
# 26          100                l2      0.897670     0.025895
# 27          100                l2      0.829656     0.040554
# 28          100                l2      0.801420     0.031946
# 29          100                l2      0.804329     0.046002
# 30          100                l2      0.853577     0.043886
# 31          100                l2      0.882543     0.027253
# 32          100                l2      0.874336     0.034517
# 33          100                l2      0.846037     0.041751
# 34          100                l2      0.895294     0.024359
# 35          100                l2      0.895732     0.028335
# 36         1000                l2      0.845494     0.041389
# 37         1000                l2      0.897937     0.023431
# 38         1000                l2      0.899126     0.026657
# 39         1000                l2      0.829655     0.040555
# 40         1000                l2      0.801288     0.032172
# 41         1000                l2      0.804279     0.044769
# 42         1000                l2      0.853577     0.043886
# 43         1000                l2      0.882635     0.027249
# 44         1000                l2      0.873949     0.034477
# 45         1000                l2      0.846038     0.041752
# 46         1000                l2      0.895321     0.024362
# 47         1000                l2      0.896261     0.027910

# %%
evaluate_model(best_pipeline_log_reg, fit_le=fit_le, test=test, y_col_name=y, model_name = 'logistic')

# %%
num_positive = np.sum(train == 1)
num_negative = np.sum(train == 0)
scale_pos_weight = num_negative / num_positive
print(scale_pos_weight)
# Out:
# cc_num                 NaN
# category               NaN
# amt               0.000000
# gender                 NaN
# state                  NaN
# city_pop               NaN
# job                    NaN
# unix_time              NaN
# is_fraud        175.735294
# lat_x                  NaN
# long_y                 NaN
# lat_z                  NaN
# merch_lat_x            NaN
# merch_long_y           NaN
# merch_lat_z            NaN
# dtype: float64

# %%
param_grid_xgb = {
    'xgb__objective': ['binary:logistic'],
    'xgb__min_child_weight': [1, 5, 10],
    'xgb__gamma': [0.5, 1, 1.5, 2, 5],
    'xgb__subsample': [0.6, 0.8, 1.0],
    'xgb__colsample_bytree': [0.6, 0.8, 1.0],
    'xgb__max_depth': [3, 4, 5],
    'pca__n_components': [15, 20, 25,30,35,50,65],
    # 'under__sampling_strategy': [0.1, 0.2, 0.3, 0.5, 0.7, 1],
    # 'over__sampling_strategy': [0.2, 0.3, 0.4, 0.5, 0.7, 1]
    'xgb__scale_pos_weight':[ 1, 10, 50, 75, 100,175.735294,  1000]

}

xgb = XGBClassifier()

# xgb = XGBClassifier(scale_pos_weight=ratio)

MODEL_NAME = "xgb"

grid = sklearn_gridsearch_using_pipeline(
    train, y_col_name=y, fit_le=fit_le, model_name=MODEL_NAME, model=xgb, param_grid=param_grid_xgb, n_folds=5, verbose=1, randomized = True, step_names_to_remove=['under', 'over'])
best_pipeline_xgb = grid.best_estimator_
best_pipeline_xgb
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Best score: 0.9269235927793256
# Best parameters: {'xgb__subsample': 1.0, 'xgb__scale_pos_weight': 175.735294, 'xgb__objective': 'binary:logistic', 'xgb__min_child_weight': 1, 'xgb__max_depth': 3, 'xgb__gamma': 1.5, 'xgb__colsample_bytree': 0.8, 'pca__n_components': 30}
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('num_imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['cc_num', 'amt', 'city_pop',
#                                                    'unix_time', 'lat_x',
#                                                    'long_y', 'lat_z',
#                                                    'merch_lat_x',
#                                                    'merch_long_y',
#                                                    'merch_lat_z']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('cat_imputer',
#                                                                    SimpleImputer(strategy='most_frequent...
#                                feature_types=None, gamma=1.5, gpu_id=None,
#                                grow_policy=None, importance_type=None,
#                                interaction_constraints=None, learning_rate=None,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=3, max_leaves=None, min_child_weight=1,
#                                missing=nan, monotone_constraints=None,
#                                n_estimators=100, n_jobs=None,
#                                num_parallel_tree=None, predictor=None,
#                                random_state=None, ...))])

# %%
write_pipeline(best_pipeline_xgb, MODEL_NAME, DATASET_NAME)

# %%
evaluate_model(best_pipeline_xgb, fit_le=fit_le, test=test, y_col_name=y, model_name=MODEL_NAME)

# %%
MODEL_NAME='logistic'
best_pipeline_log_reg = load_pipeline(model_name=MODEL_NAME, dataset_name=DATASET_NAME)

MODEL_NAME='xgb'
best_pipeline_xgb = load_pipeline(model_name=MODEL_NAME, dataset_name=DATASET_NAME)

# %% [markdown]
# # evaluation metrics

# %%
test_predictions_log = test.copy(deep=True)
test_predictions_log["y_predicted"] = best_pipeline_log_reg.predict(test_predictions_log.drop(y, axis=1))
test_predictions_log["churn_encoded"] = fit_le.transform(test_predictions_log["is_fraud"])

# first check if customers have multiple rows => if so check if we can take other if this instance-based cost
impute = SimpleImputer(strategy='median')
test_predictions_log['A'] = impute.fit_transform(
    (test_predictions_log["amt"]*2000).to_frame())[:, 0]
# scaler = MinMaxScaler()

# Fit and transform the cb_cyolumn using the scaler
# test_predictions_log['A'] = scaler.fit_transform(test_predictions_log['A'].values.reshape(-1, 1))


# Step 3: Apply the function to calculate the cost for each instance and create the instance-dependent cost matrix
test_predictions_log['instance_cost'] = test_predictions_log.apply(lambda row: instance_dependent_cost_fraud(
    row['y_predicted'], row["churn_encoded"], row["A"]), axis=1)

test_predictions_log["y_predicted_decoded"] = fit_le.inverse_transform(
    test_predictions_log["y_predicted"])

# Print the DataFrame with the instance-dependent cost matrix
test_predictions_log[['is_fraud', 'y_predicted_decoded', "A", 'instance_cost']]

print(f"Test cost/loss = {test_predictions_log['instance_cost'].sum():.0f}.")
print(' total cost/loss average : ' , test_predictions_log['instance_cost'].sum()/len(test_predictions_log))
# Out:
# Test cost/loss = 1573.
#  total cost/loss average :  0.11635086162266105

# %%
test_predictions_xgb = test.copy(deep=True)
test_predictions_xgb["y_predicted"] = best_pipeline_xgb.predict(test_predictions_xgb.drop(y, axis=1))
test_predictions_xgb["churn_encoded"] = fit_le.transform(test_predictions_xgb["is_fraud"])

# first check if customers have multiple rows => if so check if we can take other if this instance-based cost
impute = SimpleImputer(strategy='median')
test_predictions_xgb['A'] = impute.fit_transform(
    (test_predictions_xgb["amt"]*2000).to_frame())[:, 0]
# scaler = MinMaxScaler()

# # Fit and transform the cb_column using the scaler
# test_predictions_xgb['A'] = scaler.fit_transform(test_predictions_xgb['A'].values.reshape(-1, 1))


# Step 3: Apply the function to calculate the cost for each instance and create the instance-dependent cost matrix
test_predictions_xgb['instance_cost'] = test_predictions_xgb.apply(lambda row: instance_dependent_cost_fraud(
    row['y_predicted'], row["churn_encoded"], row["A"]), axis=1)

test_predictions_xgb["y_predicted_decoded"] = fit_le.inverse_transform(
    test_predictions_xgb["y_predicted"])

# Print the DataFrame with the instance-dependent cost matrix
test_predictions_xgb[['is_fraud', 'y_predicted_decoded', "A", 'instance_cost']]

print(f"Test cost/loss = {test_predictions_xgb['instance_cost'].sum():.0f}.")
print(' total cost/loss average : ' , test_predictions_xgb['instance_cost'].sum()/len(test_predictions_xgb))
# Out:
# Test cost/loss = 3895.
#  total cost/loss average :  0.2880689298128836

# %%
print(test_predictions_log[['is_fraud', "A", 'instance_cost', "y_predicted"]].head(30))
# Out:
#          is_fraud          A  instance_cost  y_predicted
# 377359          0   125260.0            0.0            0
# 343471          0   134020.0            0.0            0
# 858312          0    35100.0            0.0            0
# 653694          0    64280.0            0.0            0
# 485688          0   137480.0            0.0            0
# 381035          0   240020.0            0.0            0
# 513268          0   103860.0            0.0            0
# 430783          0   155440.0            0.0            0
# 345889          0   193300.0            0.0            0
# 953633          0    92920.0            0.0            0
# 280700          0    15300.0            0.0            0
# 136120          0   354980.0            1.0            1
# 52731           0   297420.0            0.0            0
# 683053          0    81440.0            0.0            0
# 1201668         0   149280.0            0.0            0
# 1130978         0    12100.0            0.0            0
# 156956          1  2389120.0            0.0            1
# 264952          0    99380.0            0.0            0
# 247506          0    13240.0            0.0            0
# 99618           0    34820.0            0.0            0
# 275845          0   196520.0            0.0            0
# 427953          0    33160.0            0.0            0
# 406719          0     3180.0            0.0            0
# 974428          0    99980.0            0.0            0
# 1085445         0   161680.0            0.0            0
# 106698          0     7200.0            0.0            0
# 258741          0    96180.0            0.0            0
# 1006273         0   135200.0            1.0            1
# 35460           0   114460.0            0.0            0
# 872562          0   105460.0            0.0            0

# %% [markdown]
# # AMC metric

# %%
cb_column = 'A'
test_predictions_log['y_predicted_proba_log']= best_pipeline_log_reg.predict_proba(test_predictions_log.drop(y, axis=1))[:, 1]
best_threshold_log, AMC_log, lowest_cost_log = compute_best_threshold(test_predictions_log, best_pipeline_log_reg, y,cb_column, y_predicted_proba_col_name="y_predicted_proba_log", instance_dependent_cost_type = 'fraud')
# Out:
# Decision Threshold: 0.01, Test cost/loss = 12367.00
# Decision Threshold: 0.02, Test cost/loss = 11580.00
# Decision Threshold: 0.03, Test cost/loss = 11150.00
# Decision Threshold: 0.04, Test cost/loss = 10771.00
# Decision Threshold: 0.05, Test cost/loss = 10437.00
# Decision Threshold: 0.06, Test cost/loss = 10178.00
# Decision Threshold: 0.07, Test cost/loss = 9925.00
# Decision Threshold: 0.08, Test cost/loss = 9699.81
# Decision Threshold: 0.09, Test cost/loss = 9429.81
# Decision Threshold: 0.10, Test cost/loss = 9161.81
# Decision Threshold: 0.11, Test cost/loss = 8929.81
# Decision Threshold: 0.12, Test cost/loss = 8676.81
# Decision Threshold: 0.13, Test cost/loss = 8428.81
# Decision Threshold: 0.14, Test cost/loss = 8133.81
# Decision Threshold: 0.15, Test cost/loss = 7879.91
# Decision Threshold: 0.16, Test cost/loss = 7573.91
# Decision Threshold: 0.17, Test cost/loss = 7291.91
# Decision Threshold: 0.18, Test cost/loss = 7005.05
# Decision Threshold: 0.19, Test cost/loss = 6746.05
# Decision Threshold: 0.20, Test cost/loss = 6490.05
# Decision Threshold: 0.21, Test cost/loss = 6262.51
# Decision Threshold: 0.22, Test cost/loss = 6049.51
# Decision Threshold: 0.23, Test cost/loss = 5881.91
# Decision Threshold: 0.24, Test cost/loss = 5637.91
# Decision Threshold: 0.25, Test cost/loss = 5431.91
# Decision Threshold: 0.26, Test cost/loss = 5261.65
# Decision Threshold: 0.27, Test cost/loss = 5069.65
# Decision Threshold: 0.28, Test cost/loss = 4878.65
# Decision Threshold: 0.29, Test cost/loss = 4711.65
# Decision Threshold: 0.30, Test cost/loss = 4524.65
# Decision Threshold: 0.31, Test cost/loss = 4344.65
# Decision Threshold: 0.32, Test cost/loss = 4176.65
# Decision Threshold: 0.33, Test cost/loss = 4006.65
# Decision Threshold: 0.34, Test cost/loss = 3843.65
# Decision Threshold: 0.35, Test cost/loss = 3682.65
# Decision Threshold: 0.36, Test cost/loss = 3536.65
# Decision Threshold: 0.37, Test cost/loss = 3362.65
# Decision Threshold: 0.38, Test cost/loss = 3206.65
# Decision Threshold: 0.39, Test cost/loss = 3039.65
# Decision Threshold: 0.40, Test cost/loss = 2896.65
# Decision Threshold: 0.41, Test cost/loss = 2736.46
# Decision Threshold: 0.42, Test cost/loss = 2576.46
# Decision Threshold: 0.43, Test cost/loss = 2442.46
# Decision Threshold: 0.44, Test cost/loss = 2299.46
# Decision Threshold: 0.45, Test cost/loss = 2164.18
# Decision Threshold: 0.46, Test cost/loss = 2037.18
# Decision Threshold: 0.47, Test cost/loss = 1905.18
# Decision Threshold: 0.48, Test cost/loss = 1786.18
# Decision Threshold: 0.49, Test cost/loss = 1668.18
# Decision Threshold: 0.50, Test cost/loss = 1573.18
# Decision Threshold: 0.51, Test cost/loss = 1490.18
# Decision Threshold: 0.52, Test cost/loss = 1385.18
# Decision Threshold: 0.53, Test cost/loss = 1298.18
# Decision Threshold: 0.54, Test cost/loss = 1227.18
# Decision Threshold: 0.55, Test cost/loss = 1148.18
# Decision Threshold: 0.56, Test cost/loss = 1080.18
# Decision Threshold: 0.57, Test cost/loss = 1020.18
# Decision Threshold: 0.58, Test cost/loss = 970.18
# Decision Threshold: 0.59, Test cost/loss = 1293.83
# Decision Threshold: 0.60, Test cost/loss = 1253.83
# Decision Threshold: 0.61, Test cost/loss = 1207.83
# Decision Threshold: 0.62, Test cost/loss = 1423.84
# Decision Threshold: 0.63, Test cost/loss = 1382.84
# Decision Threshold: 0.64, Test cost/loss = 1336.84
# Decision Threshold: 0.65, Test cost/loss = 1293.84
# Decision Threshold: 0.66, Test cost/loss = 1266.84
# Decision Threshold: 0.67, Test cost/loss = 1241.84
# Decision Threshold: 0.68, Test cost/loss = 1208.84
# Decision Threshold: 0.69, Test cost/loss = 1184.84
# Decision Threshold: 0.70, Test cost/loss = 1166.84
# Decision Threshold: 0.71, Test cost/loss = 1150.84
# Decision Threshold: 0.72, Test cost/loss = 1133.84
# Decision Threshold: 0.73, Test cost/loss = 1737.73
# Decision Threshold: 0.74, Test cost/loss = 1716.73
# Decision Threshold: 0.75, Test cost/loss = 1698.73
# Decision Threshold: 0.76, Test cost/loss = 1972.11
# Decision Threshold: 0.77, Test cost/loss = 1961.11
# Decision Threshold: 0.78, Test cost/loss = 1952.11
# Decision Threshold: 0.79, Test cost/loss = 1935.11
# Decision Threshold: 0.80, Test cost/loss = 2191.88
# Decision Threshold: 0.81, Test cost/loss = 2503.24
# Decision Threshold: 0.82, Test cost/loss = 2801.37
# Decision Threshold: 0.83, Test cost/loss = 3095.45
# Decision Threshold: 0.84, Test cost/loss = 3983.32
# Decision Threshold: 0.85, Test cost/loss = 3975.32
# Decision Threshold: 0.86, Test cost/loss = 4742.87
# Decision Threshold: 0.87, Test cost/loss = 4736.87
# Decision Threshold: 0.88, Test cost/loss = 4731.87
# Decision Threshold: 0.89, Test cost/loss = 5044.47
# Decision Threshold: 0.90, Test cost/loss = 5754.53
# Decision Threshold: 0.91, Test cost/loss = 6103.51
# Decision Threshold: 0.92, Test cost/loss = 6395.31
# Decision Threshold: 0.93, Test cost/loss = 7449.08
# Decision Threshold: 0.94, Test cost/loss = 7444.08
# Decision Threshold: 0.95, Test cost/loss = 7437.08
# Decision Threshold: 0.96, Test cost/loss = 7968.87
# Decision Threshold: 0.97, Test cost/loss = 8791.26
# Decision Threshold: 0.98, Test cost/loss = 10416.16
# Decision Threshold: 0.99, Test cost/loss = 13023.32
# Best Decision Threshold: 0.58, Lowest Test cost/loss = 970.18, Lowest AMC = 0.07

# %%
test_predictions_xgb['y_predicted_proba_xgb']= best_pipeline_xgb.predict_proba(test_predictions_xgb.drop(y, axis=1))[:, 1]
best_threshold_xgb, AMC_xgb, lowest_cost_xgb = compute_best_threshold(test_predictions_xgb, best_pipeline_xgb, y, cb_column, y_predicted_proba_col_name="y_predicted_proba_xgb", instance_dependent_cost_type= 'fraud' )
# Out:
# Decision Threshold: 0.01, Test cost/loss = 6748.00
# Decision Threshold: 0.02, Test cost/loss = 5148.95
# Decision Threshold: 0.03, Test cost/loss = 4213.29
# Decision Threshold: 0.04, Test cost/loss = 3582.99
# Decision Threshold: 0.05, Test cost/loss = 3105.71
# Decision Threshold: 0.06, Test cost/loss = 2677.71
# Decision Threshold: 0.07, Test cost/loss = 2688.92
# Decision Threshold: 0.08, Test cost/loss = 2418.92
# Decision Threshold: 0.09, Test cost/loss = 2235.92
# Decision Threshold: 0.10, Test cost/loss = 2043.92
# Decision Threshold: 0.11, Test cost/loss = 1896.92
# Decision Threshold: 0.12, Test cost/loss = 1762.92
# Decision Threshold: 0.13, Test cost/loss = 1658.38
# Decision Threshold: 0.14, Test cost/loss = 1562.38
# Decision Threshold: 0.15, Test cost/loss = 1469.38
# Decision Threshold: 0.16, Test cost/loss = 1385.38
# Decision Threshold: 0.17, Test cost/loss = 1322.38
# Decision Threshold: 0.18, Test cost/loss = 1262.38
# Decision Threshold: 0.19, Test cost/loss = 1198.38
# Decision Threshold: 0.20, Test cost/loss = 1145.38
# Decision Threshold: 0.21, Test cost/loss = 1467.03
# Decision Threshold: 0.22, Test cost/loss = 1421.03
# Decision Threshold: 0.23, Test cost/loss = 1370.03
# Decision Threshold: 0.24, Test cost/loss = 1333.03
# Decision Threshold: 0.25, Test cost/loss = 1291.03
# Decision Threshold: 0.26, Test cost/loss = 1273.03
# Decision Threshold: 0.27, Test cost/loss = 1247.03
# Decision Threshold: 0.28, Test cost/loss = 1223.03
# Decision Threshold: 0.29, Test cost/loss = 1202.03
# Decision Threshold: 0.30, Test cost/loss = 1178.03
# Decision Threshold: 0.31, Test cost/loss = 1163.03
# Decision Threshold: 0.32, Test cost/loss = 1146.03
# Decision Threshold: 0.33, Test cost/loss = 1136.84
# Decision Threshold: 0.34, Test cost/loss = 1118.84
# Decision Threshold: 0.35, Test cost/loss = 1108.84
# Decision Threshold: 0.36, Test cost/loss = 1093.84
# Decision Threshold: 0.37, Test cost/loss = 1094.84
# Decision Threshold: 0.38, Test cost/loss = 1074.84
# Decision Threshold: 0.39, Test cost/loss = 1066.84
# Decision Threshold: 0.40, Test cost/loss = 1057.84
# Decision Threshold: 0.41, Test cost/loss = 1050.84
# Decision Threshold: 0.42, Test cost/loss = 1815.39
# Decision Threshold: 0.43, Test cost/loss = 1800.39
# Decision Threshold: 0.44, Test cost/loss = 3077.68
# Decision Threshold: 0.45, Test cost/loss = 3070.68
# Decision Threshold: 0.46, Test cost/loss = 3064.68
# Decision Threshold: 0.47, Test cost/loss = 3058.68
# Decision Threshold: 0.48, Test cost/loss = 3051.68
# Decision Threshold: 0.49, Test cost/loss = 3899.98
# Decision Threshold: 0.50, Test cost/loss = 3894.98
# Decision Threshold: 0.51, Test cost/loss = 3886.98
# Decision Threshold: 0.52, Test cost/loss = 3882.98
# Decision Threshold: 0.53, Test cost/loss = 3878.98
# Decision Threshold: 0.54, Test cost/loss = 3874.98
# Decision Threshold: 0.55, Test cost/loss = 3869.98
# Decision Threshold: 0.56, Test cost/loss = 3864.98
# Decision Threshold: 0.57, Test cost/loss = 3858.98
# Decision Threshold: 0.58, Test cost/loss = 3853.98
# Decision Threshold: 0.59, Test cost/loss = 3844.98
# Decision Threshold: 0.60, Test cost/loss = 3840.98
# Decision Threshold: 0.61, Test cost/loss = 3835.98
# Decision Threshold: 0.62, Test cost/loss = 4458.87
# Decision Threshold: 0.63, Test cost/loss = 4456.87
# Decision Threshold: 0.64, Test cost/loss = 4455.87
# Decision Threshold: 0.65, Test cost/loss = 4996.66
# Decision Threshold: 0.66, Test cost/loss = 4995.66
# Decision Threshold: 0.67, Test cost/loss = 4993.66
# Decision Threshold: 0.68, Test cost/loss = 4990.66
# Decision Threshold: 0.69, Test cost/loss = 4989.66
# Decision Threshold: 0.70, Test cost/loss = 5303.02
# Decision Threshold: 0.71, Test cost/loss = 5302.02
# Decision Threshold: 0.72, Test cost/loss = 5301.02
# Decision Threshold: 0.73, Test cost/loss = 5297.02
# Decision Threshold: 0.74, Test cost/loss = 5294.02
# Decision Threshold: 0.75, Test cost/loss = 5293.02
# Decision Threshold: 0.76, Test cost/loss = 5291.02
# Decision Threshold: 0.77, Test cost/loss = 5290.02
# Decision Threshold: 0.78, Test cost/loss = 5290.02
# Decision Threshold: 0.79, Test cost/loss = 5288.02
# Decision Threshold: 0.80, Test cost/loss = 5285.02
# Decision Threshold: 0.81, Test cost/loss = 5285.02
# Decision Threshold: 0.82, Test cost/loss = 5284.02
# Decision Threshold: 0.83, Test cost/loss = 5283.02
# Decision Threshold: 0.84, Test cost/loss = 5279.02
# Decision Threshold: 0.85, Test cost/loss = 5278.02
# Decision Threshold: 0.86, Test cost/loss = 5998.70
# Decision Threshold: 0.87, Test cost/loss = 7013.37
# Decision Threshold: 0.88, Test cost/loss = 7008.37
# Decision Threshold: 0.89, Test cost/loss = 7006.37
# Decision Threshold: 0.90, Test cost/loss = 7004.37
# Decision Threshold: 0.91, Test cost/loss = 7343.46
# Decision Threshold: 0.92, Test cost/loss = 7342.46
# Decision Threshold: 0.93, Test cost/loss = 7340.46
# Decision Threshold: 0.94, Test cost/loss = 7337.46
# Decision Threshold: 0.95, Test cost/loss = 8117.08
# Decision Threshold: 0.96, Test cost/loss = 9035.53
# Decision Threshold: 0.97, Test cost/loss = 9603.62
# Decision Threshold: 0.98, Test cost/loss = 11075.30
# Decision Threshold: 0.99, Test cost/loss = 12526.32
# Best Decision Threshold: 0.41, Lowest Test cost/loss = 1050.84, Lowest AMC = 0.08

# %% [markdown]
# # E-AMC

# %%
test_predictions_log = add_eap_ep(
    train=train, 
    test=test_predictions_log, 
    y_col_name=y, 
    best_pipeline=best_pipeline_log_reg, 
    cb_column=cb_column, 
    predicted_proba_col_name='y_predicted_proba_log', 
    churn_label= 1, 
    instance_dependent_cost_type="fraud")
test_predictions_xgb = add_eap_ep(
    train=train, 
    test=test_predictions_xgb, 
    y_col_name=y, 
    best_pipeline=best_pipeline_xgb, 
    cb_column=cb_column, 
    predicted_proba_col_name="y_predicted_proba_xgb", 
    churn_label=1, 
    instance_dependent_cost_type="fraud")
# Out:
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:329: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_0['EAP'] = test_actual_label_0[predicted_proba_col_name]*test_actual_label_0['FP'] + \
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:331: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_0['EP'] = estimated_p_1*test_actual_label_0['FP']+estimated_p_0*test_actual_label_0['TN']
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:333: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_1['EAP'] = test_actual_label_1[predicted_proba_col_name]*test_actual_label_1['TP'] + \
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:335: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_1['EP'] = estimated_p_1 * test_actual_label_1['TP'] + estimated_p_0 * test_actual_label_1['FN']
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:329: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_0['EAP'] = test_actual_label_0[predicted_proba_col_name]*test_actual_label_0['FP'] + \
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:331: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_0['EP'] = estimated_p_1*test_actual_label_0['FP']+estimated_p_0*test_actual_label_0['TN']
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:333: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_1['EAP'] = test_actual_label_1[predicted_proba_col_name]*test_actual_label_1['TP'] + \
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:335: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_1['EP'] = estimated_p_1 * test_actual_label_1['TP'] + estimated_p_0 * test_actual_label_1['FN']

# %%
test_predictions_log
# Out:
#                       cc_num        category      amt gender state  city_pop  \
# 377359      3540210836308425     food_dining    62.63      M    TX        53
# 343471          639030014711   entertainment    67.01      M    IL       639
# 858312       377264520876399   personal_care    17.55      F    SC      4424
# 653694       213157767990030  health_fitness    32.14      F    WY     27971
# 485688        30408301059761       kids_pets    68.74      M    SC      4471
# ...                      ...             ...      ...    ...   ...       ...
# 1202685      374821819075109  health_fitness    19.34      M    NY      9565
# 670176      4266200684857219    shopping_net  1083.88      M    NE       732
# 1131211  4810789809665942990   entertainment   544.79      F    OH       338
# 90178          4195740185974     grocery_pos   314.36      M    OR    841711
# 670559      6011542681743618     grocery_pos   358.98      F    VA       863
#
#                                     job   unix_time  is_fraud     lat_x  \
# 377359                Fisheries officer  1384536888         0  0.386883
# 343471              Mechanical engineer  1383260389         0  0.374299
# 858312                           Lawyer  1355689325         0 -0.370872
# 653694                  Music therapist  1349466301         0  0.539446
# 485688           Occupational hygienist  1343748738         0 -0.025769
# ...                                 ...         ...       ...       ...
# 1202685             Exhibition designer  1368835137         1 -0.151494
# 670176   Television/film/video producer  1350086058         1  0.624315
# 1131211               Quantity surveyor  1366066429         1  0.134441
# 90178       Engineer, building services  1374463871         1 -0.022418
# 670559                 Engineer, mining  1350099543         1 -0.432334
#
#            long_y     lat_z  merch_lat_x  merch_long_y  merch_lat_z  \
# 377359   0.903359 -0.185107     0.974763      0.171631    -0.142757
# 343471  -0.790767 -0.484343    -0.101118     -0.751755    -0.651644
# 858312  -0.903818  0.213464    -0.117634     -0.817296    -0.564083
# 653694   0.478639 -0.692750    -0.001038     -0.002552    -0.999996
# 485688  -0.341624  0.939483     0.190030     -0.354266     0.915633
# ...           ...       ...          ...           ...          ...
# 1202685 -0.586493 -0.795660     0.420107     -0.862442    -0.282320
# 670176  -0.503856  0.596958     0.691758      0.004403     0.722116
# 1131211  0.269255  0.953639    -0.021650      0.099756     0.994776
# 90178    0.004107  0.999740    -0.325970     -0.031024     0.944871
# 670559   0.104784  0.895604    -0.223838     -0.005511     0.974611
#
#          y_predicted  churn_encoded          A  instance_cost  \
# 377359             0              0   125260.0           0.00
# 343471             0              0   134020.0           0.00
# 858312             0              0    35100.0           0.00
# 653694             0              0    64280.0           0.00
# 485688             0              0   137480.0           0.00
# ...              ...            ...        ...            ...
# 1202685            0              1    38680.0          19.34
# 670176             1              1  2167760.0           0.00
# 1131211            1              1  1089580.0         544.79
# 90178              1              1   628720.0         314.36
# 670559             1              1   717960.0         358.98
#
#          y_predicted_decoded  y_predicted_proba_log  TN       FN  FP  TP  \
# 377359                     0               0.139684   0    62.63   1   0
# 343471                     0               0.014245   0    67.01   1   0
# 858312                     0               0.257365   0    17.55   1   0
# 653694                     0               0.242835   0    32.14   1   0
# 485688                     0               0.331213   0    68.74   1   0
# ...                      ...                    ...  ..      ...  ..  ..
# 1202685                    0               0.226523   0    19.34   1   0
# 670176                     1               0.997431   0  1083.88   1   0
# 1131211                    1               0.952933   0   544.79   1   0
# 90178                      1               0.802604   0   314.36   1   0
# 670559                     1               0.908526   0   358.98   1   0
#
#                EAP           EP
# 377359    0.139684     0.005658
# 343471    0.014245     0.005658
# 858312    0.257365     0.005658
# 653694    0.242835     0.005658
# 485688    0.331213     0.005658
# ...            ...          ...
# 1202685  14.959041    19.230571
# 670176    2.784479  1077.747213
# 1131211  25.641771   541.707480
# 90178    62.053359   312.581295
# 670559   32.837453   356.948827
#
# [13521 rows x 27 columns]

# %%
test_predictions_xgb
# Out:
#                       cc_num        category      amt gender state  city_pop  \
# 377359      3540210836308425     food_dining    62.63      M    TX        53
# 343471          639030014711   entertainment    67.01      M    IL       639
# 858312       377264520876399   personal_care    17.55      F    SC      4424
# 653694       213157767990030  health_fitness    32.14      F    WY     27971
# 485688        30408301059761       kids_pets    68.74      M    SC      4471
# ...                      ...             ...      ...    ...   ...       ...
# 1202685      374821819075109  health_fitness    19.34      M    NY      9565
# 670176      4266200684857219    shopping_net  1083.88      M    NE       732
# 1131211  4810789809665942990   entertainment   544.79      F    OH       338
# 90178          4195740185974     grocery_pos   314.36      M    OR    841711
# 670559      6011542681743618     grocery_pos   358.98      F    VA       863
#
#                                     job   unix_time  is_fraud     lat_x  \
# 377359                Fisheries officer  1384536888         0  0.386883
# 343471              Mechanical engineer  1383260389         0  0.374299
# 858312                           Lawyer  1355689325         0 -0.370872
# 653694                  Music therapist  1349466301         0  0.539446
# 485688           Occupational hygienist  1343748738         0 -0.025769
# ...                                 ...         ...       ...       ...
# 1202685             Exhibition designer  1368835137         1 -0.151494
# 670176   Television/film/video producer  1350086058         1  0.624315
# 1131211               Quantity surveyor  1366066429         1  0.134441
# 90178       Engineer, building services  1374463871         1 -0.022418
# 670559                 Engineer, mining  1350099543         1 -0.432334
#
#            long_y     lat_z  merch_lat_x  merch_long_y  merch_lat_z  \
# 377359   0.903359 -0.185107     0.974763      0.171631    -0.142757
# 343471  -0.790767 -0.484343    -0.101118     -0.751755    -0.651644
# 858312  -0.903818  0.213464    -0.117634     -0.817296    -0.564083
# 653694   0.478639 -0.692750    -0.001038     -0.002552    -0.999996
# 485688  -0.341624  0.939483     0.190030     -0.354266     0.915633
# ...           ...       ...          ...           ...          ...
# 1202685 -0.586493 -0.795660     0.420107     -0.862442    -0.282320
# 670176  -0.503856  0.596958     0.691758      0.004403     0.722116
# 1131211  0.269255  0.953639    -0.021650      0.099756     0.994776
# 90178    0.004107  0.999740    -0.325970     -0.031024     0.944871
# 670559   0.104784  0.895604    -0.223838     -0.005511     0.974611
#
#          y_predicted  churn_encoded          A  instance_cost  \
# 377359             0              0   125260.0           0.00
# 343471             0              0   134020.0           0.00
# 858312             0              0    35100.0           0.00
# 653694             0              0    64280.0           0.00
# 485688             0              0   137480.0           0.00
# ...              ...            ...        ...            ...
# 1202685            0              1    38680.0          19.34
# 670176             1              1  2167760.0           0.00
# 1131211            1              1  1089580.0         544.79
# 90178              1              1   628720.0         314.36
# 670559             1              1   717960.0           0.00
#
#          y_predicted_decoded  y_predicted_proba_xgb  TN       FN  FP  TP  \
# 377359                     0               0.019904   0    62.63   1   0
# 343471                     0               0.000159   0    67.01   1   0
# 858312                     0               0.027998   0    17.55   1   0
# 653694                     0               0.068678   0    32.14   1   0
# 485688                     0               0.013107   0    68.74   1   0
# ...                      ...                    ...  ..      ...  ..  ..
# 1202685                    0               0.026504   0    19.34   1   0
# 670176                     1               0.998277   0  1083.88   1   0
# 1131211                    1               0.647450   0   544.79   1   0
# 90178                      1               0.697626   0   314.36   1   0
# 670559                     1               0.995718   0   358.98   1   0
#
#                 EAP           EP
# 377359     0.019904     0.005658
# 343471     0.000159     0.005658
# 858312     0.027998     0.005658
# 653694     0.068678     0.005658
# 485688     0.013107     0.005658
# ...             ...          ...
# 1202685   18.827421    19.230571
# 670176     1.867064  1077.747213
# 1131211  192.065731   541.707480
# 90178     95.054423   312.581295
# 670559     1.537259   356.948827
#
# [13521 rows x 27 columns]

# %%
print(test_predictions_log['EAP'].sum())
print(test_predictions_log['EP'].sum())


print('EAP : ', test_predictions_log['EAP'].sum()/len(test_predictions_log))
print('EP : ', test_predictions_log['EP'].sum()/len(test_predictions_log))
# Out:
# 4705.968615612789
# 26764.698161091692
# EAP :  0.3480488584877442
# EP :  1.9794910258924407

# %%
print(test_predictions_xgb['EAP'].sum())
print(test_predictions_xgb['EP'].sum())


print('EAP : ', test_predictions_xgb['EAP'].sum()/len(test_predictions_xgb))
print('EP : ', test_predictions_xgb['EP'].sum()/len(test_predictions_xgb))
# Out:
# 3969.0375024876535
# 26764.698161091692
# EAP :  0.29354615061664474
# EP :  1.9794910258924407

# %% [markdown]
# # mp 50% threshold

# %%
test_predictions_log_2= test.copy(deep=True)
test_predictions_log_2["y_predicted"] = best_pipeline_log_reg.predict(test_predictions_log_2.drop(y, axis=1))
test_predictions_log_2["churn_encoded"] = fit_le.transform(test_predictions_log_2["is_fraud"])

# first check if customers have multiple rows => if so check if we can take other if this instance-based cost
impute = SimpleImputer(strategy='median')
test_predictions_log_2['A'] = impute.fit_transform(
    (test_predictions_log_2["amt"]*2000).to_frame())[:, 0]
# scaler = MinMaxScaler()

# Fit and transform the cb_cyolumn using the scaler
# test_predictions_log['A'] = scaler.fit_transform(test_predictions_log['A'].values.reshape(-1, 1))


# Step 3: Apply the function to calculate the cost for each instance and create the instance-dependent cost matrix
test_predictions_log_2['instance_cost'] = test_predictions_log_2.apply(lambda row: instance_dependent_cost_fraud_2(
    row['y_predicted'], row["churn_encoded"], row["A"]), axis=1)

test_predictions_log_2["y_predicted_decoded"] = fit_le.inverse_transform(
    test_predictions_log_2["y_predicted"])

# Print the DataFrame with the instance-dependent cost matrix
test_predictions_log_2[['is_fraud', 'y_predicted_decoded', "A", 'instance_cost']]

print(f"Test cost/loss = {test_predictions_log_2['instance_cost'].sum():.0f}.")
print(' total cost/loss average : ' , test_predictions_log_2['instance_cost'].sum()/len(test_predictions_log_2))
# Out:
# Test cost/loss = -1534.
#  total cost/loss average :  -0.11346645958139191

# %%
test_predictions_xgb_2 = test.copy(deep=True)
test_predictions_xgb_2["y_predicted"] = best_pipeline_xgb.predict(test_predictions_xgb_2.drop(y, axis=1))
test_predictions_xgb_2["churn_encoded"] = fit_le.transform(test_predictions_xgb_2["is_fraud"])

# first check if customers have multiple rows => if so check if we can take other if this instance-based cost
impute = SimpleImputer(strategy='median')
test_predictions_xgb_2['A'] = impute.fit_transform(
    (test_predictions_xgb_2["amt"]*2000).to_frame())[:, 0]
# scaler = MinMaxScaler()

# # Fit and transform the cb_column using the scaler
# test_predictions_xgb['A'] = scaler.fit_transform(test_predictions_xgb['A'].values.reshape(-1, 1))


# Step 3: Apply the function to calculate the cost for each instance and create the instance-dependent cost matrix
test_predictions_xgb_2['instance_cost'] = test_predictions_xgb_2.apply(lambda row: instance_dependent_cost_fraud_2(
    row['y_predicted'], row["churn_encoded"], row["A"]), axis=1)

test_predictions_xgb_2["y_predicted_decoded"] = fit_le.inverse_transform(
    test_predictions_xgb_2["y_predicted"])

# Print the DataFrame with the instance-dependent cost matrix
test_predictions_xgb_2[['is_fraud', 'y_predicted_decoded', "A", 'instance_cost']]

print(f"Test cost/loss = {test_predictions_xgb_2['instance_cost'].sum():.0f}.")
print(' total cost/loss average : ' , test_predictions_xgb_2['instance_cost'].sum()/len(test_predictions_xgb_2))
# Out:
# Test cost/loss = -3861.
#  total cost/loss average :  -0.2855543229051105

# %% [markdown]
# # mp-metric

# %%
cb_column = 'A'
test_predictions_log_2['y_predicted_proba_log']= best_pipeline_log_reg.predict_proba(test_predictions_log_2.drop(y, axis=1))[:, 1]
best_threshold_log, AMC_log, lowest_cost_log = compute_best_threshold_2(test_predictions_log_2, best_pipeline_log_reg, y,cb_column, y_predicted_proba_col_name="y_predicted_proba_log", instance_dependent_cost_type = 'fraud_2')
# Out:
# Decision Threshold: 0.01, Test cost/loss = -12316.00
# Decision Threshold: 0.02, Test cost/loss = -11529.00
# Decision Threshold: 0.03, Test cost/loss = -11099.00
# Decision Threshold: 0.04, Test cost/loss = -10720.00
# Decision Threshold: 0.05, Test cost/loss = -10386.00
# Decision Threshold: 0.06, Test cost/loss = -10127.00
# Decision Threshold: 0.07, Test cost/loss = -9875.00
# Decision Threshold: 0.08, Test cost/loss = -9650.81
# Decision Threshold: 0.09, Test cost/loss = -9380.81
# Decision Threshold: 0.10, Test cost/loss = -9113.81
# Decision Threshold: 0.11, Test cost/loss = -8881.81
# Decision Threshold: 0.12, Test cost/loss = -8628.81
# Decision Threshold: 0.13, Test cost/loss = -8380.81
# Decision Threshold: 0.14, Test cost/loss = -8085.81
# Decision Threshold: 0.15, Test cost/loss = -7832.91
# Decision Threshold: 0.16, Test cost/loss = -7526.91
# Decision Threshold: 0.17, Test cost/loss = -7244.91
# Decision Threshold: 0.18, Test cost/loss = -6959.05
# Decision Threshold: 0.19, Test cost/loss = -6700.05
# Decision Threshold: 0.20, Test cost/loss = -6444.05
# Decision Threshold: 0.21, Test cost/loss = -6217.51
# Decision Threshold: 0.22, Test cost/loss = -6004.51
# Decision Threshold: 0.23, Test cost/loss = -5839.91
# Decision Threshold: 0.24, Test cost/loss = -5595.91
# Decision Threshold: 0.25, Test cost/loss = -5389.91
# Decision Threshold: 0.26, Test cost/loss = -5220.65
# Decision Threshold: 0.27, Test cost/loss = -5028.65
# Decision Threshold: 0.28, Test cost/loss = -4837.65
# Decision Threshold: 0.29, Test cost/loss = -4670.65
# Decision Threshold: 0.30, Test cost/loss = -4483.65
# Decision Threshold: 0.31, Test cost/loss = -4303.65
# Decision Threshold: 0.32, Test cost/loss = -4135.65
# Decision Threshold: 0.33, Test cost/loss = -3965.65
# Decision Threshold: 0.34, Test cost/loss = -3802.65
# Decision Threshold: 0.35, Test cost/loss = -3641.65
# Decision Threshold: 0.36, Test cost/loss = -3495.65
# Decision Threshold: 0.37, Test cost/loss = -3321.65
# Decision Threshold: 0.38, Test cost/loss = -3165.65
# Decision Threshold: 0.39, Test cost/loss = -2998.65
# Decision Threshold: 0.40, Test cost/loss = -2855.65
# Decision Threshold: 0.41, Test cost/loss = -2696.46
# Decision Threshold: 0.42, Test cost/loss = -2536.46
# Decision Threshold: 0.43, Test cost/loss = -2402.46
# Decision Threshold: 0.44, Test cost/loss = -2259.46
# Decision Threshold: 0.45, Test cost/loss = -2125.18
# Decision Threshold: 0.46, Test cost/loss = -1998.18
# Decision Threshold: 0.47, Test cost/loss = -1866.18
# Decision Threshold: 0.48, Test cost/loss = -1747.18
# Decision Threshold: 0.49, Test cost/loss = -1629.18
# Decision Threshold: 0.50, Test cost/loss = -1534.18
# Decision Threshold: 0.51, Test cost/loss = -1451.18
# Decision Threshold: 0.52, Test cost/loss = -1346.18
# Decision Threshold: 0.53, Test cost/loss = -1259.18
# Decision Threshold: 0.54, Test cost/loss = -1188.18
# Decision Threshold: 0.55, Test cost/loss = -1109.18
# Decision Threshold: 0.56, Test cost/loss = -1041.18
# Decision Threshold: 0.57, Test cost/loss = -981.18
# Decision Threshold: 0.58, Test cost/loss = -931.18
# Decision Threshold: 0.59, Test cost/loss = -1255.83
# Decision Threshold: 0.60, Test cost/loss = -1215.83
# Decision Threshold: 0.61, Test cost/loss = -1169.83
# Decision Threshold: 0.62, Test cost/loss = -1386.84
# Decision Threshold: 0.63, Test cost/loss = -1345.84
# Decision Threshold: 0.64, Test cost/loss = -1299.84
# Decision Threshold: 0.65, Test cost/loss = -1256.84
# Decision Threshold: 0.66, Test cost/loss = -1229.84
# Decision Threshold: 0.67, Test cost/loss = -1204.84
# Decision Threshold: 0.68, Test cost/loss = -1171.84
# Decision Threshold: 0.69, Test cost/loss = -1147.84
# Decision Threshold: 0.70, Test cost/loss = -1129.84
# Decision Threshold: 0.71, Test cost/loss = -1113.84
# Decision Threshold: 0.72, Test cost/loss = -1096.84
# Decision Threshold: 0.73, Test cost/loss = -1701.73
# Decision Threshold: 0.74, Test cost/loss = -1680.73
# Decision Threshold: 0.75, Test cost/loss = -1662.73
# Decision Threshold: 0.76, Test cost/loss = -1937.11
# Decision Threshold: 0.77, Test cost/loss = -1926.11
# Decision Threshold: 0.78, Test cost/loss = -1917.11
# Decision Threshold: 0.79, Test cost/loss = -1900.11
# Decision Threshold: 0.80, Test cost/loss = -2157.88
# Decision Threshold: 0.81, Test cost/loss = -2470.24
# Decision Threshold: 0.82, Test cost/loss = -2769.37
# Decision Threshold: 0.83, Test cost/loss = -3064.45
# Decision Threshold: 0.84, Test cost/loss = -3955.32
# Decision Threshold: 0.85, Test cost/loss = -3947.32
# Decision Threshold: 0.86, Test cost/loss = -4715.87
# Decision Threshold: 0.87, Test cost/loss = -4709.87
# Decision Threshold: 0.88, Test cost/loss = -4704.87
# Decision Threshold: 0.89, Test cost/loss = -5018.47
# Decision Threshold: 0.90, Test cost/loss = -5730.53
# Decision Threshold: 0.91, Test cost/loss = -6080.51
# Decision Threshold: 0.92, Test cost/loss = -6373.31
# Decision Threshold: 0.93, Test cost/loss = -7429.08
# Decision Threshold: 0.94, Test cost/loss = -7424.08
# Decision Threshold: 0.95, Test cost/loss = -7417.08
# Decision Threshold: 0.96, Test cost/loss = -7949.87
# Decision Threshold: 0.97, Test cost/loss = -8773.26
# Decision Threshold: 0.98, Test cost/loss = -10400.16
# Decision Threshold: 0.99, Test cost/loss = -13010.32
# Best Decision Threshold: 0.58, Lowest Test cost/loss = -931.18, Lowest AMC = -0.07

# %%
test_predictions_xgb_2['y_predicted_proba_xgb']= best_pipeline_xgb.predict_proba(test_predictions_xgb_2.drop(y, axis=1))[:, 1]
best_threshold_xgb, AMC_xgb, lowest_cost_xgb = compute_best_threshold(test_predictions_xgb_2, best_pipeline_xgb, y, cb_column, y_predicted_proba_col_name="y_predicted_proba_xgb", instance_dependent_cost_type= 'fraud_2' )
# Out:
# Decision Threshold: 0.01, Test cost/loss = -6697.00
# Decision Threshold: 0.02, Test cost/loss = -5099.95
# Decision Threshold: 0.03, Test cost/loss = -4165.29
# Decision Threshold: 0.04, Test cost/loss = -3536.99
# Decision Threshold: 0.05, Test cost/loss = -3060.71
# Decision Threshold: 0.06, Test cost/loss = -2632.71
# Decision Threshold: 0.07, Test cost/loss = -2646.92
# Decision Threshold: 0.08, Test cost/loss = -2376.92
# Decision Threshold: 0.09, Test cost/loss = -2193.92
# Decision Threshold: 0.10, Test cost/loss = -2001.92
# Decision Threshold: 0.11, Test cost/loss = -1854.92
# Decision Threshold: 0.12, Test cost/loss = -1720.92
# Decision Threshold: 0.13, Test cost/loss = -1617.38
# Decision Threshold: 0.14, Test cost/loss = -1522.38
# Decision Threshold: 0.15, Test cost/loss = -1429.38
# Decision Threshold: 0.16, Test cost/loss = -1345.38
# Decision Threshold: 0.17, Test cost/loss = -1282.38
# Decision Threshold: 0.18, Test cost/loss = -1222.38
# Decision Threshold: 0.19, Test cost/loss = -1158.38
# Decision Threshold: 0.20, Test cost/loss = -1105.38
# Decision Threshold: 0.21, Test cost/loss = -1428.03
# Decision Threshold: 0.22, Test cost/loss = -1382.03
# Decision Threshold: 0.23, Test cost/loss = -1331.03
# Decision Threshold: 0.24, Test cost/loss = -1294.03
# Decision Threshold: 0.25, Test cost/loss = -1252.03
# Decision Threshold: 0.26, Test cost/loss = -1234.03
# Decision Threshold: 0.27, Test cost/loss = -1208.03
# Decision Threshold: 0.28, Test cost/loss = -1184.03
# Decision Threshold: 0.29, Test cost/loss = -1163.03
# Decision Threshold: 0.30, Test cost/loss = -1139.03
# Decision Threshold: 0.31, Test cost/loss = -1124.03
# Decision Threshold: 0.32, Test cost/loss = -1107.03
# Decision Threshold: 0.33, Test cost/loss = -1098.84
# Decision Threshold: 0.34, Test cost/loss = -1080.84
# Decision Threshold: 0.35, Test cost/loss = -1070.84
# Decision Threshold: 0.36, Test cost/loss = -1055.84
# Decision Threshold: 0.37, Test cost/loss = -1057.84
# Decision Threshold: 0.38, Test cost/loss = -1037.84
# Decision Threshold: 0.39, Test cost/loss = -1029.84
# Decision Threshold: 0.40, Test cost/loss = -1020.84
# Decision Threshold: 0.41, Test cost/loss = -1013.84
# Decision Threshold: 0.42, Test cost/loss = -1779.39
# Decision Threshold: 0.43, Test cost/loss = -1764.39
# Decision Threshold: 0.44, Test cost/loss = -3042.68
# Decision Threshold: 0.45, Test cost/loss = -3035.68
# Decision Threshold: 0.46, Test cost/loss = -3029.68
# Decision Threshold: 0.47, Test cost/loss = -3023.68
# Decision Threshold: 0.48, Test cost/loss = -3016.68
# Decision Threshold: 0.49, Test cost/loss = -3865.98
# Decision Threshold: 0.50, Test cost/loss = -3860.98
# Decision Threshold: 0.51, Test cost/loss = -3852.98
# Decision Threshold: 0.52, Test cost/loss = -3848.98
# Decision Threshold: 0.53, Test cost/loss = -3844.98
# Decision Threshold: 0.54, Test cost/loss = -3840.98
# Decision Threshold: 0.55, Test cost/loss = -3835.98
# Decision Threshold: 0.56, Test cost/loss = -3830.98
# Decision Threshold: 0.57, Test cost/loss = -3824.98
# Decision Threshold: 0.58, Test cost/loss = -3819.98
# Decision Threshold: 0.59, Test cost/loss = -3810.98
# Decision Threshold: 0.60, Test cost/loss = -3806.98
# Decision Threshold: 0.61, Test cost/loss = -3801.98
# Decision Threshold: 0.62, Test cost/loss = -4425.87
# Decision Threshold: 0.63, Test cost/loss = -4423.87
# Decision Threshold: 0.64, Test cost/loss = -4422.87
# Decision Threshold: 0.65, Test cost/loss = -4964.66
# Decision Threshold: 0.66, Test cost/loss = -4963.66
# Decision Threshold: 0.67, Test cost/loss = -4961.66
# Decision Threshold: 0.68, Test cost/loss = -4958.66
# Decision Threshold: 0.69, Test cost/loss = -4957.66
# Decision Threshold: 0.70, Test cost/loss = -5272.02
# Decision Threshold: 0.71, Test cost/loss = -5271.02
# Decision Threshold: 0.72, Test cost/loss = -5270.02
# Decision Threshold: 0.73, Test cost/loss = -5266.02
# Decision Threshold: 0.74, Test cost/loss = -5263.02
# Decision Threshold: 0.75, Test cost/loss = -5262.02
# Decision Threshold: 0.76, Test cost/loss = -5260.02
# Decision Threshold: 0.77, Test cost/loss = -5259.02
# Decision Threshold: 0.78, Test cost/loss = -5259.02
# Decision Threshold: 0.79, Test cost/loss = -5257.02
# Decision Threshold: 0.80, Test cost/loss = -5254.02
# Decision Threshold: 0.81, Test cost/loss = -5254.02
# Decision Threshold: 0.82, Test cost/loss = -5253.02
# Decision Threshold: 0.83, Test cost/loss = -5252.02
# Decision Threshold: 0.84, Test cost/loss = -5248.02
# Decision Threshold: 0.85, Test cost/loss = -5247.02
# Decision Threshold: 0.86, Test cost/loss = -5968.70
# Decision Threshold: 0.87, Test cost/loss = -6984.37
# Decision Threshold: 0.88, Test cost/loss = -6979.37
# Decision Threshold: 0.89, Test cost/loss = -6977.37
# Decision Threshold: 0.90, Test cost/loss = -6975.37
# Decision Threshold: 0.91, Test cost/loss = -7315.46
# Decision Threshold: 0.92, Test cost/loss = -7314.46
# Decision Threshold: 0.93, Test cost/loss = -7312.46
# Decision Threshold: 0.94, Test cost/loss = -7309.46
# Decision Threshold: 0.95, Test cost/loss = -8090.08
# Decision Threshold: 0.96, Test cost/loss = -9011.53
# Decision Threshold: 0.97, Test cost/loss = -9581.62
# Decision Threshold: 0.98, Test cost/loss = -11056.30
# Decision Threshold: 0.99, Test cost/loss = -12510.32
# Best Decision Threshold: 0.99, Lowest Test cost/loss = -12510.32, Lowest AMC = -0.93

# %%
len(test)
# Out:
# 13521

# %% [markdown]
# # E-MP metric

# %%
test_predictions_log_2 = add_eap_ep(
    train=train, 
    test=test_predictions_log_2, 
    y_col_name=y, 
    best_pipeline=best_pipeline_log_reg, 
    cb_column=cb_column, 
    predicted_proba_col_name='y_predicted_proba_log', 
    churn_label= 1, 
    instance_dependent_cost_type="fraud_2")
test_predictions_xgb_2 = add_eap_ep(
    train=train, 
    test=test_predictions_xgb_2, 
    y_col_name=y, 
    best_pipeline=best_pipeline_xgb, 
    cb_column=cb_column, 
    predicted_proba_col_name="y_predicted_proba_xgb", 
    churn_label=1, 
    instance_dependent_cost_type="fraud_2")
# Out:
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:329: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_0['EAP'] = test_actual_label_0[predicted_proba_col_name]*test_actual_label_0['FP'] + \
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:331: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_0['EP'] = estimated_p_1*test_actual_label_0['FP']+estimated_p_0*test_actual_label_0['TN']
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:333: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_1['EAP'] = test_actual_label_1[predicted_proba_col_name]*test_actual_label_1['TP'] + \
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:335: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_1['EP'] = estimated_p_1 * test_actual_label_1['TP'] + estimated_p_0 * test_actual_label_1['FN']
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:329: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_0['EAP'] = test_actual_label_0[predicted_proba_col_name]*test_actual_label_0['FP'] + \
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:331: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_0['EP'] = estimated_p_1*test_actual_label_0['FP']+estimated_p_0*test_actual_label_0['TN']
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:333: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_1['EAP'] = test_actual_label_1[predicted_proba_col_name]*test_actual_label_1['TP'] + \
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:335: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_1['EP'] = estimated_p_1 * test_actual_label_1['TP'] + estimated_p_0 * test_actual_label_1['FN']

# %%
print(test_predictions_log_2['EAP'].sum())
print(test_predictions_log_2['EP'].sum())


print('EAP : ', test_predictions_log_2['EAP'].sum()/len(test_predictions_log_2))
print('EP : ', test_predictions_log_2['EP'].sum()/len(test_predictions_log_2))
# Out:
# -4668.063675008788
# -26764.409593942415
# EAP :  -0.3452454459735809
# EP :  -1.979469683746943

# %%
print(test_predictions_xgb_2['EAP'].sum())
print(test_predictions_xgb_2['EP'].sum())


print('EAP : ', test_predictions_xgb_2['EAP'].sum()/len(test_predictions_xgb_2))
print('EP : ', test_predictions_xgb_2['EP'].sum()/len(test_predictions_xgb_2))
# Out:
# -3934.0304644121766
# -26764.409593942415
# EAP :  -0.2909570641529603
# EP :  -1.979469683746943

# %%
test_predictions_log_2
# Out:
#                       cc_num        category      amt gender state  city_pop  \
# 377359      3540210836308425     food_dining    62.63      M    TX        53
# 343471          639030014711   entertainment    67.01      M    IL       639
# 858312       377264520876399   personal_care    17.55      F    SC      4424
# 653694       213157767990030  health_fitness    32.14      F    WY     27971
# 485688        30408301059761       kids_pets    68.74      M    SC      4471
# ...                      ...             ...      ...    ...   ...       ...
# 1202685      374821819075109  health_fitness    19.34      M    NY      9565
# 670176      4266200684857219    shopping_net  1083.88      M    NE       732
# 1131211  4810789809665942990   entertainment   544.79      F    OH       338
# 90178          4195740185974     grocery_pos   314.36      M    OR    841711
# 670559      6011542681743618     grocery_pos   358.98      F    VA       863
#
#                                     job   unix_time  is_fraud     lat_x  \
# 377359                Fisheries officer  1384536888         0  0.386883
# 343471              Mechanical engineer  1383260389         0  0.374299
# 858312                           Lawyer  1355689325         0 -0.370872
# 653694                  Music therapist  1349466301         0  0.539446
# 485688           Occupational hygienist  1343748738         0 -0.025769
# ...                                 ...         ...       ...       ...
# 1202685             Exhibition designer  1368835137         1 -0.151494
# 670176   Television/film/video producer  1350086058         1  0.624315
# 1131211               Quantity surveyor  1366066429         1  0.134441
# 90178       Engineer, building services  1374463871         1 -0.022418
# 670559                 Engineer, mining  1350099543         1 -0.432334
#
#            long_y     lat_z  merch_lat_x  merch_long_y  merch_lat_z  \
# 377359   0.903359 -0.185107     0.974763      0.171631    -0.142757
# 343471  -0.790767 -0.484343    -0.101118     -0.751755    -0.651644
# 858312  -0.903818  0.213464    -0.117634     -0.817296    -0.564083
# 653694   0.478639 -0.692750    -0.001038     -0.002552    -0.999996
# 485688  -0.341624  0.939483     0.190030     -0.354266     0.915633
# ...           ...       ...          ...           ...          ...
# 1202685 -0.586493 -0.795660     0.420107     -0.862442    -0.282320
# 670176  -0.503856  0.596958     0.691758      0.004403     0.722116
# 1131211  0.269255  0.953639    -0.021650      0.099756     0.994776
# 90178    0.004107  0.999740    -0.325970     -0.031024     0.944871
# 670559   0.104784  0.895604    -0.223838     -0.005511     0.974611
#
#          y_predicted  churn_encoded          A  instance_cost  \
# 377359             0              0   125260.0           0.00
# 343471             0              0   134020.0           0.00
# 858312             0              0    35100.0           0.00
# 653694             0              0    64280.0           0.00
# 485688             0              0   137480.0           0.00
# ...              ...            ...        ...            ...
# 1202685            0              1    38680.0         -19.34
# 670176             1              1  2167760.0           1.00
# 1131211            1              1  1089580.0        -544.79
# 90178              1              1   628720.0        -314.36
# 670559             1              1   717960.0        -358.98
#
#          y_predicted_decoded  y_predicted_proba_log  TN       FN  FP  TP  \
# 377359                     0               0.139684   0   -62.63  -1   1
# 343471                     0               0.014245   0   -67.01  -1   1
# 858312                     0               0.257365   0   -17.55  -1   1
# 653694                     0               0.242835   0   -32.14  -1   1
# 485688                     0               0.331213   0   -68.74  -1   1
# ...                      ...                    ...  ..      ...  ..  ..
# 1202685                    0               0.226523   0   -19.34  -1   1
# 670176                     1               0.997431   0 -1083.88  -1   1
# 1131211                    1               0.952933   0  -544.79  -1   1
# 90178                      1               0.802604   0  -314.36  -1   1
# 670559                     1               0.908526   0  -358.98  -1   1
#
#                EAP           EP
# 377359   -0.139684    -0.005658
# 343471   -0.014245    -0.005658
# 858312   -0.257365    -0.005658
# 653694   -0.242835    -0.005658
# 485688   -0.331213    -0.005658
# ...            ...          ...
# 1202685 -14.732517   -19.224913
# 670176   -1.787048 -1077.741554
# 1131211 -24.688838  -541.701822
# 90178   -61.250754  -312.575637
# 670559  -31.928927  -356.943169
#
# [13521 rows x 27 columns]

# %% [markdown]
# # cost- curves

# %%
len(test_predictions_log['FP'])
# Out:
# 13521

# %%
total_fp_log = 0

for i in range(0,13521):
    if test_predictions_log['churn_encoded'].iloc[i] == 0 and test_predictions_log['y_predicted'].iloc[i]==1:
        total_fp_log += test_predictions_log['FP'].iloc[i]
    else:
        total_fp_log += 0

print(total_fp_log)

average_fp_log = total_fp_log/13521
print( average_fp_log)
# Out:
# 1381
# 0.10213741587160713

# %%
total_fn_log = 0

for i in range(0,13521):
    if test_predictions_log['churn_encoded'].iloc[i] == 1 and test_predictions_log['y_predicted'].iloc[i]==0:
        total_fn_log += test_predictions_log['FN'].iloc[i]
    else:
        total_fn_log += 0

print(total_fn_log)

average_fn_log = total_fn_log/13521
print( average_fn_log)
# Out:
# 192.18
# 0.014213445751053917

# %%
# C(-|+)
cost_fn_log = average_fn_log
# C(+|-)
cost_fp_log = average_fp_log

# Ground truth
truth = test_predictions_log['churn_encoded']
#  <a list of 0 (negative class) or 1 (positive class)>
# Predictions from a classifier
score = test_predictions_log['y_predicted']
# best_pipeline_log_reg.predict_proba(test.drop(y_encoded_col_name, axis=1))[:, 1]
# <a list of [0,1] class probabilities>

# %% OUTPUTS

# 1D-array of x-axis values (normalized PC)
pc = None
# list of lines as (slope, intercept)
lines = []
# lower envelope of the list of lines as a 1D-array of y-axis values (NEC)
lower_envelope = []
# area under the lower envelope (the smaller, the better)
area = None

# %% COMPUTATION

# points from the roc curve, because a point in the ROC space <=> a line in the cost space
roc_fpr, roc_tpr, _ = roc_curve(truth, score)

# compute the normalized p(+)*C(-|+)
thresholds = np.arange(0, 1.01, .01)
pc = (thresholds*cost_fn_log) / (thresholds*cost_fn_log + (1-thresholds)*cost_fp_log)

# compute a line in the cost space for each point in the roc space
for fpr, tpr in zip(roc_fpr, roc_tpr):
    slope = (1-tpr-fpr)
    intercept = fpr
    lines.append((slope, intercept))

# compute the lower envelope
for x_value in pc:
    y_value = min([slope*x_value+intercept for slope, intercept in lines])
    lower_envelope.append(max(0, y_value))
lower_envelope = np.array(lower_envelope)

# compute the area under the lower envelope using the composite trapezoidal rule
area = np.trapz(lower_envelope, pc)

# %% EXAMPLE OF PLOT

# display each line as a thin dashed line
for slope, intercept in lines:
    plt.plot(pc, slope*pc+intercept, color="grey", lw=1, linestyle="--")

# display the lower envelope as a thicker black line
plt.plot(pc, lower_envelope, color="black", lw=3, label="area={:.3f}".format(area))

# plot parameters
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05*max(lower_envelope)])
plt.xlabel("Probability Cost Function")
plt.ylabel("Normalized Expected Cost")
plt.title("Cost curve")
plt.legend(loc="lower right")

plt.show()

# %%
total_fp_xgb = 0

for i in range(0,13521):
    if test_predictions_xgb['churn_encoded'].iloc[i] == 0 and test_predictions_xgb['y_predicted'].iloc[i]==1:
        total_fp_xgb += test_predictions_xgb['FP'].iloc[i]
    else:
        total_fp_xgb += 0

print(total_fp_xgb)

average_fp_xgb = total_fp_xgb/13521
print( average_fp_xgb)
# Out:
# 138
# 0.010206345684490793

# %%
total_fn_xgb = 0

for i in range(0,13521):
    if test_predictions_xgb['churn_encoded'].iloc[i] == 1 and test_predictions_xgb['y_predicted'].iloc[i]==0:
        total_fn_xgb += test_predictions_xgb['FN'].iloc[i]
    else:
        total_fn_xgb += 0

print(total_fn_xgb)

average_fn_xgb = total_fn_xgb/13521
print( average_fn_xgb)
# Out:
# 3756.9799999999996
# 0.2778625841283928

# %%
# C(-|+)
cost_fn_xgb = average_fn_xgb
# C(+|-)
cost_fp_xgb = average_fp_xgb

# Ground truth
truth = test_predictions_xgb['churn_encoded']
#  <a list of 0 (negative class) or 1 (positive class)>
# Predictions from a classifier
score = test_predictions_xgb['y_predicted']
# best_pipeline_log_reg.predict_proba(test.drop(y_encoded_col_name, axis=1))[:, 1]
# <a list of [0,1] class probabilities>

# %% OUTPUTS

# 1D-array of x-axis values (normalized PC)
pc = None
# list of lines as (slope, intercept)
lines = []
# lower envelope of the list of lines as a 1D-array of y-axis values (NEC)
lower_envelope = []
# area under the lower envelope (the smaller, the better)
area = None

# %% COMPUTATION

# points from the roc curve, because a point in the ROC space <=> a line in the cost space
roc_fpr, roc_tpr, _ = roc_curve(truth, score)

# compute the normalized p(+)*C(-|+)
thresholds = np.arange(0, 1.01, .01)
pc = (thresholds*cost_fn_xgb) / (thresholds*cost_fn_xgb + (1-thresholds)*cost_fp_xgb)

# compute a line in the cost space for each point in the roc space
for fpr, tpr in zip(roc_fpr, roc_tpr):
    slope = (1-tpr-fpr)
    intercept = fpr
    lines.append((slope, intercept))

# compute the lower envelope
for x_value in pc:
    y_value = min([slope*x_value+intercept for slope, intercept in lines])
    lower_envelope.append(max(0, y_value))
lower_envelope = np.array(lower_envelope)

# compute the area under the lower envelope using the composite trapezoidal rule
area = np.trapz(lower_envelope, pc)

# %% EXAMPLE OF PLOT

# display each line as a thin dashed line
for slope, intercept in lines:
    plt.plot(pc, slope*pc+intercept, color="grey", lw=1, linestyle="--")

# display the lower envelope as a thicker black line
plt.plot(pc, lower_envelope, color="black", lw=3, label="area={:.3f}".format(area))

# plot parameters
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05*max(lower_envelope)])
plt.xlabel("Probability Cost Function")
plt.ylabel("Normalized Expected Cost")
plt.title("Cost curve")
plt.legend(loc="lower right")

plt.show()

# %% [markdown]
# # from here on we calculate the amc, e-amc, mp and emp but with the churn prediction cost and benefit matrices

# %% [markdown]
# # total cost at 50% decision threshold

# %%
test_predictions_log_churn = test.copy(deep=True)
test_predictions_log_churn["y_predicted"] = best_pipeline_log_reg.predict(test_predictions_log_churn.drop(y, axis=1))
test_predictions_log_churn["churn_encoded"] = fit_le.transform(test_predictions_log_churn["is_fraud"])

# first check if customers have multiple rows => if so check if we can take other if this instance-based cost
impute = SimpleImputer(strategy='median')
test_predictions_log_churn['A'] = impute.fit_transform(
    (test_predictions_log_churn["amt"]).to_frame())[:, 0]
# scaler = MinMaxScaler()

# Fit and transform the cb_cyolumn using the scaler
# test_predictions_log['A'] = scaler.fit_transform(test_predictions_log['A'].values.reshape(-1, 1))


# Step 3: Apply the function to calculate the cost for each instance and create the instance-dependent cost matrix
test_predictions_log_churn['instance_cost'] = test_predictions_log_churn.apply(lambda row: instance_dependent_cost_churn(
    row['y_predicted'], row["churn_encoded"], row["A"]), axis=1)

test_predictions_log_churn["y_predicted_decoded"] = fit_le.inverse_transform(
    test_predictions_log_churn["y_predicted"])

# Print the DataFrame with the instance-dependent cost matrix
test_predictions_log_churn[['is_fraud', 'y_predicted_decoded', "A", 'instance_cost']]

print(f"Test cost/loss = {test_predictions_log_churn['instance_cost'].sum():.0f}.")
print(' total cost/loss average : ' , test_predictions_log_churn['instance_cost'].sum()/len(test_predictions_log_churn))
# Out:
# Test cost/loss = 596063.
#  total cost/loss average :  44.08420974779972

# %%
test_predictions_xgb_churn = test.copy(deep=True)
test_predictions_xgb_churn["y_predicted"] = best_pipeline_xgb.predict(test_predictions_xgb_churn.drop(y, axis=1))
test_predictions_xgb_churn["churn_encoded"] = fit_le.transform(test_predictions_xgb_churn["is_fraud"])

# first check if customers have multiple rows => if so check if we can take other if this instance-based cost
impute = SimpleImputer(strategy='median')
test_predictions_xgb_churn['A'] = impute.fit_transform(
    (test_predictions_xgb_churn["amt"]).to_frame())[:, 0]
# scaler = MinMaxScaler()

# # Fit and transform the cb_column using the scaler
# test_predictions_xgb_churn['A'] = scaler.fit_transform(test_predictions_xgb_churn['A'].values.reshape(-1, 1))


# Step 3: Apply the function to calculate the cost for each instance and create the instance-dependent cost matrix
test_predictions_xgb_churn['instance_cost'] = test_predictions_xgb_churn.apply(lambda row: instance_dependent_cost_churn(
    row['y_predicted'], row["churn_encoded"], row["A"]), axis=1)

test_predictions_xgb_churn["y_predicted_decoded"] = fit_le.inverse_transform(
    test_predictions_xgb_churn["y_predicted"])

# Print the DataFrame with the instance-dependent cost matrix
test_predictions_xgb_churn[['is_fraud', 'y_predicted_decoded', "A", 'instance_cost']]

print(f"Test cost/loss = {test_predictions_xgb_churn['instance_cost'].sum():.0f}.")
print(' total cost/loss average : ' , test_predictions_xgb_churn['instance_cost'].sum()/len(test_predictions_xgb_churn))
# Out:
# Test cost/loss = 170712.
#  total cost/loss average :  12.625718511944383

# %% [markdown]
# # amc metric

# %%
cb_column = 'A'
test_predictions_log_churn['y_predicted_proba_log']= best_pipeline_log_reg.predict_proba(test_predictions_log_churn.drop(y, axis=1))[:, 1]
best_threshold_log, AMC_log, lowest_cost_log = compute_best_threshold(test_predictions_log_churn, best_pipeline_log_reg, y,cb_column, y_predicted_proba_col_name="y_predicted_proba_log", instance_dependent_cost_type = 'churn')
# Out:
# Decision Threshold: 0.01, Test cost/loss = 1795725.56
# Decision Threshold: 0.02, Test cost/loss = 1750985.34
# Decision Threshold: 0.03, Test cost/loss = 1714321.50
# Decision Threshold: 0.04, Test cost/loss = 1679765.98
# Decision Threshold: 0.05, Test cost/loss = 1646384.30
# Decision Threshold: 0.06, Test cost/loss = 1620057.24
# Decision Threshold: 0.07, Test cost/loss = 1591107.26
# Decision Threshold: 0.08, Test cost/loss = 1567245.06
# Decision Threshold: 0.09, Test cost/loss = 1543766.08
# Decision Threshold: 0.10, Test cost/loss = 1519373.78
# Decision Threshold: 0.11, Test cost/loss = 1502658.50
# Decision Threshold: 0.12, Test cost/loss = 1482533.02
# Decision Threshold: 0.13, Test cost/loss = 1459935.94
# Decision Threshold: 0.14, Test cost/loss = 1433918.30
# Decision Threshold: 0.15, Test cost/loss = 1409311.92
# Decision Threshold: 0.16, Test cost/loss = 1382196.98
# Decision Threshold: 0.17, Test cost/loss = 1354010.22
# Decision Threshold: 0.18, Test cost/loss = 1326813.44
# Decision Threshold: 0.19, Test cost/loss = 1302778.18
# Decision Threshold: 0.20, Test cost/loss = 1276496.96
# Decision Threshold: 0.21, Test cost/loss = 1251312.16
# Decision Threshold: 0.22, Test cost/loss = 1229835.34
# Decision Threshold: 0.23, Test cost/loss = 1209215.50
# Decision Threshold: 0.24, Test cost/loss = 1183149.18
# Decision Threshold: 0.25, Test cost/loss = 1161461.24
# Decision Threshold: 0.26, Test cost/loss = 1143684.90
# Decision Threshold: 0.27, Test cost/loss = 1120534.76
# Decision Threshold: 0.28, Test cost/loss = 1097884.64
# Decision Threshold: 0.29, Test cost/loss = 1077545.70
# Decision Threshold: 0.30, Test cost/loss = 1052424.62
# Decision Threshold: 0.31, Test cost/loss = 1028168.94
# Decision Threshold: 0.32, Test cost/loss = 1004722.38
# Decision Threshold: 0.33, Test cost/loss = 981837.20
# Decision Threshold: 0.34, Test cost/loss = 958744.48
# Decision Threshold: 0.35, Test cost/loss = 937526.96
# Decision Threshold: 0.36, Test cost/loss = 915991.82
# Decision Threshold: 0.37, Test cost/loss = 891927.52
# Decision Threshold: 0.38, Test cost/loss = 869385.16
# Decision Threshold: 0.39, Test cost/loss = 845463.36
# Decision Threshold: 0.40, Test cost/loss = 821990.06
# Decision Threshold: 0.41, Test cost/loss = 796074.92
# Decision Threshold: 0.42, Test cost/loss = 767733.74
# Decision Threshold: 0.43, Test cost/loss = 745628.18
# Decision Threshold: 0.44, Test cost/loss = 722894.28
# Decision Threshold: 0.45, Test cost/loss = 699684.44
# Decision Threshold: 0.46, Test cost/loss = 679041.28
# Decision Threshold: 0.47, Test cost/loss = 656086.34
# Decision Threshold: 0.48, Test cost/loss = 635063.80
# Decision Threshold: 0.49, Test cost/loss = 614260.62
# Decision Threshold: 0.50, Test cost/loss = 596062.60
# Decision Threshold: 0.51, Test cost/loss = 577935.06
# Decision Threshold: 0.52, Test cost/loss = 557843.86
# Decision Threshold: 0.53, Test cost/loss = 538721.56
# Decision Threshold: 0.54, Test cost/loss = 523101.94
# Decision Threshold: 0.55, Test cost/loss = 506444.02
# Decision Threshold: 0.56, Test cost/loss = 492636.58
# Decision Threshold: 0.57, Test cost/loss = 477808.44
# Decision Threshold: 0.58, Test cost/loss = 466214.56
# Decision Threshold: 0.59, Test cost/loss = 459332.20
# Decision Threshold: 0.60, Test cost/loss = 449748.96
# Decision Threshold: 0.61, Test cost/loss = 434471.38
# Decision Threshold: 0.62, Test cost/loss = 423050.14
# Decision Threshold: 0.63, Test cost/loss = 411333.94
# Decision Threshold: 0.64, Test cost/loss = 398875.04
# Decision Threshold: 0.65, Test cost/loss = 385214.02
# Decision Threshold: 0.66, Test cost/loss = 376772.06
# Decision Threshold: 0.67, Test cost/loss = 368662.92
# Decision Threshold: 0.68, Test cost/loss = 356850.46
# Decision Threshold: 0.69, Test cost/loss = 348572.84
# Decision Threshold: 0.70, Test cost/loss = 342773.32
# Decision Threshold: 0.71, Test cost/loss = 335602.18
# Decision Threshold: 0.72, Test cost/loss = 327696.86
# Decision Threshold: 0.73, Test cost/loss = 324955.14
# Decision Threshold: 0.74, Test cost/loss = 313907.48
# Decision Threshold: 0.75, Test cost/loss = 304587.74
# Decision Threshold: 0.76, Test cost/loss = 302369.50
# Decision Threshold: 0.77, Test cost/loss = 296844.88
# Decision Threshold: 0.78, Test cost/loss = 292103.98
# Decision Threshold: 0.79, Test cost/loss = 282841.90
# Decision Threshold: 0.80, Test cost/loss = 281150.48
# Decision Threshold: 0.81, Test cost/loss = 283039.00
# Decision Threshold: 0.82, Test cost/loss = 281748.12
# Decision Threshold: 0.83, Test cost/loss = 279485.92
# Decision Threshold: 0.84, Test cost/loss = 288172.44
# Decision Threshold: 0.85, Test cost/loss = 283107.90
# Decision Threshold: 0.86, Test cost/loss = 287083.90
# Decision Threshold: 0.87, Test cost/loss = 281454.22
# Decision Threshold: 0.88, Test cost/loss = 276941.12
# Decision Threshold: 0.89, Test cost/loss = 276576.08
# Decision Threshold: 0.90, Test cost/loss = 277698.80
# Decision Threshold: 0.91, Test cost/loss = 272135.44
# Decision Threshold: 0.92, Test cost/loss = 265481.22
# Decision Threshold: 0.93, Test cost/loss = 269490.28
# Decision Threshold: 0.94, Test cost/loss = 263934.30
# Decision Threshold: 0.95, Test cost/loss = 255129.18
# Decision Threshold: 0.96, Test cost/loss = 247331.30
# Decision Threshold: 0.97, Test cost/loss = 246577.82
# Decision Threshold: 0.98, Test cost/loss = 250357.64
# Decision Threshold: 0.99, Test cost/loss = 263183.98
# Best Decision Threshold: 0.97, Lowest Test cost/loss = 246577.82, Lowest AMC = 18.24

# %%
test_predictions_xgb_churn['y_predicted_proba_xgb']= best_pipeline_xgb.predict_proba(test_predictions_xgb_churn.drop(y, axis=1))[:, 1]
best_threshold_xgb, AMC_xgb, lowest_cost_xgb = compute_best_threshold(test_predictions_xgb_churn, best_pipeline_xgb, y, cb_column, y_predicted_proba_col_name="y_predicted_proba_xgb", instance_dependent_cost_type= 'churn' )
# Out:
# Decision Threshold: 0.01, Test cost/loss = 1078198.38
# Decision Threshold: 0.02, Test cost/loss = 881075.70
# Decision Threshold: 0.03, Test cost/loss = 758119.96
# Decision Threshold: 0.04, Test cost/loss = 661239.60
# Decision Threshold: 0.05, Test cost/loss = 603511.74
# Decision Threshold: 0.06, Test cost/loss = 538470.70
# Decision Threshold: 0.07, Test cost/loss = 497889.20
# Decision Threshold: 0.08, Test cost/loss = 457514.26
# Decision Threshold: 0.09, Test cost/loss = 424581.80
# Decision Threshold: 0.10, Test cost/loss = 398648.94
# Decision Threshold: 0.11, Test cost/loss = 377105.36
# Decision Threshold: 0.12, Test cost/loss = 358480.16
# Decision Threshold: 0.13, Test cost/loss = 342015.60
# Decision Threshold: 0.14, Test cost/loss = 326386.06
# Decision Threshold: 0.15, Test cost/loss = 309468.70
# Decision Threshold: 0.16, Test cost/loss = 300648.78
# Decision Threshold: 0.17, Test cost/loss = 291414.82
# Decision Threshold: 0.18, Test cost/loss = 279046.98
# Decision Threshold: 0.19, Test cost/loss = 261635.56
# Decision Threshold: 0.20, Test cost/loss = 255911.62
# Decision Threshold: 0.21, Test cost/loss = 250321.80
# Decision Threshold: 0.22, Test cost/loss = 242642.92
# Decision Threshold: 0.23, Test cost/loss = 236447.20
# Decision Threshold: 0.24, Test cost/loss = 229564.60
# Decision Threshold: 0.25, Test cost/loss = 222945.04
# Decision Threshold: 0.26, Test cost/loss = 219227.18
# Decision Threshold: 0.27, Test cost/loss = 212703.64
# Decision Threshold: 0.28, Test cost/loss = 207929.20
# Decision Threshold: 0.29, Test cost/loss = 201770.96
# Decision Threshold: 0.30, Test cost/loss = 197484.22
# Decision Threshold: 0.31, Test cost/loss = 195062.36
# Decision Threshold: 0.32, Test cost/loss = 192799.42
# Decision Threshold: 0.33, Test cost/loss = 187058.76
# Decision Threshold: 0.34, Test cost/loss = 183240.26
# Decision Threshold: 0.35, Test cost/loss = 179077.08
# Decision Threshold: 0.36, Test cost/loss = 174864.18
# Decision Threshold: 0.37, Test cost/loss = 169526.82
# Decision Threshold: 0.38, Test cost/loss = 165094.84
# Decision Threshold: 0.39, Test cost/loss = 163666.20
# Decision Threshold: 0.40, Test cost/loss = 160732.76
# Decision Threshold: 0.41, Test cost/loss = 158589.86
# Decision Threshold: 0.42, Test cost/loss = 165595.02
# Decision Threshold: 0.43, Test cost/loss = 161627.20
# Decision Threshold: 0.44, Test cost/loss = 175303.86
# Decision Threshold: 0.45, Test cost/loss = 174108.78
# Decision Threshold: 0.46, Test cost/loss = 172337.66
# Decision Threshold: 0.47, Test cost/loss = 168843.12
# Decision Threshold: 0.48, Test cost/loss = 162514.06
# Decision Threshold: 0.49, Test cost/loss = 171435.84
# Decision Threshold: 0.50, Test cost/loss = 170712.34
# Decision Threshold: 0.51, Test cost/loss = 165753.04
# Decision Threshold: 0.52, Test cost/loss = 161056.44
# Decision Threshold: 0.53, Test cost/loss = 157841.52
# Decision Threshold: 0.54, Test cost/loss = 156465.90
# Decision Threshold: 0.55, Test cost/loss = 154970.16
# Decision Threshold: 0.56, Test cost/loss = 154464.14
# Decision Threshold: 0.57, Test cost/loss = 152663.70
# Decision Threshold: 0.58, Test cost/loss = 148529.42
# Decision Threshold: 0.59, Test cost/loss = 145537.94
# Decision Threshold: 0.60, Test cost/loss = 144508.00
# Decision Threshold: 0.61, Test cost/loss = 142497.52
# Decision Threshold: 0.62, Test cost/loss = 149453.10
# Decision Threshold: 0.63, Test cost/loss = 147686.94
# Decision Threshold: 0.64, Test cost/loss = 147510.40
# Decision Threshold: 0.65, Test cost/loss = 151593.06
# Decision Threshold: 0.66, Test cost/loss = 151559.32
# Decision Threshold: 0.67, Test cost/loss = 151029.96
# Decision Threshold: 0.68, Test cost/loss = 148370.98
# Decision Threshold: 0.69, Test cost/loss = 145792.72
# Decision Threshold: 0.70, Test cost/loss = 147456.52
# Decision Threshold: 0.71, Test cost/loss = 146383.34
# Decision Threshold: 0.72, Test cost/loss = 145221.08
# Decision Threshold: 0.73, Test cost/loss = 140102.42
# Decision Threshold: 0.74, Test cost/loss = 139081.06
# Decision Threshold: 0.75, Test cost/loss = 138646.56
# Decision Threshold: 0.76, Test cost/loss = 136267.26
# Decision Threshold: 0.77, Test cost/loss = 134014.48
# Decision Threshold: 0.78, Test cost/loss = 134014.48
# Decision Threshold: 0.79, Test cost/loss = 132304.56
# Decision Threshold: 0.80, Test cost/loss = 126942.70
# Decision Threshold: 0.81, Test cost/loss = 126942.70
# Decision Threshold: 0.82, Test cost/loss = 125278.48
# Decision Threshold: 0.83, Test cost/loss = 124144.20
# Decision Threshold: 0.84, Test cost/loss = 120302.62
# Decision Threshold: 0.85, Test cost/loss = 119859.02
# Decision Threshold: 0.86, Test cost/loss = 126905.92
# Decision Threshold: 0.87, Test cost/loss = 134600.64
# Decision Threshold: 0.88, Test cost/loss = 128016.26
# Decision Threshold: 0.89, Test cost/loss = 123430.88
# Decision Threshold: 0.90, Test cost/loss = 120909.04
# Decision Threshold: 0.91, Test cost/loss = 124978.12
# Decision Threshold: 0.92, Test cost/loss = 123300.14
# Decision Threshold: 0.93, Test cost/loss = 120928.36
# Decision Threshold: 0.94, Test cost/loss = 117965.26
# Decision Threshold: 0.95, Test cost/loss = 127320.70
# Decision Threshold: 0.96, Test cost/loss = 136485.16
# Decision Threshold: 0.97, Test cost/loss = 141535.66
# Decision Threshold: 0.98, Test cost/loss = 156154.58
# Decision Threshold: 0.99, Test cost/loss = 153520.86
# Best Decision Threshold: 0.94, Lowest Test cost/loss = 117965.26, Lowest AMC = 8.72

# %% [markdown]
# # e- amc metric

# %%
test_predictions_log_churn = add_eap_ep(
    train=train, 
    test=test_predictions_log_churn, 
    y_col_name=y, 
    best_pipeline=best_pipeline_log_reg, 
    cb_column=cb_column, 
    predicted_proba_col_name='y_predicted_proba_log', 
    churn_label= 1.0, 
    instance_dependent_cost_type="churn")
test_predictions_xgb_churn = add_eap_ep(
    train=train, 
    test=test_predictions_xgb_churn, 
    y_col_name=y, 
    best_pipeline=best_pipeline_xgb, 
    cb_column=cb_column, 
    predicted_proba_col_name="y_predicted_proba_xgb", 
    churn_label=1.0, 
    instance_dependent_cost_type="churn")
# Out:
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:329: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_0['EAP'] = test_actual_label_0[predicted_proba_col_name]*test_actual_label_0['FP'] + \
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:331: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_0['EP'] = estimated_p_1*test_actual_label_0['FP']+estimated_p_0*test_actual_label_0['TN']
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:333: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_1['EAP'] = test_actual_label_1[predicted_proba_col_name]*test_actual_label_1['TP'] + \
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:335: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_1['EP'] = estimated_p_1 * test_actual_label_1['TP'] + estimated_p_0 * test_actual_label_1['FN']
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:329: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_0['EAP'] = test_actual_label_0[predicted_proba_col_name]*test_actual_label_0['FP'] + \
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:331: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_0['EP'] = estimated_p_1*test_actual_label_0['FP']+estimated_p_0*test_actual_label_0['TN']
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:333: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_1['EAP'] = test_actual_label_1[predicted_proba_col_name]*test_actual_label_1['TP'] + \
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:335: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_1['EP'] = estimated_p_1 * test_actual_label_1['TP'] + estimated_p_0 * test_actual_label_1['FN']

# %%
print(test_predictions_log_churn['EAP'].sum())
print(test_predictions_log_churn['EP'].sum())


print('EAP : ', test_predictions_log_churn['EAP'].sum()/len(test_predictions_log_churn))
print('EP : ', test_predictions_log_churn['EP'].sum()/len(test_predictions_log_churn))
# Out:
# 762362.5823217805
# 330540.7564985855
# EAP :  56.383594580414204
# EP :  24.446472635055507

# %%
print(test_predictions_xgb_churn['EAP'].sum())
print(test_predictions_xgb_churn['EP'].sum())


print('EAP : ', test_predictions_xgb_churn['EAP'].sum()/len(test_predictions_xgb_churn))
print('EP : ', test_predictions_xgb_churn['EP'].sum()/len(test_predictions_xgb_churn))
# Out:
# 228314.1518282724
# 330540.7564985855
# EAP :  16.885892450874373
# EP :  24.446472635055507

# %% [markdown]
# # mp at 50% threshold

# %%
test_predictions_log_churn_2 = test.copy(deep=True)
test_predictions_log_churn_2["y_predicted"] = best_pipeline_log_reg.predict(test_predictions_log_churn_2.drop(y, axis=1))
test_predictions_log_churn_2["churn_encoded"] = fit_le.transform(test_predictions_log_churn_2["is_fraud"])

# First check if customers have multiple rows => if so check if we can take other if this instance-based cost
impute = SimpleImputer(strategy='median')
test_predictions_log_churn_2['A'] = impute.fit_transform(
    (test_predictions_log_churn_2["amt"]).to_frame())[:, 0]
# Step 3: Apply the function to calculate the cost for each instance and create the instance-dependent cost matrix
test_predictions_log_churn_2['instance_cost'] = test_predictions_log_churn_2.apply(lambda row: instance_dependent_cost_churn_2(
    row['y_predicted'], row["churn_encoded"], row["A"]), axis=1)

test_predictions_log_churn_2["y_predicted_decoded"] = fit_le.inverse_transform(
    test_predictions_log_churn_2["y_predicted"])

# Print the DataFrame with the instance-dependent cost matrix
test_predictions_log_churn_2[['is_fraud', 'y_predicted_decoded', "A", 'instance_cost']]

print(f"Test cost/loss = {test_predictions_log_churn_2['instance_cost'].sum():.0f}.")
print(' total cost/loss average : ' , test_predictions_log_churn_2['instance_cost'].sum()/len(test_predictions_log_churn_2))
# Out:
# Test cost/loss = -542766.
#  total cost/loss average :  -40.14246431476962

# %%
test_predictions_xgb_churn_2 = test.copy(deep=True)
test_predictions_xgb_churn_2["y_predicted"] = best_pipeline_xgb.predict(test_predictions_xgb_churn_2.drop(y, axis=1))
test_predictions_xgb_churn_2["churn_encoded"] = fit_le.transform(test_predictions_xgb_churn_2["is_fraud"])

# First check if customers have multiple rows => if so check if we can take other if this instance-based cost
impute = SimpleImputer(strategy='median')
test_predictions_xgb_churn_2['A'] = impute.fit_transform(
    (test_predictions_xgb_churn_2["amt"]).to_frame())[:, 0]

# Step 3: Apply the function to calculate the cost for each instance and create the instance-dependent cost matrix
test_predictions_xgb_churn_2['instance_cost'] = test_predictions_xgb_churn_2.apply(lambda row: instance_dependent_cost_churn_2(
    row['y_predicted'], row["churn_encoded"], row["A"]), axis=1)

test_predictions_xgb_churn_2["y_predicted_decoded"] = fit_le.inverse_transform(
    test_predictions_xgb_churn_2["y_predicted"])

# Print the DataFrame with the instance-dependent cost matrix
test_predictions_xgb_churn_2[['is_fraud', 'y_predicted_decoded', "A", 'instance_cost']]

print(f"Test cost/loss = {test_predictions_xgb_churn_2['instance_cost'].sum():.0f}.")
# Out:
# Test cost/loss = -124546.

# %%
test_predictions_xgb_churn_2
# Out:
#                   cc_num        category     amt gender state  city_pop  \
# 377359  3540210836308425     food_dining   62.63      M    TX        53
# 343471      639030014711   entertainment   67.01      M    IL       639
# 858312   377264520876399   personal_care   17.55      F    SC      4424
# 653694   213157767990030  health_fitness   32.14      F    WY     27971
# 485688    30408301059761       kids_pets   68.74      M    SC      4471
# ...                  ...             ...     ...    ...   ...       ...
# 681119  3597926034019603        misc_pos  103.97      M    TN      9496
# 216844  2254917871818484    shopping_net    1.92      F    MD       313
# 6122    3586955669388457    shopping_pos  137.68      M    PA      1770
# 37347   3559160581764413   entertainment   85.12      M    NY      1453
# 80760       676369110710   entertainment    4.49      M    MI     75830
#
#                                     job   unix_time  is_fraud     lat_x  \
# 377359                Fisheries officer  1384536888         0  0.386883
# 343471              Mechanical engineer  1383260389         0  0.374299
# 858312                           Lawyer  1355689325         0 -0.370872
# 653694                  Music therapist  1349466301         0  0.539446
# 485688           Occupational hygienist  1343748738         0 -0.025769
# ...                                 ...         ...       ...       ...
# 681119   Furniture conservator/restorer  1350504417         0  0.012908
# 216844            Insurance underwriter  1334945628         0  0.539784
# 6122    Administrator, local government  1371946103         0  0.724015
# 37347                      Toxicologist  1327246546         0  0.139454
# 80760              Engineer, automotive  1329495958         0 -0.003317
#
#           long_y     lat_z  merch_lat_x  merch_long_y  merch_lat_z  \
# 377359  0.903359 -0.185107     0.974763      0.171631    -0.142757
# 343471 -0.790767 -0.484343    -0.101118     -0.751755    -0.651644
# 858312 -0.903818  0.213464    -0.117634     -0.817296    -0.564083
# 653694  0.478639 -0.692750    -0.001038     -0.002552    -0.999996
# 485688 -0.341624  0.939483     0.190030     -0.354266     0.915633
# ...          ...       ...          ...           ...          ...
# 681119  0.786576 -0.617359    -0.060673     -0.039846    -0.997362
# 216844 -0.753990  0.374343     0.405536     -0.876989     0.257743
# 6122   -0.517629  0.455919     0.874663      0.283635    -0.393084
# 37347  -0.020347 -0.990020     0.236203     -0.099020    -0.966645
# 80760  -0.085231 -0.996356     0.553350      0.336696    -0.761866
#
#         y_predicted  churn_encoded       A  instance_cost  y_predicted_decoded
# 377359            0              0   62.63            0.0                    0
# 343471            0              0   67.01            0.0                    0
# 858312            0              0   17.55            0.0                    0
# 653694            0              0   32.14            0.0                    0
# 485688            0              0   68.74            0.0                    0
# ...             ...            ...     ...            ...                  ...
# 681119            0              0  103.97            0.0                    0
# 216844            0              0    1.92            0.0                    0
# 6122              0              0  137.68            0.0                    0
# 37347             0              0   85.12            0.0                    0
# 80760             0              0    4.49            0.0                    0
#
# [13521 rows x 20 columns]

# %% [markdown]
# # MP metric

# %%
cb_column = 'A'
test_predictions_log_churn_2['y_predicted_proba_log']= best_pipeline_log_reg.predict_proba(test_predictions_log_churn_2.drop(y, axis=1))[:, 1]
best_threshold_log, AMC_log, lowest_cost_log = compute_best_threshold_2(test_predictions_log_churn_2, best_pipeline_log_reg, y,cb_column, y_predicted_proba_col_name="y_predicted_proba_log", instance_dependent_cost_type = 'churn_2')
# Out:
# Decision Threshold: 0.01, Test cost/loss = -1742044.86
# Decision Threshold: 0.02, Test cost/loss = -1697304.64
# Decision Threshold: 0.03, Test cost/loss = -1660640.80
# Decision Threshold: 0.04, Test cost/loss = -1626085.28
# Decision Threshold: 0.05, Test cost/loss = -1592703.60
# Decision Threshold: 0.06, Test cost/loss = -1566376.54
# Decision Threshold: 0.07, Test cost/loss = -1537444.56
# Decision Threshold: 0.08, Test cost/loss = -1513621.98
# Decision Threshold: 0.09, Test cost/loss = -1490143.00
# Decision Threshold: 0.10, Test cost/loss = -1465778.70
# Decision Threshold: 0.11, Test cost/loss = -1449063.42
# Decision Threshold: 0.12, Test cost/loss = -1428937.94
# Decision Threshold: 0.13, Test cost/loss = -1406340.86
# Decision Threshold: 0.14, Test cost/loss = -1380323.22
# Decision Threshold: 0.15, Test cost/loss = -1355761.04
# Decision Threshold: 0.16, Test cost/loss = -1328646.10
# Decision Threshold: 0.17, Test cost/loss = -1300459.34
# Decision Threshold: 0.18, Test cost/loss = -1273280.84
# Decision Threshold: 0.19, Test cost/loss = -1249245.58
# Decision Threshold: 0.20, Test cost/loss = -1222964.36
# Decision Threshold: 0.21, Test cost/loss = -1197822.48
# Decision Threshold: 0.22, Test cost/loss = -1176345.66
# Decision Threshold: 0.23, Test cost/loss = -1155838.62
# Decision Threshold: 0.24, Test cost/loss = -1129772.30
# Decision Threshold: 0.25, Test cost/loss = -1108084.36
# Decision Threshold: 0.26, Test cost/loss = -1090347.50
# Decision Threshold: 0.27, Test cost/loss = -1067197.36
# Decision Threshold: 0.28, Test cost/loss = -1044547.24
# Decision Threshold: 0.29, Test cost/loss = -1024208.30
# Decision Threshold: 0.30, Test cost/loss = -999087.22
# Decision Threshold: 0.31, Test cost/loss = -974831.54
# Decision Threshold: 0.32, Test cost/loss = -951384.98
# Decision Threshold: 0.33, Test cost/loss = -928499.80
# Decision Threshold: 0.34, Test cost/loss = -905407.08
# Decision Threshold: 0.35, Test cost/loss = -884189.56
# Decision Threshold: 0.36, Test cost/loss = -862654.42
# Decision Threshold: 0.37, Test cost/loss = -838590.12
# Decision Threshold: 0.38, Test cost/loss = -816047.76
# Decision Threshold: 0.39, Test cost/loss = -792125.96
# Decision Threshold: 0.40, Test cost/loss = -768652.66
# Decision Threshold: 0.41, Test cost/loss = -742757.14
# Decision Threshold: 0.42, Test cost/loss = -714415.96
# Decision Threshold: 0.43, Test cost/loss = -692310.40
# Decision Threshold: 0.44, Test cost/loss = -669576.50
# Decision Threshold: 0.45, Test cost/loss = -646388.10
# Decision Threshold: 0.46, Test cost/loss = -625744.94
# Decision Threshold: 0.47, Test cost/loss = -602790.00
# Decision Threshold: 0.48, Test cost/loss = -581767.46
# Decision Threshold: 0.49, Test cost/loss = -560964.28
# Decision Threshold: 0.50, Test cost/loss = -542766.26
# Decision Threshold: 0.51, Test cost/loss = -524638.72
# Decision Threshold: 0.52, Test cost/loss = -504547.52
# Decision Threshold: 0.53, Test cost/loss = -485425.22
# Decision Threshold: 0.54, Test cost/loss = -469805.60
# Decision Threshold: 0.55, Test cost/loss = -453147.68
# Decision Threshold: 0.56, Test cost/loss = -439340.24
# Decision Threshold: 0.57, Test cost/loss = -424512.10
# Decision Threshold: 0.58, Test cost/loss = -412918.22
# Decision Threshold: 0.59, Test cost/loss = -406791.16
# Decision Threshold: 0.60, Test cost/loss = -397207.92
# Decision Threshold: 0.61, Test cost/loss = -381930.34
# Decision Threshold: 0.62, Test cost/loss = -371047.12
# Decision Threshold: 0.63, Test cost/loss = -359330.92
# Decision Threshold: 0.64, Test cost/loss = -346872.02
# Decision Threshold: 0.65, Test cost/loss = -333211.00
# Decision Threshold: 0.66, Test cost/loss = -324769.04
# Decision Threshold: 0.67, Test cost/loss = -316659.90
# Decision Threshold: 0.68, Test cost/loss = -304847.44
# Decision Threshold: 0.69, Test cost/loss = -296569.82
# Decision Threshold: 0.70, Test cost/loss = -290770.30
# Decision Threshold: 0.71, Test cost/loss = -283599.16
# Decision Threshold: 0.72, Test cost/loss = -275693.84
# Decision Threshold: 0.73, Test cost/loss = -274199.90
# Decision Threshold: 0.74, Test cost/loss = -263152.24
# Decision Threshold: 0.75, Test cost/loss = -253832.50
# Decision Threshold: 0.76, Test cost/loss = -252185.02
# Decision Threshold: 0.77, Test cost/loss = -246660.40
# Decision Threshold: 0.78, Test cost/loss = -241919.50
# Decision Threshold: 0.79, Test cost/loss = -232657.42
# Decision Threshold: 0.80, Test cost/loss = -231495.54
# Decision Threshold: 0.81, Test cost/loss = -234012.78
# Decision Threshold: 0.82, Test cost/loss = -233332.16
# Decision Threshold: 0.83, Test cost/loss = -231670.12
# Decision Threshold: 0.84, Test cost/loss = -242138.38
# Decision Threshold: 0.85, Test cost/loss = -237073.84
# Decision Threshold: 0.86, Test cost/loss = -242596.94
# Decision Threshold: 0.87, Test cost/loss = -236967.26
# Decision Threshold: 0.88, Test cost/loss = -232454.16
# Decision Threshold: 0.89, Test cost/loss = -232722.32
# Decision Threshold: 0.90, Test cost/loss = -235279.16
# Decision Threshold: 0.91, Test cost/loss = -230433.76
# Decision Threshold: 0.92, Test cost/loss = -224383.14
# Decision Threshold: 0.93, Test cost/loss = -230515.74
# Decision Threshold: 0.94, Test cost/loss = -224959.76
# Decision Threshold: 0.95, Test cost/loss = -216154.64
# Decision Threshold: 0.96, Test cost/loss = -209446.34
# Decision Threshold: 0.97, Test cost/loss = -210357.64
# Decision Threshold: 0.98, Test cost/loss = -217407.26
# Decision Threshold: 0.99, Test cost/loss = -235471.92
# Best Decision Threshold: 0.96, Lowest Test cost/loss = -209446.34, Lowest AMC = -15.49

# %%
test_predictions_xgb_churn_2['y_predicted_proba_xgb']= best_pipeline_xgb.predict_proba(test_predictions_xgb_churn_2.drop(y, axis=1))[:, 1]
best_threshold_xgb, AMC_xgb, lowest_cost_xgb = compute_best_threshold_2(test_predictions_xgb_churn_2, best_pipeline_xgb, y, cb_column, y_predicted_proba_col_name="y_predicted_proba_xgb", instance_dependent_cost_type= 'churn_2' )
# Out:
# Decision Threshold: 0.01, Test cost/loss = -1024517.68
# Decision Threshold: 0.02, Test cost/loss = -827452.90
# Decision Threshold: 0.03, Test cost/loss = -704535.84
# Decision Threshold: 0.04, Test cost/loss = -607736.88
# Decision Threshold: 0.05, Test cost/loss = -550030.46
# Decision Threshold: 0.06, Test cost/loss = -484989.42
# Decision Threshold: 0.07, Test cost/loss = -445022.34
# Decision Threshold: 0.08, Test cost/loss = -404647.40
# Decision Threshold: 0.09, Test cost/loss = -371714.94
# Decision Threshold: 0.10, Test cost/loss = -345782.08
# Decision Threshold: 0.11, Test cost/loss = -324238.50
# Decision Threshold: 0.12, Test cost/loss = -305613.30
# Decision Threshold: 0.13, Test cost/loss = -289191.66
# Decision Threshold: 0.14, Test cost/loss = -273580.12
# Decision Threshold: 0.15, Test cost/loss = -256662.76
# Decision Threshold: 0.16, Test cost/loss = -247842.84
# Decision Threshold: 0.17, Test cost/loss = -238608.88
# Decision Threshold: 0.18, Test cost/loss = -226241.04
# Decision Threshold: 0.19, Test cost/loss = -208829.62
# Decision Threshold: 0.20, Test cost/loss = -203105.68
# Decision Threshold: 0.21, Test cost/loss = -198271.16
# Decision Threshold: 0.22, Test cost/loss = -190592.28
# Decision Threshold: 0.23, Test cost/loss = -184396.56
# Decision Threshold: 0.24, Test cost/loss = -177513.96
# Decision Threshold: 0.25, Test cost/loss = -170894.40
# Decision Threshold: 0.26, Test cost/loss = -167176.54
# Decision Threshold: 0.27, Test cost/loss = -160653.00
# Decision Threshold: 0.28, Test cost/loss = -155878.56
# Decision Threshold: 0.29, Test cost/loss = -149720.32
# Decision Threshold: 0.30, Test cost/loss = -145433.58
# Decision Threshold: 0.31, Test cost/loss = -143011.72
# Decision Threshold: 0.32, Test cost/loss = -140748.78
# Decision Threshold: 0.33, Test cost/loss = -135027.74
# Decision Threshold: 0.34, Test cost/loss = -131209.24
# Decision Threshold: 0.35, Test cost/loss = -127046.06
# Decision Threshold: 0.36, Test cost/loss = -122833.16
# Decision Threshold: 0.37, Test cost/loss = -117523.80
# Decision Threshold: 0.38, Test cost/loss = -113091.82
# Decision Threshold: 0.39, Test cost/loss = -111663.18
# Decision Threshold: 0.40, Test cost/loss = -108729.74
# Decision Threshold: 0.41, Test cost/loss = -106586.84
# Decision Threshold: 0.42, Test cost/loss = -115139.10
# Decision Threshold: 0.43, Test cost/loss = -111171.28
# Decision Threshold: 0.44, Test cost/loss = -127424.52
# Decision Threshold: 0.45, Test cost/loss = -126229.44
# Decision Threshold: 0.46, Test cost/loss = -124458.32
# Decision Threshold: 0.47, Test cost/loss = -120963.78
# Decision Threshold: 0.48, Test cost/loss = -114634.72
# Decision Threshold: 0.49, Test cost/loss = -125269.10
# Decision Threshold: 0.50, Test cost/loss = -124545.60
# Decision Threshold: 0.51, Test cost/loss = -119586.30
# Decision Threshold: 0.52, Test cost/loss = -114889.70
# Decision Threshold: 0.53, Test cost/loss = -111674.78
# Decision Threshold: 0.54, Test cost/loss = -110299.16
# Decision Threshold: 0.55, Test cost/loss = -108803.42
# Decision Threshold: 0.56, Test cost/loss = -108297.40
# Decision Threshold: 0.57, Test cost/loss = -106496.96
# Decision Threshold: 0.58, Test cost/loss = -102362.68
# Decision Threshold: 0.59, Test cost/loss = -99371.20
# Decision Threshold: 0.60, Test cost/loss = -98341.26
# Decision Threshold: 0.61, Test cost/loss = -96330.78
# Decision Threshold: 0.62, Test cost/loss = -104534.14
# Decision Threshold: 0.63, Test cost/loss = -102767.98
# Decision Threshold: 0.64, Test cost/loss = -102591.44
# Decision Threshold: 0.65, Test cost/loss = -107763.68
# Decision Threshold: 0.66, Test cost/loss = -107729.94
# Decision Threshold: 0.67, Test cost/loss = -107200.58
# Decision Threshold: 0.68, Test cost/loss = -104541.60
# Decision Threshold: 0.69, Test cost/loss = -101963.34
# Decision Threshold: 0.70, Test cost/loss = -104255.86
# Decision Threshold: 0.71, Test cost/loss = -103182.68
# Decision Threshold: 0.72, Test cost/loss = -102020.42
# Decision Threshold: 0.73, Test cost/loss = -96901.76
# Decision Threshold: 0.74, Test cost/loss = -95880.40
# Decision Threshold: 0.75, Test cost/loss = -95445.90
# Decision Threshold: 0.76, Test cost/loss = -93066.60
# Decision Threshold: 0.77, Test cost/loss = -90813.82
# Decision Threshold: 0.78, Test cost/loss = -90813.82
# Decision Threshold: 0.79, Test cost/loss = -89103.90
# Decision Threshold: 0.80, Test cost/loss = -83742.04
# Decision Threshold: 0.81, Test cost/loss = -83742.04
# Decision Threshold: 0.82, Test cost/loss = -82077.82
# Decision Threshold: 0.83, Test cost/loss = -80943.54
# Decision Threshold: 0.84, Test cost/loss = -77101.96
# Decision Threshold: 0.85, Test cost/loss = -76658.36
# Decision Threshold: 0.86, Test cost/loss = -85150.62
# Decision Threshold: 0.87, Test cost/loss = -94880.68
# Decision Threshold: 0.88, Test cost/loss = -88296.30
# Decision Threshold: 0.89, Test cost/loss = -83710.92
# Decision Threshold: 0.90, Test cost/loss = -81189.08
# Decision Threshold: 0.91, Test cost/loss = -85936.34
# Decision Threshold: 0.92, Test cost/loss = -84258.36
# Decision Threshold: 0.93, Test cost/loss = -81886.58
# Decision Threshold: 0.94, Test cost/loss = -78923.48
# Decision Threshold: 0.95, Test cost/loss = -89838.16
# Decision Threshold: 0.96, Test cost/loss = -100841.52
# Decision Threshold: 0.97, Test cost/loss = -107030.20
# Decision Threshold: 0.98, Test cost/loss = -124596.48
# Decision Threshold: 0.99, Test cost/loss = -124888.80
# Best Decision Threshold: 0.85, Lowest Test cost/loss = -76658.36, Lowest AMC = -5.67

# %% [markdown]
# # E-MP metric

# %%
test_predictions_log_churn_2 = add_eap_ep(
    train=train, 
    test=test_predictions_log_churn_2, 
    y_col_name=y, 
    best_pipeline=best_pipeline_log_reg, 
    cb_column=cb_column, 
    predicted_proba_col_name='y_predicted_proba_log', 
    churn_label= 1.0, 
    instance_dependent_cost_type="churn_2")
test_predictions_xgb_churn_2 = add_eap_ep(
    train=train, 
    test=test_predictions_xgb_churn_2, 
    y_col_name=y, 
    best_pipeline=best_pipeline_xgb, 
    cb_column=cb_column, 
    predicted_proba_col_name="y_predicted_proba_xgb", 
    churn_label=1.0, 
    instance_dependent_cost_type="churn_2")
# Out:
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:329: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_0['EAP'] = test_actual_label_0[predicted_proba_col_name]*test_actual_label_0['FP'] + \
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:331: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_0['EP'] = estimated_p_1*test_actual_label_0['FP']+estimated_p_0*test_actual_label_0['TN']
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:333: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_1['EAP'] = test_actual_label_1[predicted_proba_col_name]*test_actual_label_1['TP'] + \
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:335: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_1['EP'] = estimated_p_1 * test_actual_label_1['TP'] + estimated_p_0 * test_actual_label_1['FN']
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:329: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_0['EAP'] = test_actual_label_0[predicted_proba_col_name]*test_actual_label_0['FP'] + \
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:331: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_0['EP'] = estimated_p_1*test_actual_label_0['FP']+estimated_p_0*test_actual_label_0['TN']
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:333: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_1['EAP'] = test_actual_label_1[predicted_proba_col_name]*test_actual_label_1['TP'] + \
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:335: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_1['EP'] = estimated_p_1 * test_actual_label_1['TP'] + estimated_p_0 * test_actual_label_1['FN']

# %%
print(test_predictions_log_churn_2['EAP'].sum())
print(test_predictions_log_churn_2['EP'].sum())


print('EAP : ', test_predictions_log_churn_2['EAP'].sum()/len(test_predictions_log_churn_2))
print('EP : ', test_predictions_log_churn_2['EP'].sum()/len(test_predictions_log_churn_2))
# Out:
# -711843.380813064
# -330237.0214677984
# EAP :  -52.647243607208345
# EP :  -24.424008687804037

# %%
print(test_predictions_xgb_churn_2['EAP'].sum())
print(test_predictions_xgb_churn_2['EP'].sum())


print('EAP : ', test_predictions_xgb_churn_2['EAP'].sum()/len(test_predictions_xgb_churn_2))
print('EP : ', test_predictions_xgb_churn_2['EP'].sum()/len(test_predictions_xgb_churn_2))
# Out:
# -181357.1203384911
# -330237.0214677984
# EAP :  -13.412996105206057
# EP :  -24.424008687804037

# %% [markdown]
# # cost curves

# %%
total_fp_log_2 = 0

for i in range(0,13521):
    if test_predictions_log_churn['churn_encoded'].iloc[i] == 0 and test_predictions_log_churn['y_predicted'].iloc[i]==1:
        total_fp_log_2 += test_predictions_log_churn['FP'].iloc[i]
    else:
        total_fp_log_2 += 0

print(total_fp_log_2)

average_fp_log_2 = total_fp_log_2/13521
print( average_fp_log_2)
# Out:
# 197001.34000000008
# 14.570027364839884

# %%
total_fn_log_2 = 0

for i in range(0,13521):
    if test_predictions_log_churn['churn_encoded'].iloc[i] == 1 and test_predictions_log_churn['y_predicted'].iloc[i]==0:
        total_fn_log_2 += test_predictions_log_churn['FN'].iloc[i]
    else:
        total_fn_log_2 += 0

print(total_fn_log_2)

average_fn_log_2 = total_fn_log_2/13521
print( average_fn_log_2)
# Out:
# 10246.8
# 0.757843354781451

# %%
cost_fn_log_2 = average_fn_log_2
# C(+|-)
cost_fp_log_2 = average_fp_log_2

# Ground truth
truth = test_predictions_log_churn['churn_encoded']
#  <a list of 0 (negative class) or 1 (positive class)>
# Predictions from a classifier
score = test_predictions_log_churn['y_predicted']
# best_pipeline_log_reg.predict_proba(test.drop(y_encoded_col_name, axis=1))[:, 1]
# <a list of [0,1] class probabilities>

# %% OUTPUTS

# 1D-array of x-axis values (normalized PC)
pc = None
# list of lines as (slope, intercept)
lines = []
# lower envelope of the list of lines as a 1D-array of y-axis values (NEC)
lower_envelope = []
# area under the lower envelope (the smaller, the better)
area = None

# %% COMPUTATION

# points from the roc curve, because a point in the ROC space <=> a line in the cost space
roc_fpr, roc_tpr, _ = roc_curve(truth, score)

# compute the normalized p(+)*C(-|+)
thresholds = np.arange(0, 1.01, .01)
pc = (thresholds*cost_fn_log_2) / (thresholds*cost_fn_log_2 + (1-thresholds)*cost_fp_log_2)

# compute a line in the cost space for each point in the roc space
for fpr, tpr in zip(roc_fpr, roc_tpr):
    slope = (1-tpr-fpr)
    intercept = fpr
    lines.append((slope, intercept))

# compute the lower envelope
for x_value in pc:
    y_value = min([slope*x_value+intercept for slope, intercept in lines])
    lower_envelope.append(max(0, y_value))
lower_envelope = np.array(lower_envelope)

# compute the area under the lower envelope using the composite trapezoidal rule
area = np.trapz(lower_envelope, pc)

# %% EXAMPLE OF PLOT

# display each line as a thin dashed line
for slope, intercept in lines:
    plt.plot(pc, slope*pc+intercept, color="grey", lw=1, linestyle="--")

# display the lower envelope as a thicker black line
plt.plot(pc, lower_envelope, color="black", lw=3, label="area={:.3f}".format(area))

# plot parameters
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05*max(lower_envelope)])
plt.xlabel("Probability Cost Function")
plt.ylabel("Normalized Expected Cost")
plt.title("Cost curve")
plt.legend(loc="lower right")

plt.show()

# %%
total_fp_xgb_2 = 0

for i in range(0,13521):
    if test_predictions_xgb_churn['churn_encoded'].iloc[i] == 0 and test_predictions_xgb_churn['y_predicted'].iloc[i]==1:
        total_fp_xgb_2 += test_predictions_xgb_churn['FP'].iloc[i]
    else:
        total_fp_xgb_2 += 0

print(total_fp_xgb_2)

average_fp_xgb_2 = total_fp_xgb_2/13521
print( average_fp_xgb_2)
# Out:
# 129757.98000000003
# 9.596773907255383

# %%
total_fn_xgb_2 = 0

for i in range(0,13521):
    if test_predictions_xgb_churn['churn_encoded'].iloc[i] == 1 and test_predictions_xgb_churn['y_predicted'].iloc[i]==0:
        total_fn_xgb_2 += test_predictions_xgb_churn['FN'].iloc[i]
    else:
        total_fn_xgb_2 += 0

print(total_fn_xgb_2)

average_fn_xgb_2 = total_fn_xgb_2/13521
print( average_fn_xgb_2)
# Out:
# 17113.56
# 1.265702240958509

# %%
#C(-|+)
cost_fn_xgb_2 = average_fn_xgb_2
# C(+|-)
cost_fp_xgb_2 = average_fp_xgb_2

# Ground truth
truth = test_predictions_xgb_churn['churn_encoded']
#  <a list of 0 (negative class) or 1 (positive class)>
# Predictions from a classifier
score = test_predictions_xgb_churn['y_predicted']
# best_pipeline_log_reg.predict_proba(test.drop(y_encoded_col_name, axis=1))[:, 1]
# <a list of [0,1] class probabilities>

# %% OUTPUTS

# 1D-array of x-axis values (normalized PC)
pc = None
# list of lines as (slope, intercept)
lines = []
# lower envelope of the list of lines as a 1D-array of y-axis values (NEC)
lower_envelope = []
# area under the lower envelope (the smaller, the better)
area = None

# %% COMPUTATION

# points from the roc curve, because a point in the ROC space <=> a line in the cost space
roc_fpr, roc_tpr, _ = roc_curve(truth, score)

# compute the normalized p(+)*C(-|+)
thresholds = np.arange(0, 1.01, .01)
pc = (thresholds*cost_fn_xgb_2) / (thresholds*cost_fn_xgb_2 + (1-thresholds)*cost_fp_xgb_2)

# compute a line in the cost space for each point in the roc space
for fpr, tpr in zip(roc_fpr, roc_tpr):
    slope = (1-tpr-fpr)
    intercept = fpr
    lines.append((slope, intercept))

# compute the lower envelope
for x_value in pc:
    y_value = min([slope*x_value+intercept for slope, intercept in lines])
    lower_envelope.append(max(0, y_value))
lower_envelope = np.array(lower_envelope)

# compute the area under the lower envelope using the composite trapezoidal rule
area = np.trapz(lower_envelope, pc)

# %% EXAMPLE OF PLOT

# display each line as a thin dashed line
for slope, intercept in lines:
    plt.plot(pc, slope*pc+intercept, color="grey", lw=1, linestyle="--")

# display the lower envelope as a thicker black line
plt.plot(pc, lower_envelope, color="black", lw=3, label="area={:.3f}".format(area))

# plot parameters
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05*max(lower_envelope)])
plt.xlabel("Probability Cost Function")
plt.ylabel("Normalized Expected Cost")
plt.title("Cost curve")
plt.legend(loc="lower right")

plt.show()
