# %%
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from sklearn.metrics import roc_curve
import collections
from scipy.spatial import ConvexHull
from scipy.special import betainc
import scipy.special as ss
import sys

sys.path.append("../")

from src.common_functions import *

# %%
# sample data
# RAW_DATA_PATH1 = "../datasets/fraud/fraudTrain.csv"
# RAW_DATA_PATH2 = "../datasets/fraud/fraudTest.csv"
SAMPLED_DATA_PATH = "../datasets/fraud/cc_fraud_2.csv"
DATASET_NAME = Path(SAMPLED_DATA_PATH).stem
# raw_data1 = pd.read_csv("../datasets/fraud/fraudTrain.csv", index_col='Unnamed: 0')
# raw_data2 = pd.read_csv("../datasets/fraud/fraudTest.csv", index_col='Unnamed: 0')
# raw_data = pd.concat([raw_data1, raw_data2])
# raw_data = raw_data.rename(columns=dict(zip(raw_data.columns, list(map(to_snake_case, raw_data.columns)))))
# raw_data.head()
# _to_drop, df = train_test_split(raw_data, test_size=0.055, random_state=42, stratify=raw_data["is_fraud"])
# df.to_csv(SAMPLED_DATA_PATH, header=True, sep=",")
# del _to_drop
df = pd.read_csv(SAMPLED_DATA_PATH, index_col='Unnamed: 0')
print(df.shape[0])
df["is_fraud"].value_counts()/df.shape[0]*100
# Out:
# 101882
# is_fraud
# 0    99.478809
# 1     0.521191
# Name: count, dtype: float64

# %%
ratio = df["is_fraud"].value_counts()[0]/df["is_fraud"].value_counts()[1]
print(ratio)
# Out:
# 190.86817325800376

# %%
df["is_fraud"].value_counts()
# Out:
# is_fraud
# 0    101351
# 1       531
# Name: count, dtype: int64

# %%
df.isna().any()
# Out:
# trans_date_trans_time    False
# cc_num                   False
# merchant                 False
# category                 False
# amt                      False
# first                    False
# last                     False
# gender                   False
# street                   False
# city                     False
# state                    False
# zip                      False
# lat                      False
# long                     False
# city_pop                 False
# job                      False
# dob                      False
# trans_num                False
# unix_time                False
# merch_lat                False
# merch_long               False
# is_fraud                 False
# dtype: bool

# %%
numerical_columns = df.select_dtypes(
        include='number').columns.to_list()
numerical_columns
# Out:
# ['cc_num',
#  'amt',
#  'zip',
#  'lat',
#  'long',
#  'city_pop',
#  'unix_time',
#  'merch_lat',
#  'merch_long',
#  'is_fraud']

# %%
pd.set_option('display.max_columns', None)

df.head()
# Out:
#        trans_date_trans_time               cc_num                merchant  \
# 81955    2019-02-18 05:13:53       30442439074871   fraud_Prohaska-Murray
# 105389   2020-07-27 21:39:15  4599735407877245080    fraud_Crona and Sons
# 442525   2020-12-07 04:50:50      375848982312810  fraud_Erdman-Kertzmann
# 916621   2019-12-30 03:31:10      375237305371366        fraud_Sawayn PLC
# 117618   2019-03-07 18:03:51     4607072969078276    fraud_Abbott-Steuber
#
#              category     amt   first      last gender  \
# 81955   gas_transport   84.50   Linda   Sanchez      F
# 105389      kids_pets  141.70    Mary     Myers      F
# 442525  gas_transport   92.17    Dale     Smith      M
# 916621   shopping_pos    9.89   David  Erickson      M
# 117618  personal_care   13.98  Brenda     Perez      F
#
#                                     street            city state    zip  \
# 81955           6574 William Hill Apt. 375          Jermyn    PA  18433
# 105389         39787 Pamela Fall Suite 639     Tiptonville    TN  38079
# 442525  25036 Contreras Turnpike Suite 270         Purmela    TX  76566
# 916621         616 Jimenez Meadow Apt. 701  East Rochester    NY  14445
# 117618            033 Tara Brook Suite 523           Coyle    OK  73027
#
#             lat     long  city_pop                               job  \
# 81955   41.5744 -75.5881      6508  Training and development officer
# 105389  36.3846 -89.4649      5577                        Geochemist
# 442525  31.4841 -97.9903       258                      Web designer
# 916621  43.1128 -77.4906      8019                      Retail buyer
# 117618  35.8985 -97.2607      1493            Amenity horticulturist
#
#                dob                         trans_num   unix_time  merch_lat  \
# 81955   1981-06-22  e87d0600784494b1fa22cc39ee43a664  1329542033  41.415102
# 105389  1964-12-30  aa521d71ed29b262ed53702992785426  1374961155  35.532554
# 442525  1943-12-15  ebdbe410178c5365013842e9555aac59  1386391850  30.521008
# 916621  1928-06-26  ff86e07988b326802e76ef0db08dc994  1356838270  42.571261
# 117618  1985-03-21  bff6baa0a339d57d105bd587012d35a9  1331143431  36.858453
#
#         merch_long  is_fraud
# 81955   -74.742120         0
# 105389  -89.097033         0
# 442525  -97.837087         0
# 916621  -78.185175         0
# 117618  -97.334306         0

# %%
df.dtypes
# Out:
# trans_date_trans_time     object
# cc_num                     int64
# merchant                  object
# category                  object
# amt                      float64
# first                     object
# last                      object
# gender                    object
# street                    object
# city                      object
# state                     object
# zip                        int64
# lat                      float64
# long                     float64
# city_pop                   int64
# job                       object
# dob                       object
# trans_num                 object
# unix_time                  int64
# merch_lat                float64
# merch_long               float64
# is_fraud                   int64
# dtype: object

# %%
import numpy as np

def preprocess_lat_lon(df:pd.DataFrame, lat_col_name:str="latitude", lon_col_name:str="longitude") -> pd.DataFrame:
    """
    Preprocesses latitude and longitude columns.

    Parameters
    ----------
    df : pd.DataFrame
        The dataframe to preprocess.
    lat_col_name : str
        The name of the latitude column.
    lon_col_name : str
        The name of the longitude column.
        
    Returns
    -------
    pd.DataFrame
        The preprocessed dataframe.
    """
    # Convert to radians
    df[f"{lat_col_name}_x"] = np.cos(df[lat_col_name]) * np.cos(df[lon_col_name])
    df[f"{lon_col_name}_y"] = np.cos(df[lat_col_name]) * np.sin(df[lon_col_name])
    df[f"{lat_col_name}_z"] = np.sin(df[lat_col_name])
    return df.drop([lat_col_name, lon_col_name], axis=1)

# %%
y = "is_fraud"

# some generic cleaning
# Amt - amount of the transaction in local currency
# otherwise unrecognized cases in test set
counts = df.value_counts([y, "job"])
jobs_to_filter = counts[counts==1].reset_index()["job"].unique()
df = df.loc[~df.job.isin(jobs_to_filter)]

COLUMNS_TO_DROP = ["city", "trans_date_trans_time", "merchant", "first", "last", "street", "zip", "trans_num", "dob"]
assert df[y].isna().any() == False
raw_features = df.drop(COLUMNS_TO_DROP, axis=1)

raw_features = raw_features.transform(preprocess_lat_lon, lat_col_name="lat", lon_col_name="long")
raw_features = raw_features.transform(preprocess_lat_lon, lat_col_name="merch_lat", lon_col_name="merch_long")

# ML tuning
train, test = train_test_split(
    raw_features, test_size=0.2, random_state=0, stratify=df[[y, "job"]])

fit_le = LabelEncoder().fit(train[y])

# %%
train['is_fraud']
# Out:
# 206194     0
# 493703     0
# 159        0
# 1270652    0
# 703338     0
#           ..
# 157596     0
# 137950     0
# 1170743    0
# 262918     0
# 7781       0
# Name: is_fraud, Length: 54081, dtype: int64

# %%
class_weights = compute_class_weight(
                                        class_weight = "balanced",
                                        classes = np.unique(train['is_fraud']),
                                        y = train['is_fraud']                                                    
                                    )
class_weights = dict(zip(np.unique(train['is_fraud']), class_weights))
class_weights
# Out:
# {0: 0.5028451882845189, 1: 88.36764705882354}

# %%
class_weights_5 = [{0: 1, 1: 1}, {0: 1, 1: 5}, {0: 1, 1: 10}, {0: 1, 1: 20}]

# %%
pipeline = build_sklearn_pipeline(train, y, "logistic", LogisticRegression())
pipeline.fit(train.drop(y, axis=1), train[y])
print(Pipeline(pipeline.steps[:-1]).transform(train.drop(y, axis=1)).shape)
pipeline.predict(train.drop(y, axis=1))
# Out:
# (54081, 384)
# array([0, 0, 0, ..., 0, 0, 1], dtype=int64)

# %%
balance = [{0:100,1:1}, {0:10,1:1}, {0:1,1:1}, {0:1,1:10}, {0:1,1:100}]

# %%
param_grid = {
    'logistic__penalty': ['l2'],
    'logistic__C': [1, 10, 100, 1000],
    'pca__n_components': [10, 20,30],
    # 'under__sampling_strategy': [0.1, 0.2, 0.3, 0.5, 0.7, 1],
    # 'over__sampling_strategy': [0.2, 0.3, 0.4, 0.5, 0.7, 1]
    'logistic__class_weight': [{0: 0.5028451882845189, 1: 88.36764705882354}, {0:1,1:1}, {0:1,1:10}, {0:1,1:100}]
    # 'class_weight': ['balanced', {0: 1, 1: 5}]

}

# param_grid = {
#     'logistic__penalty': ['l2'],
#     'logistic__C': [10],
#     'pca__n_components': [10, 20,30],
#     # 'under__sampling_strategy': [0.1, 0.2, 0.3, 0.5, 0.7, 1],
#     # 'over__sampling_strategy': [0.2, 0.3, 0.4, 0.5, 0.7, 1]
#     'logistic__class_weight': [{0:1,1:10}]
#     # 'class_weight': ['balanced', {0: 1, 1: 5}]

# }

model = LogisticRegression()
# model = LogisticRegression(class_weight= class_weights)

MODEL_NAME = 'logistic'

grid = sklearn_gridsearch_using_pipeline(
    train, y_col_name=y, model=model, fit_le=fit_le, model_name='logistic', param_grid=param_grid, verbose=1,
    step_names_to_remove=['under', 'over'])

best_pipeline_log_reg = grid.best_estimator_
best_pipeline_log_reg
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# Best score: 0.8991547226405086
# Best parameters: {'logistic__C': 1000, 'logistic__class_weight': {0: 0.5028451882845189, 1: 88.36764705882354}, 'logistic__penalty': 'l2', 'pca__n_components': 30}
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('num_imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['cc_num', 'amt', 'city_pop',
#                                                    'unix_time', 'lat_x',
#                                                    'long_y', 'lat_z',
#                                                    'merch_lat_x',
#                                                    'merch_long_y',
#                                                    'merch_lat_z']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('cat_imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(sparse_output=False))]),
#                                                   ['category', 'gender',
#                                                    'state', 'job'])])),
#                 ('pca', PCA(n_components=30)),
#                 ('logistic',
#                  LogisticRegression(C=1000,
#                                     class_weight={0: 0.5028451882845189,
#                                                   1: 88.36764705882354}))])

# %%
write_pipeline(best_pipeline_log_reg, MODEL_NAME, DATASET_NAME)

# %%
COLUMNS = ["pca__n_components", "logistic__class_weight", f"{MODEL_NAME}__C", f"{MODEL_NAME}__penalty", "roc_auc_mean", "roc_auc_std"]

pd.concat([
    pd.DataFrame(grid.cv_results_["params"]),
    pd.DataFrame(grid.cv_results_["mean_test_score"], columns=["roc_auc_mean"]),
    pd.DataFrame(grid.cv_results_["std_test_score"], columns=["roc_auc_std"])
    ],axis=1).dropna(subset=["roc_auc_mean", "roc_auc_std"])[COLUMNS] #.sort_values(by=COLUMNS)
# Out:
#     pca__n_components                         logistic__class_weight  \
# 0                  10  {0: 0.5028451882845189, 1: 88.36764705882354}
# 1                  20  {0: 0.5028451882845189, 1: 88.36764705882354}
# 2                  30  {0: 0.5028451882845189, 1: 88.36764705882354}
# 3                  10                                   {0: 1, 1: 1}
# 4                  20                                   {0: 1, 1: 1}
# 5                  30                                   {0: 1, 1: 1}
# 6                  10                                  {0: 1, 1: 10}
# 7                  20                                  {0: 1, 1: 10}
# 8                  30                                  {0: 1, 1: 10}
# 9                  10                                 {0: 1, 1: 100}
# 10                 20                                 {0: 1, 1: 100}
# 11                 30                                 {0: 1, 1: 100}
# 12                 10  {0: 0.5028451882845189, 1: 88.36764705882354}
# 13                 20  {0: 0.5028451882845189, 1: 88.36764705882354}
# 14                 30  {0: 0.5028451882845189, 1: 88.36764705882354}
# 15                 10                                   {0: 1, 1: 1}
# 16                 20                                   {0: 1, 1: 1}
# 17                 30                                   {0: 1, 1: 1}
# 18                 10                                  {0: 1, 1: 10}
# 19                 20                                  {0: 1, 1: 10}
# 20                 30                                  {0: 1, 1: 10}
# 21                 10                                 {0: 1, 1: 100}
# 22                 20                                 {0: 1, 1: 100}
# 23                 30                                 {0: 1, 1: 100}
# 24                 10  {0: 0.5028451882845189, 1: 88.36764705882354}
# 25                 20  {0: 0.5028451882845189, 1: 88.36764705882354}
# 26                 30  {0: 0.5028451882845189, 1: 88.36764705882354}
# 27                 10                                   {0: 1, 1: 1}
# 28                 20                                   {0: 1, 1: 1}
# 29                 30                                   {0: 1, 1: 1}
# 30                 10                                  {0: 1, 1: 10}
# 31                 20                                  {0: 1, 1: 10}
# 32                 30                                  {0: 1, 1: 10}
# 33                 10                                 {0: 1, 1: 100}
# 34                 20                                 {0: 1, 1: 100}
# 35                 30                                 {0: 1, 1: 100}
# 36                 10  {0: 0.5028451882845189, 1: 88.36764705882354}
# 37                 20  {0: 0.5028451882845189, 1: 88.36764705882354}
# 38                 30  {0: 0.5028451882845189, 1: 88.36764705882354}
# 39                 10                                   {0: 1, 1: 1}
# 40                 20                                   {0: 1, 1: 1}
# 41                 30                                   {0: 1, 1: 1}
# 42                 10                                  {0: 1, 1: 10}
# 43                 20                                  {0: 1, 1: 10}
# 44                 30                                  {0: 1, 1: 10}
# 45                 10                                 {0: 1, 1: 100}
# 46                 20                                 {0: 1, 1: 100}
# 47                 30                                 {0: 1, 1: 100}
#
#     logistic__C logistic__penalty  roc_auc_mean  roc_auc_std
# 0             1                l2      0.845496     0.041389
# 1             1                l2      0.897923     0.023404
# 2             1                l2      0.898988     0.026941
# 3             1                l2      0.829932     0.040579
# 4             1                l2      0.803612     0.031063
# 5             1                l2      0.807050     0.042470
# 6             1                l2      0.853580     0.043879
# 7             1                l2      0.882339     0.027359
# 8             1                l2      0.874896     0.034002
# 9             1                l2      0.846042     0.041750
# 10            1                l2      0.895186     0.024433
# 11            1                l2      0.896241     0.027992
# 12           10                l2      0.845494     0.041389
# 13           10                l2      0.897942     0.023425
# 14           10                l2      0.898942     0.027282
# 15           10                l2      0.829680     0.040562
# 16           10                l2      0.801605     0.031904
# 17           10                l2      0.804833     0.043324
# 18           10                l2      0.853576     0.043886
# 19           10                l2      0.882525     0.027247
# 20           10                l2      0.874207     0.034877
# 21           10                l2      0.846038     0.041751
# 22           10                l2      0.895287     0.024374
# 23           10                l2      0.896158     0.027984
# 24          100                l2      0.845493     0.041389
# 25          100                l2      0.897943     0.023425
# 26          100                l2      0.899085     0.027047
# 27          100                l2      0.829656     0.040555
# 28          100                l2      0.801383     0.032050
# 29          100                l2      0.804099     0.044336
# 30          100                l2      0.853577     0.043886
# 31          100                l2      0.882453     0.027261
# 32          100                l2      0.874309     0.035108
# 33          100                l2      0.846038     0.041752
# 34          100                l2      0.895257     0.024374
# 35          100                l2      0.896334     0.028429
# 36         1000                l2      0.845493     0.041389
# 37         1000                l2      0.897952     0.023455
# 38         1000                l2      0.899155     0.026887
# 39         1000                l2      0.829655     0.040555
# 40         1000                l2      0.801355     0.032026
# 41         1000                l2      0.804162     0.044259
# 42         1000                l2      0.853577     0.043886
# 43         1000                l2      0.882483     0.027266
# 44         1000                l2      0.874241     0.034719
# 45         1000                l2      0.846038     0.041752
# 46         1000                l2      0.895259     0.024385
# 47         1000                l2      0.896192     0.028119

# %%
evaluate_model(best_pipeline_log_reg, fit_le=fit_le, test=test, y_col_name=y, model_name = 'logistic')

# %%
num_positive = np.sum(train == 1)
num_negative = np.sum(train == 0)
scale_pos_weight = num_negative / num_positive
print(scale_pos_weight)
# Out:
# cc_num                 NaN
# category               NaN
# amt               0.000000
# gender                 NaN
# state                  NaN
# city_pop               NaN
# job                    NaN
# unix_time              NaN
# is_fraud        175.735294
# lat_x                  NaN
# long_y                 NaN
# lat_z                  NaN
# merch_lat_x            NaN
# merch_long_y           NaN
# merch_lat_z            NaN
# dtype: float64

# %%
param_grid_xgb = {
    'xgb__objective': ['binary:logistic'],
    'xgb__min_child_weight': [1, 5, 10],
    'xgb__gamma': [0.5, 1, 1.5, 2, 5],
    'xgb__subsample': [0.6, 0.8, 1.0],
    'xgb__colsample_bytree': [0.6, 0.8, 1.0],
    'xgb__max_depth': [3, 4, 5],
    'pca__n_components': [15, 20, 25,30,35,50,65],
    # 'under__sampling_strategy': [0.1, 0.2, 0.3, 0.5, 0.7, 1],
    # 'over__sampling_strategy': [0.2, 0.3, 0.4, 0.5, 0.7, 1]
    'xgb__scale_pos_weight':[ 1, 10, 50, 75, 100,175.735294,  1000]

}

xgb = XGBClassifier()

# xgb = XGBClassifier(scale_pos_weight=ratio)

MODEL_NAME = "xgb"

grid = sklearn_gridsearch_using_pipeline(
    train, y_col_name=y, fit_le=fit_le, model_name=MODEL_NAME, model=xgb, param_grid=param_grid_xgb, n_folds=5, verbose=1, randomized = True, step_names_to_remove=['under', 'over'])
best_pipeline_xgb = grid.best_estimator_
best_pipeline_xgb
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Best score: 0.9304101713721356
# Best parameters: {'xgb__subsample': 1.0, 'xgb__scale_pos_weight': 175.735294, 'xgb__objective': 'binary:logistic', 'xgb__min_child_weight': 1, 'xgb__max_depth': 3, 'xgb__gamma': 1.5, 'xgb__colsample_bytree': 0.8, 'pca__n_components': 30}
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('num_imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['cc_num', 'amt', 'city_pop',
#                                                    'unix_time', 'lat_x',
#                                                    'long_y', 'lat_z',
#                                                    'merch_lat_x',
#                                                    'merch_long_y',
#                                                    'merch_lat_z']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('cat_imputer',
#                                                                    SimpleImputer(strategy='most_frequent...
#                                feature_types=None, gamma=1.5, gpu_id=None,
#                                grow_policy=None, importance_type=None,
#                                interaction_constraints=None, learning_rate=None,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=3, max_leaves=None, min_child_weight=1,
#                                missing=nan, monotone_constraints=None,
#                                n_estimators=100, n_jobs=None,
#                                num_parallel_tree=None, predictor=None,
#                                random_state=None, ...))])

# %%
write_pipeline(best_pipeline_xgb, MODEL_NAME, DATASET_NAME)

# %%
evaluate_model(best_pipeline_xgb, fit_le=fit_le, test=test, y_col_name=y, model_name=MODEL_NAME)

# %%
MODEL_NAME='logistic'
best_pipeline_log_reg = load_pipeline(model_name=MODEL_NAME, dataset_name=DATASET_NAME)

MODEL_NAME='xgb'
best_pipeline_xgb = load_pipeline(model_name=MODEL_NAME, dataset_name=DATASET_NAME)

# %% [markdown]
# # evaluation metrics

# %%
test_predictions_log = test.copy(deep=True)
test_predictions_log["y_predicted"] = best_pipeline_log_reg.predict(test_predictions_log.drop(y, axis=1))
test_predictions_log["churn_encoded"] = fit_le.transform(test_predictions_log["is_fraud"])

# first check if customers have multiple rows => if so check if we can take other if this instance-based cost
impute = SimpleImputer(strategy='median')
test_predictions_log['A'] = impute.fit_transform(
    (test_predictions_log["amt"]*2000).to_frame())[:, 0]
# scaler = MinMaxScaler()

# Fit and transform the cb_cyolumn using the scaler
# test_predictions_log['A'] = scaler.fit_transform(test_predictions_log['A'].values.reshape(-1, 1))


# Step 3: Apply the function to calculate the cost for each instance and create the instance-dependent cost matrix
test_predictions_log['instance_cost'] = test_predictions_log.apply(lambda row: instance_dependent_cost_fraud(
    row['y_predicted'], row["churn_encoded"], row["A"]), axis=1)

test_predictions_log["y_predicted_decoded"] = fit_le.inverse_transform(
    test_predictions_log["y_predicted"])

# Print the DataFrame with the instance-dependent cost matrix
test_predictions_log[['is_fraud', 'y_predicted_decoded', "A", 'instance_cost']]

print(f"Test cost/loss = {test_predictions_log['instance_cost'].sum():.0f}.")
print(' total cost/loss average : ' , test_predictions_log['instance_cost'].sum()/len(test_predictions_log))
# Out:
# Test cost/loss = 1545.
#  total cost/loss average :  0.1142800088750832

# %%
test_predictions_xgb = test.copy(deep=True)
test_predictions_xgb["y_predicted"] = best_pipeline_xgb.predict(test_predictions_xgb.drop(y, axis=1))
test_predictions_xgb["churn_encoded"] = fit_le.transform(test_predictions_xgb["is_fraud"])

# first check if customers have multiple rows => if so check if we can take other if this instance-based cost
impute = SimpleImputer(strategy='median')
test_predictions_xgb['A'] = impute.fit_transform(
    (test_predictions_xgb["amt"]*2000).to_frame())[:, 0]
# scaler = MinMaxScaler()

# # Fit and transform the cb_column using the scaler
# test_predictions_xgb['A'] = scaler.fit_transform(test_predictions_xgb['A'].values.reshape(-1, 1))


# Step 3: Apply the function to calculate the cost for each instance and create the instance-dependent cost matrix
test_predictions_xgb['instance_cost'] = test_predictions_xgb.apply(lambda row: instance_dependent_cost_fraud(
    row['y_predicted'], row["churn_encoded"], row["A"]), axis=1)

test_predictions_xgb["y_predicted_decoded"] = fit_le.inverse_transform(
    test_predictions_xgb["y_predicted"])

# Print the DataFrame with the instance-dependent cost matrix
test_predictions_xgb[['is_fraud', 'y_predicted_decoded', "A", 'instance_cost']]

print(f"Test cost/loss = {test_predictions_xgb['instance_cost'].sum():.0f}.")
print(' total cost/loss average : ' , test_predictions_xgb['instance_cost'].sum()/len(test_predictions_xgb))
# Out:
# Test cost/loss = 1576.
#  total cost/loss average :  0.11656904075142371

# %%
print(test_predictions_log[['is_fraud', "A", 'instance_cost', "y_predicted"]].head(30))
# Out:
#          is_fraud          A  instance_cost  y_predicted
# 377359          0   125260.0            0.0            0
# 343471          0   134020.0            0.0            0
# 858312          0    35100.0            0.0            0
# 653694          0    64280.0            0.0            0
# 485688          0   137480.0            0.0            0
# 381035          0   240020.0            0.0            0
# 513268          0   103860.0            0.0            0
# 430783          0   155440.0            0.0            0
# 345889          0   193300.0            0.0            0
# 953633          0    92920.0            0.0            0
# 280700          0    15300.0            0.0            0
# 136120          0   354980.0            1.0            1
# 52731           0   297420.0            0.0            0
# 683053          0    81440.0            0.0            0
# 1201668         0   149280.0            0.0            0
# 1130978         0    12100.0            0.0            0
# 156956          1  2389120.0            0.0            1
# 264952          0    99380.0            0.0            0
# 247506          0    13240.0            0.0            0
# 99618           0    34820.0            0.0            0
# 275845          0   196520.0            0.0            0
# 427953          0    33160.0            0.0            0
# 406719          0     3180.0            0.0            0
# 974428          0    99980.0            0.0            0
# 1085445         0   161680.0            0.0            0
# 106698          0     7200.0            0.0            0
# 258741          0    96180.0            0.0            0
# 1006273         0   135200.0            0.0            0
# 35460           0   114460.0            0.0            0
# 872562          0   105460.0            0.0            0

# %% [markdown]
# # AMC metric

# %%
cb_column = 'A'
test_predictions_log['y_predicted_proba_log']= best_pipeline_log_reg.predict_proba(test_predictions_log.drop(y, axis=1))[:, 1]
best_threshold_log, AMC_log, lowest_cost_log = compute_best_threshold(test_predictions_log, best_pipeline_log_reg, y,cb_column, y_predicted_proba_col_name="y_predicted_proba_log", instance_dependent_cost_type = 'fraud')
# Out:
# Decision Threshold: 0.01, Test cost/loss = 12083.00
# Decision Threshold: 0.02, Test cost/loss = 11378.00
# Decision Threshold: 0.03, Test cost/loss = 10951.00
# Decision Threshold: 0.04, Test cost/loss = 10627.00
# Decision Threshold: 0.05, Test cost/loss = 10326.00
# Decision Threshold: 0.06, Test cost/loss = 10104.00
# Decision Threshold: 0.07, Test cost/loss = 9881.00
# Decision Threshold: 0.08, Test cost/loss = 9681.81
# Decision Threshold: 0.09, Test cost/loss = 9424.81
# Decision Threshold: 0.10, Test cost/loss = 9179.81
# Decision Threshold: 0.11, Test cost/loss = 8914.81
# Decision Threshold: 0.12, Test cost/loss = 8679.81
# Decision Threshold: 0.13, Test cost/loss = 8437.91
# Decision Threshold: 0.14, Test cost/loss = 8192.91
# Decision Threshold: 0.15, Test cost/loss = 7916.91
# Decision Threshold: 0.16, Test cost/loss = 7618.91
# Decision Threshold: 0.17, Test cost/loss = 7373.05
# Decision Threshold: 0.18, Test cost/loss = 7091.05
# Decision Threshold: 0.19, Test cost/loss = 6842.05
# Decision Threshold: 0.20, Test cost/loss = 6605.51
# Decision Threshold: 0.21, Test cost/loss = 6372.97
# Decision Threshold: 0.22, Test cost/loss = 6158.31
# Decision Threshold: 0.23, Test cost/loss = 5926.91
# Decision Threshold: 0.24, Test cost/loss = 5690.91
# Decision Threshold: 0.25, Test cost/loss = 5488.65
# Decision Threshold: 0.26, Test cost/loss = 5275.65
# Decision Threshold: 0.27, Test cost/loss = 5081.65
# Decision Threshold: 0.28, Test cost/loss = 4892.65
# Decision Threshold: 0.29, Test cost/loss = 4698.65
# Decision Threshold: 0.30, Test cost/loss = 4500.65
# Decision Threshold: 0.31, Test cost/loss = 4323.65
# Decision Threshold: 0.32, Test cost/loss = 4158.65
# Decision Threshold: 0.33, Test cost/loss = 3990.65
# Decision Threshold: 0.34, Test cost/loss = 3822.65
# Decision Threshold: 0.35, Test cost/loss = 3663.65
# Decision Threshold: 0.36, Test cost/loss = 3500.65
# Decision Threshold: 0.37, Test cost/loss = 3322.65
# Decision Threshold: 0.38, Test cost/loss = 3159.65
# Decision Threshold: 0.39, Test cost/loss = 3008.65
# Decision Threshold: 0.40, Test cost/loss = 2852.65
# Decision Threshold: 0.41, Test cost/loss = 2692.46
# Decision Threshold: 0.42, Test cost/loss = 2542.46
# Decision Threshold: 0.43, Test cost/loss = 2418.46
# Decision Threshold: 0.44, Test cost/loss = 2265.46
# Decision Threshold: 0.45, Test cost/loss = 2139.46
# Decision Threshold: 0.46, Test cost/loss = 1988.46
# Decision Threshold: 0.47, Test cost/loss = 1880.18
# Decision Threshold: 0.48, Test cost/loss = 1758.18
# Decision Threshold: 0.49, Test cost/loss = 1649.18
# Decision Threshold: 0.50, Test cost/loss = 1545.18
# Decision Threshold: 0.51, Test cost/loss = 1462.18
# Decision Threshold: 0.52, Test cost/loss = 1360.18
# Decision Threshold: 0.53, Test cost/loss = 1279.18
# Decision Threshold: 0.54, Test cost/loss = 1202.18
# Decision Threshold: 0.55, Test cost/loss = 1130.18
# Decision Threshold: 0.56, Test cost/loss = 1068.18
# Decision Threshold: 0.57, Test cost/loss = 1015.18
# Decision Threshold: 0.58, Test cost/loss = 1338.83
# Decision Threshold: 0.59, Test cost/loss = 1294.83
# Decision Threshold: 0.60, Test cost/loss = 1250.83
# Decision Threshold: 0.61, Test cost/loss = 1202.83
# Decision Threshold: 0.62, Test cost/loss = 1431.84
# Decision Threshold: 0.63, Test cost/loss = 1382.84
# Decision Threshold: 0.64, Test cost/loss = 1339.84
# Decision Threshold: 0.65, Test cost/loss = 1304.84
# Decision Threshold: 0.66, Test cost/loss = 1276.84
# Decision Threshold: 0.67, Test cost/loss = 1236.84
# Decision Threshold: 0.68, Test cost/loss = 1209.84
# Decision Threshold: 0.69, Test cost/loss = 1190.84
# Decision Threshold: 0.70, Test cost/loss = 1164.84
# Decision Threshold: 0.71, Test cost/loss = 1147.84
# Decision Threshold: 0.72, Test cost/loss = 1756.73
# Decision Threshold: 0.73, Test cost/loss = 1739.73
# Decision Threshold: 0.74, Test cost/loss = 1719.73
# Decision Threshold: 0.75, Test cost/loss = 1701.73
# Decision Threshold: 0.76, Test cost/loss = 1686.73
# Decision Threshold: 0.77, Test cost/loss = 1964.11
# Decision Threshold: 0.78, Test cost/loss = 1952.11
# Decision Threshold: 0.79, Test cost/loss = 1940.11
# Decision Threshold: 0.80, Test cost/loss = 2196.88
# Decision Threshold: 0.81, Test cost/loss = 2502.24
# Decision Threshold: 0.82, Test cost/loss = 2800.37
# Decision Threshold: 0.83, Test cost/loss = 3434.44
# Decision Threshold: 0.84, Test cost/loss = 3702.45
# Decision Threshold: 0.85, Test cost/loss = 3982.32
# Decision Threshold: 0.86, Test cost/loss = 4747.87
# Decision Threshold: 0.87, Test cost/loss = 4744.87
# Decision Threshold: 0.88, Test cost/loss = 4737.87
# Decision Threshold: 0.89, Test cost/loss = 5048.47
# Decision Threshold: 0.90, Test cost/loss = 5407.33
# Decision Threshold: 0.91, Test cost/loss = 5753.53
# Decision Threshold: 0.92, Test cost/loss = 6403.31
# Decision Threshold: 0.93, Test cost/loss = 7120.99
# Decision Threshold: 0.94, Test cost/loss = 7450.08
# Decision Threshold: 0.95, Test cost/loss = 7443.08
# Decision Threshold: 0.96, Test cost/loss = 7979.87
# Decision Threshold: 0.97, Test cost/loss = 8795.26
# Decision Threshold: 0.98, Test cost/loss = 10417.16
# Decision Threshold: 0.99, Test cost/loss = 13026.32
# Best Decision Threshold: 0.57, Lowest Test cost/loss = 1015.18, Lowest AMC = 0.08

# %%
test_predictions_xgb['y_predicted_proba_xgb']= best_pipeline_xgb.predict_proba(test_predictions_xgb.drop(y, axis=1))[:, 1]
best_threshold_xgb, AMC_xgb, lowest_cost_xgb = compute_best_threshold(test_predictions_xgb, best_pipeline_xgb, y, cb_column, y_predicted_proba_col_name="y_predicted_proba_xgb", instance_dependent_cost_type= 'fraud' )
# Out:
# Decision Threshold: 0.01, Test cost/loss = 7216.75
# Decision Threshold: 0.02, Test cost/loss = 5566.75
# Decision Threshold: 0.03, Test cost/loss = 4506.61
# Decision Threshold: 0.04, Test cost/loss = 3805.71
# Decision Threshold: 0.05, Test cost/loss = 3246.71
# Decision Threshold: 0.06, Test cost/loss = 2826.45
# Decision Threshold: 0.07, Test cost/loss = 2479.45
# Decision Threshold: 0.08, Test cost/loss = 2207.91
# Decision Threshold: 0.09, Test cost/loss = 1985.91
# Decision Threshold: 0.10, Test cost/loss = 1778.91
# Decision Threshold: 0.11, Test cost/loss = 1599.91
# Decision Threshold: 0.12, Test cost/loss = 1859.56
# Decision Threshold: 0.13, Test cost/loss = 1740.56
# Decision Threshold: 0.14, Test cost/loss = 1639.56
# Decision Threshold: 0.15, Test cost/loss = 1545.56
# Decision Threshold: 0.16, Test cost/loss = 1467.56
# Decision Threshold: 0.17, Test cost/loss = 1427.02
# Decision Threshold: 0.18, Test cost/loss = 1372.02
# Decision Threshold: 0.19, Test cost/loss = 2173.32
# Decision Threshold: 0.20, Test cost/loss = 2123.32
# Decision Threshold: 0.21, Test cost/loss = 2067.32
# Decision Threshold: 0.22, Test cost/loss = 2015.32
# Decision Threshold: 0.23, Test cost/loss = 1971.32
# Decision Threshold: 0.24, Test cost/loss = 1938.32
# Decision Threshold: 0.25, Test cost/loss = 1906.32
# Decision Threshold: 0.26, Test cost/loss = 1875.32
# Decision Threshold: 0.27, Test cost/loss = 1847.32
# Decision Threshold: 0.28, Test cost/loss = 1822.32
# Decision Threshold: 0.29, Test cost/loss = 1804.32
# Decision Threshold: 0.30, Test cost/loss = 1780.32
# Decision Threshold: 0.31, Test cost/loss = 1780.32
# Decision Threshold: 0.32, Test cost/loss = 1761.32
# Decision Threshold: 0.33, Test cost/loss = 1734.32
# Decision Threshold: 0.34, Test cost/loss = 1713.32
# Decision Threshold: 0.35, Test cost/loss = 1699.32
# Decision Threshold: 0.36, Test cost/loss = 1695.13
# Decision Threshold: 0.37, Test cost/loss = 1681.13
# Decision Threshold: 0.38, Test cost/loss = 1662.13
# Decision Threshold: 0.39, Test cost/loss = 1655.13
# Decision Threshold: 0.40, Test cost/loss = 1647.13
# Decision Threshold: 0.41, Test cost/loss = 1637.13
# Decision Threshold: 0.42, Test cost/loss = 1630.13
# Decision Threshold: 0.43, Test cost/loss = 1621.13
# Decision Threshold: 0.44, Test cost/loss = 1610.13
# Decision Threshold: 0.45, Test cost/loss = 1602.13
# Decision Threshold: 0.46, Test cost/loss = 1597.13
# Decision Threshold: 0.47, Test cost/loss = 1588.13
# Decision Threshold: 0.48, Test cost/loss = 1582.13
# Decision Threshold: 0.49, Test cost/loss = 1579.13
# Decision Threshold: 0.50, Test cost/loss = 1576.13
# Decision Threshold: 0.51, Test cost/loss = 1571.13
# Decision Threshold: 0.52, Test cost/loss = 1831.14
# Decision Threshold: 0.53, Test cost/loss = 1827.14
# Decision Threshold: 0.54, Test cost/loss = 1825.14
# Decision Threshold: 0.55, Test cost/loss = 1820.14
# Decision Threshold: 0.56, Test cost/loss = 2586.69
# Decision Threshold: 0.57, Test cost/loss = 3208.58
# Decision Threshold: 0.58, Test cost/loss = 3203.58
# Decision Threshold: 0.59, Test cost/loss = 3198.58
# Decision Threshold: 0.60, Test cost/loss = 3192.58
# Decision Threshold: 0.61, Test cost/loss = 3190.58
# Decision Threshold: 0.62, Test cost/loss = 3188.58
# Decision Threshold: 0.63, Test cost/loss = 3185.58
# Decision Threshold: 0.64, Test cost/loss = 3185.58
# Decision Threshold: 0.65, Test cost/loss = 3184.58
# Decision Threshold: 0.66, Test cost/loss = 3181.58
# Decision Threshold: 0.67, Test cost/loss = 3178.58
# Decision Threshold: 0.68, Test cost/loss = 3173.58
# Decision Threshold: 0.69, Test cost/loss = 3168.58
# Decision Threshold: 0.70, Test cost/loss = 4455.87
# Decision Threshold: 0.71, Test cost/loss = 4450.87
# Decision Threshold: 0.72, Test cost/loss = 4448.87
# Decision Threshold: 0.73, Test cost/loss = 4444.87
# Decision Threshold: 0.74, Test cost/loss = 4443.87
# Decision Threshold: 0.75, Test cost/loss = 4439.87
# Decision Threshold: 0.76, Test cost/loss = 4436.87
# Decision Threshold: 0.77, Test cost/loss = 4980.66
# Decision Threshold: 0.78, Test cost/loss = 5700.34
# Decision Threshold: 0.79, Test cost/loss = 5699.34
# Decision Threshold: 0.80, Test cost/loss = 5696.34
# Decision Threshold: 0.81, Test cost/loss = 6472.96
# Decision Threshold: 0.82, Test cost/loss = 6470.96
# Decision Threshold: 0.83, Test cost/loss = 6470.96
# Decision Threshold: 0.84, Test cost/loss = 6469.96
# Decision Threshold: 0.85, Test cost/loss = 6466.96
# Decision Threshold: 0.86, Test cost/loss = 6750.34
# Decision Threshold: 0.87, Test cost/loss = 6747.34
# Decision Threshold: 0.88, Test cost/loss = 7397.79
# Decision Threshold: 0.89, Test cost/loss = 7397.79
# Decision Threshold: 0.90, Test cost/loss = 7394.79
# Decision Threshold: 0.91, Test cost/loss = 7394.79
# Decision Threshold: 0.92, Test cost/loss = 7392.79
# Decision Threshold: 0.93, Test cost/loss = 7390.79
# Decision Threshold: 0.94, Test cost/loss = 7388.79
# Decision Threshold: 0.95, Test cost/loss = 7386.79
# Decision Threshold: 0.96, Test cost/loss = 7668.66
# Decision Threshold: 0.97, Test cost/loss = 8016.86
# Decision Threshold: 0.98, Test cost/loss = 9631.41
# Decision Threshold: 0.99, Test cost/loss = 13617.03
# Best Decision Threshold: 0.18, Lowest Test cost/loss = 1372.02, Lowest AMC = 0.10

# %% [markdown]
# # E-AMC

# %%
test_predictions_log = add_eap_ep(
    train=train, 
    test=test_predictions_log, 
    y_col_name=y, 
    best_pipeline=best_pipeline_log_reg, 
    cb_column=cb_column, 
    predicted_proba_col_name='y_predicted_proba_log', 
    churn_label= 1, 
    instance_dependent_cost_type="fraud")
test_predictions_xgb = add_eap_ep(
    train=train, 
    test=test_predictions_xgb, 
    y_col_name=y, 
    best_pipeline=best_pipeline_xgb, 
    cb_column=cb_column, 
    predicted_proba_col_name="y_predicted_proba_xgb", 
    churn_label=1, 
    instance_dependent_cost_type="fraud")
# Out:
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:329: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_0['EAP'] = test_actual_label_0[predicted_proba_col_name]*test_actual_label_0['FP'] + \
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:331: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_0['EP'] = estimated_p_1*test_actual_label_0['FP']+estimated_p_0*test_actual_label_0['TN']
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:333: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_1['EAP'] = test_actual_label_1[predicted_proba_col_name]*test_actual_label_1['TP'] + \
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:335: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_1['EP'] = estimated_p_1 * test_actual_label_1['TP'] + estimated_p_0 * test_actual_label_1['FN']
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:329: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_0['EAP'] = test_actual_label_0[predicted_proba_col_name]*test_actual_label_0['FP'] + \
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:331: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_0['EP'] = estimated_p_1*test_actual_label_0['FP']+estimated_p_0*test_actual_label_0['TN']
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:333: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_1['EAP'] = test_actual_label_1[predicted_proba_col_name]*test_actual_label_1['TP'] + \
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:335: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_1['EP'] = estimated_p_1 * test_actual_label_1['TP'] + estimated_p_0 * test_actual_label_1['FN']

# %%
test_predictions_log
# Out:
#                       cc_num        category      amt gender state  city_pop  \
# 377359      3540210836308425     food_dining    62.63      M    TX        53
# 343471          639030014711   entertainment    67.01      M    IL       639
# 858312       377264520876399   personal_care    17.55      F    SC      4424
# 653694       213157767990030  health_fitness    32.14      F    WY     27971
# 485688        30408301059761       kids_pets    68.74      M    SC      4471
# ...                      ...             ...      ...    ...   ...       ...
# 1202685      374821819075109  health_fitness    19.34      M    NY      9565
# 670176      4266200684857219    shopping_net  1083.88      M    NE       732
# 1131211  4810789809665942990   entertainment   544.79      F    OH       338
# 90178          4195740185974     grocery_pos   314.36      M    OR    841711
# 670559      6011542681743618     grocery_pos   358.98      F    VA       863
#
#                                     job   unix_time  is_fraud     lat_x  \
# 377359                Fisheries officer  1384536888         0  0.386883
# 343471              Mechanical engineer  1383260389         0  0.374299
# 858312                           Lawyer  1355689325         0 -0.370872
# 653694                  Music therapist  1349466301         0  0.539446
# 485688           Occupational hygienist  1343748738         0 -0.025769
# ...                                 ...         ...       ...       ...
# 1202685             Exhibition designer  1368835137         1 -0.151494
# 670176   Television/film/video producer  1350086058         1  0.624315
# 1131211               Quantity surveyor  1366066429         1  0.134441
# 90178       Engineer, building services  1374463871         1 -0.022418
# 670559                 Engineer, mining  1350099543         1 -0.432334
#
#            long_y     lat_z  merch_lat_x  merch_long_y  merch_lat_z  \
# 377359   0.903359 -0.185107     0.974763      0.171631    -0.142757
# 343471  -0.790767 -0.484343    -0.101118     -0.751755    -0.651644
# 858312  -0.903818  0.213464    -0.117634     -0.817296    -0.564083
# 653694   0.478639 -0.692750    -0.001038     -0.002552    -0.999996
# 485688  -0.341624  0.939483     0.190030     -0.354266     0.915633
# ...           ...       ...          ...           ...          ...
# 1202685 -0.586493 -0.795660     0.420107     -0.862442    -0.282320
# 670176  -0.503856  0.596958     0.691758      0.004403     0.722116
# 1131211  0.269255  0.953639    -0.021650      0.099756     0.994776
# 90178    0.004107  0.999740    -0.325970     -0.031024     0.944871
# 670559   0.104784  0.895604    -0.223838     -0.005511     0.974611
#
#          y_predicted  churn_encoded          A  instance_cost  \
# 377359             0              0   125260.0           0.00
# 343471             0              0   134020.0           0.00
# 858312             0              0    35100.0           0.00
# 653694             0              0    64280.0           0.00
# 485688             0              0   137480.0           0.00
# ...              ...            ...        ...            ...
# 1202685            0              1    38680.0          19.34
# 670176             1              1  2167760.0           0.00
# 1131211            1              1  1089580.0         544.79
# 90178              1              1   628720.0         314.36
# 670559             1              1   717960.0         358.98
#
#          y_predicted_decoded  y_predicted_proba_log  TN       FN  FP  TP  \
# 377359                     0               0.136093   0    62.63   1   0
# 343471                     0               0.013334   0    67.01   1   0
# 858312                     0               0.249659   0    17.55   1   0
# 653694                     0               0.241324   0    32.14   1   0
# 485688                     0               0.326600   0    68.74   1   0
# ...                      ...                    ...  ..      ...  ..  ..
# 1202685                    0               0.219136   0    19.34   1   0
# 670176                     1               0.997513   0  1083.88   1   0
# 1131211                    1               0.953016   0   544.79   1   0
# 90178                      1               0.806133   0   314.36   1   0
# 670559                     1               0.911498   0   358.98   1   0
#
#                EAP           EP
# 377359    0.136093     0.005658
# 343471    0.013334     0.005658
# 858312    0.249659     0.005658
# 653694    0.241324     0.005658
# 485688    0.326600     0.005658
# ...            ...          ...
# 1202685  15.101906    19.230571
# 670176    2.695676  1077.747213
# 1131211  25.596215   541.707480
# 90178    60.943941   312.581295
# 670559   31.770362   356.948827
#
# [13521 rows x 27 columns]

# %%
test_predictions_xgb
# Out:
#                       cc_num        category      amt gender state  city_pop  \
# 377359      3540210836308425     food_dining    62.63      M    TX        53
# 343471          639030014711   entertainment    67.01      M    IL       639
# 858312       377264520876399   personal_care    17.55      F    SC      4424
# 653694       213157767990030  health_fitness    32.14      F    WY     27971
# 485688        30408301059761       kids_pets    68.74      M    SC      4471
# ...                      ...             ...      ...    ...   ...       ...
# 1202685      374821819075109  health_fitness    19.34      M    NY      9565
# 670176      4266200684857219    shopping_net  1083.88      M    NE       732
# 1131211  4810789809665942990   entertainment   544.79      F    OH       338
# 90178          4195740185974     grocery_pos   314.36      M    OR    841711
# 670559      6011542681743618     grocery_pos   358.98      F    VA       863
#
#                                     job   unix_time  is_fraud     lat_x  \
# 377359                Fisheries officer  1384536888         0  0.386883
# 343471              Mechanical engineer  1383260389         0  0.374299
# 858312                           Lawyer  1355689325         0 -0.370872
# 653694                  Music therapist  1349466301         0  0.539446
# 485688           Occupational hygienist  1343748738         0 -0.025769
# ...                                 ...         ...       ...       ...
# 1202685             Exhibition designer  1368835137         1 -0.151494
# 670176   Television/film/video producer  1350086058         1  0.624315
# 1131211               Quantity surveyor  1366066429         1  0.134441
# 90178       Engineer, building services  1374463871         1 -0.022418
# 670559                 Engineer, mining  1350099543         1 -0.432334
#
#            long_y     lat_z  merch_lat_x  merch_long_y  merch_lat_z  \
# 377359   0.903359 -0.185107     0.974763      0.171631    -0.142757
# 343471  -0.790767 -0.484343    -0.101118     -0.751755    -0.651644
# 858312  -0.903818  0.213464    -0.117634     -0.817296    -0.564083
# 653694   0.478639 -0.692750    -0.001038     -0.002552    -0.999996
# 485688  -0.341624  0.939483     0.190030     -0.354266     0.915633
# ...           ...       ...          ...           ...          ...
# 1202685 -0.586493 -0.795660     0.420107     -0.862442    -0.282320
# 670176  -0.503856  0.596958     0.691758      0.004403     0.722116
# 1131211  0.269255  0.953639    -0.021650      0.099756     0.994776
# 90178    0.004107  0.999740    -0.325970     -0.031024     0.944871
# 670559   0.104784  0.895604    -0.223838     -0.005511     0.974611
#
#          y_predicted  churn_encoded          A  instance_cost  \
# 377359             0              0   125260.0           0.00
# 343471             0              0   134020.0           0.00
# 858312             0              0    35100.0           0.00
# 653694             0              0    64280.0           0.00
# 485688             0              0   137480.0           0.00
# ...              ...            ...        ...            ...
# 1202685            0              1    38680.0          19.34
# 670176             1              1  2167760.0           0.00
# 1131211            1              1  1089580.0         544.79
# 90178              1              1   628720.0         314.36
# 670559             1              1   717960.0           0.00
#
#          y_predicted_decoded  y_predicted_proba_xgb  TN       FN  FP  TP  \
# 377359                     0               0.030850   0    62.63   1   0
# 343471                     0               0.000839   0    67.01   1   0
# 858312                     0               0.139900   0    17.55   1   0
# 653694                     0               0.133361   0    32.14   1   0
# 485688                     0               0.008483   0    68.74   1   0
# ...                      ...                    ...  ..      ...  ..  ..
# 1202685                    0               0.009055   0    19.34   1   0
# 670176                     1               0.995325   0  1083.88   1   0
# 1131211                    1               0.767989   0   544.79   1   0
# 90178                      1               0.874957   0   314.36   1   0
# 670559                     1               0.991703   0   358.98   1   0
#
#                 EAP           EP
# 377359     0.030850     0.005658
# 343471     0.000839     0.005658
# 858312     0.139900     0.005658
# 653694     0.133361     0.005658
# 485688     0.008483     0.005658
# ...             ...          ...
# 1202685   19.164874    19.230571
# 670176     5.067560  1077.747213
# 1131211  126.397284   541.707480
# 90178     39.308641   312.581295
# 670559     2.978552   356.948827
#
# [13521 rows x 27 columns]

# %%
print(test_predictions_log['EAP'].sum())
print(test_predictions_log['EP'].sum())


print('EAP : ', test_predictions_log['EAP'].sum()/len(test_predictions_log))
print('EP : ', test_predictions_log['EP'].sum()/len(test_predictions_log))
# Out:
# 4695.254355575067
# 26764.698161091692
# EAP :  0.34725644224355207
# EP :  1.9794910258924407

# %%
print(test_predictions_xgb['EAP'].sum())
print(test_predictions_xgb['EP'].sum())


print('EAP : ', test_predictions_xgb['EAP'].sum()/len(test_predictions_xgb))
print('EP : ', test_predictions_xgb['EP'].sum()/len(test_predictions_xgb))
# Out:
# 3733.4557882310123
# 26764.698161091692
# EAP :  0.2761227563220925
# EP :  1.9794910258924407

# %% [markdown]
# # mp 50% threshold

# %%
test_predictions_log_2= test.copy(deep=True)
test_predictions_log_2["y_predicted"] = best_pipeline_log_reg.predict(test_predictions_log_2.drop(y, axis=1))
test_predictions_log_2["churn_encoded"] = fit_le.transform(test_predictions_log_2["is_fraud"])

# first check if customers have multiple rows => if so check if we can take other if this instance-based cost
impute = SimpleImputer(strategy='median')
test_predictions_log_2['A'] = impute.fit_transform(
    (test_predictions_log_2["amt"]*2000).to_frame())[:, 0]
# scaler = MinMaxScaler()

# Fit and transform the cb_cyolumn using the scaler
# test_predictions_log['A'] = scaler.fit_transform(test_predictions_log['A'].values.reshape(-1, 1))


# Step 3: Apply the function to calculate the cost for each instance and create the instance-dependent cost matrix
test_predictions_log_2['instance_cost'] = test_predictions_log_2.apply(lambda row: instance_dependent_cost_fraud_2(
    row['y_predicted'], row["churn_encoded"], row["A"]), axis=1)

test_predictions_log_2["y_predicted_decoded"] = fit_le.inverse_transform(
    test_predictions_log_2["y_predicted"])

# Print the DataFrame with the instance-dependent cost matrix
test_predictions_log_2[['is_fraud', 'y_predicted_decoded', "A", 'instance_cost']]

print(f"Test cost/loss = {test_predictions_log_2['instance_cost'].sum():.0f}.")
print(' total cost/loss average : ' , test_predictions_log_2['instance_cost'].sum()/len(test_predictions_log_2))
# Out:
# Test cost/loss = -1506.
#  total cost/loss average :  -0.11139560683381407

# %%
test_predictions_xgb_2 = test.copy(deep=True)
test_predictions_xgb_2["y_predicted"] = best_pipeline_xgb.predict(test_predictions_xgb_2.drop(y, axis=1))
test_predictions_xgb_2["churn_encoded"] = fit_le.transform(test_predictions_xgb_2["is_fraud"])

# first check if customers have multiple rows => if so check if we can take other if this instance-based cost
impute = SimpleImputer(strategy='median')
test_predictions_xgb_2['A'] = impute.fit_transform(
    (test_predictions_xgb_2["amt"]*2000).to_frame())[:, 0]
# scaler = MinMaxScaler()

# # Fit and transform the cb_column using the scaler
# test_predictions_xgb['A'] = scaler.fit_transform(test_predictions_xgb['A'].values.reshape(-1, 1))


# Step 3: Apply the function to calculate the cost for each instance and create the instance-dependent cost matrix
test_predictions_xgb_2['instance_cost'] = test_predictions_xgb_2.apply(lambda row: instance_dependent_cost_fraud_2(
    row['y_predicted'], row["churn_encoded"], row["A"]), axis=1)

test_predictions_xgb_2["y_predicted_decoded"] = fit_le.inverse_transform(
    test_predictions_xgb_2["y_predicted"])

# Print the DataFrame with the instance-dependent cost matrix
test_predictions_xgb_2[['is_fraud', 'y_predicted_decoded', "A", 'instance_cost']]

print(f"Test cost/loss = {test_predictions_xgb_2['instance_cost'].sum():.0f}.")
print(' total cost/loss average : ' , test_predictions_xgb_2['instance_cost'].sum()/len(test_predictions_xgb_2))
# Out:
# Test cost/loss = -1539.
#  total cost/loss average :  -0.113832556763553

# %% [markdown]
# # mp-metric

# %%
cb_column = 'A'
test_predictions_log_2['y_predicted_proba_log']= best_pipeline_log_reg.predict_proba(test_predictions_log_2.drop(y, axis=1))[:, 1]
best_threshold_log, AMC_log, lowest_cost_log = compute_best_threshold_2(test_predictions_log_2, best_pipeline_log_reg, y,cb_column, y_predicted_proba_col_name="y_predicted_proba_log", instance_dependent_cost_type = 'fraud_2')
# Out:
# Decision Threshold: 0.01, Test cost/loss = -12032.00
# Decision Threshold: 0.02, Test cost/loss = -11327.00
# Decision Threshold: 0.03, Test cost/loss = -10900.00
# Decision Threshold: 0.04, Test cost/loss = -10576.00
# Decision Threshold: 0.05, Test cost/loss = -10275.00
# Decision Threshold: 0.06, Test cost/loss = -10053.00
# Decision Threshold: 0.07, Test cost/loss = -9830.00
# Decision Threshold: 0.08, Test cost/loss = -9632.81
# Decision Threshold: 0.09, Test cost/loss = -9375.81
# Decision Threshold: 0.10, Test cost/loss = -9130.81
# Decision Threshold: 0.11, Test cost/loss = -8865.81
# Decision Threshold: 0.12, Test cost/loss = -8630.81
# Decision Threshold: 0.13, Test cost/loss = -8389.91
# Decision Threshold: 0.14, Test cost/loss = -8145.91
# Decision Threshold: 0.15, Test cost/loss = -7869.91
# Decision Threshold: 0.16, Test cost/loss = -7571.91
# Decision Threshold: 0.17, Test cost/loss = -7327.05
# Decision Threshold: 0.18, Test cost/loss = -7045.05
# Decision Threshold: 0.19, Test cost/loss = -6796.05
# Decision Threshold: 0.20, Test cost/loss = -6560.51
# Decision Threshold: 0.21, Test cost/loss = -6328.97
# Decision Threshold: 0.22, Test cost/loss = -6115.31
# Decision Threshold: 0.23, Test cost/loss = -5884.91
# Decision Threshold: 0.24, Test cost/loss = -5648.91
# Decision Threshold: 0.25, Test cost/loss = -5447.65
# Decision Threshold: 0.26, Test cost/loss = -5234.65
# Decision Threshold: 0.27, Test cost/loss = -5040.65
# Decision Threshold: 0.28, Test cost/loss = -4851.65
# Decision Threshold: 0.29, Test cost/loss = -4657.65
# Decision Threshold: 0.30, Test cost/loss = -4459.65
# Decision Threshold: 0.31, Test cost/loss = -4282.65
# Decision Threshold: 0.32, Test cost/loss = -4117.65
# Decision Threshold: 0.33, Test cost/loss = -3949.65
# Decision Threshold: 0.34, Test cost/loss = -3781.65
# Decision Threshold: 0.35, Test cost/loss = -3622.65
# Decision Threshold: 0.36, Test cost/loss = -3459.65
# Decision Threshold: 0.37, Test cost/loss = -3281.65
# Decision Threshold: 0.38, Test cost/loss = -3118.65
# Decision Threshold: 0.39, Test cost/loss = -2967.65
# Decision Threshold: 0.40, Test cost/loss = -2811.65
# Decision Threshold: 0.41, Test cost/loss = -2652.46
# Decision Threshold: 0.42, Test cost/loss = -2502.46
# Decision Threshold: 0.43, Test cost/loss = -2378.46
# Decision Threshold: 0.44, Test cost/loss = -2225.46
# Decision Threshold: 0.45, Test cost/loss = -2099.46
# Decision Threshold: 0.46, Test cost/loss = -1948.46
# Decision Threshold: 0.47, Test cost/loss = -1841.18
# Decision Threshold: 0.48, Test cost/loss = -1719.18
# Decision Threshold: 0.49, Test cost/loss = -1610.18
# Decision Threshold: 0.50, Test cost/loss = -1506.18
# Decision Threshold: 0.51, Test cost/loss = -1423.18
# Decision Threshold: 0.52, Test cost/loss = -1321.18
# Decision Threshold: 0.53, Test cost/loss = -1240.18
# Decision Threshold: 0.54, Test cost/loss = -1163.18
# Decision Threshold: 0.55, Test cost/loss = -1091.18
# Decision Threshold: 0.56, Test cost/loss = -1029.18
# Decision Threshold: 0.57, Test cost/loss = -976.18
# Decision Threshold: 0.58, Test cost/loss = -1300.83
# Decision Threshold: 0.59, Test cost/loss = -1256.83
# Decision Threshold: 0.60, Test cost/loss = -1212.83
# Decision Threshold: 0.61, Test cost/loss = -1164.83
# Decision Threshold: 0.62, Test cost/loss = -1394.84
# Decision Threshold: 0.63, Test cost/loss = -1345.84
# Decision Threshold: 0.64, Test cost/loss = -1302.84
# Decision Threshold: 0.65, Test cost/loss = -1267.84
# Decision Threshold: 0.66, Test cost/loss = -1239.84
# Decision Threshold: 0.67, Test cost/loss = -1199.84
# Decision Threshold: 0.68, Test cost/loss = -1172.84
# Decision Threshold: 0.69, Test cost/loss = -1153.84
# Decision Threshold: 0.70, Test cost/loss = -1127.84
# Decision Threshold: 0.71, Test cost/loss = -1110.84
# Decision Threshold: 0.72, Test cost/loss = -1720.73
# Decision Threshold: 0.73, Test cost/loss = -1703.73
# Decision Threshold: 0.74, Test cost/loss = -1683.73
# Decision Threshold: 0.75, Test cost/loss = -1665.73
# Decision Threshold: 0.76, Test cost/loss = -1650.73
# Decision Threshold: 0.77, Test cost/loss = -1929.11
# Decision Threshold: 0.78, Test cost/loss = -1917.11
# Decision Threshold: 0.79, Test cost/loss = -1905.11
# Decision Threshold: 0.80, Test cost/loss = -2162.88
# Decision Threshold: 0.81, Test cost/loss = -2469.24
# Decision Threshold: 0.82, Test cost/loss = -2768.37
# Decision Threshold: 0.83, Test cost/loss = -3404.44
# Decision Threshold: 0.84, Test cost/loss = -3673.45
# Decision Threshold: 0.85, Test cost/loss = -3954.32
# Decision Threshold: 0.86, Test cost/loss = -4720.87
# Decision Threshold: 0.87, Test cost/loss = -4717.87
# Decision Threshold: 0.88, Test cost/loss = -4710.87
# Decision Threshold: 0.89, Test cost/loss = -5022.47
# Decision Threshold: 0.90, Test cost/loss = -5382.33
# Decision Threshold: 0.91, Test cost/loss = -5729.53
# Decision Threshold: 0.92, Test cost/loss = -6381.31
# Decision Threshold: 0.93, Test cost/loss = -7099.99
# Decision Threshold: 0.94, Test cost/loss = -7430.08
# Decision Threshold: 0.95, Test cost/loss = -7423.08
# Decision Threshold: 0.96, Test cost/loss = -7960.87
# Decision Threshold: 0.97, Test cost/loss = -8777.26
# Decision Threshold: 0.98, Test cost/loss = -10401.16
# Decision Threshold: 0.99, Test cost/loss = -13013.32
# Best Decision Threshold: 0.57, Lowest Test cost/loss = -976.18, Lowest AMC = -0.07

# %%
test_predictions_xgb_2['y_predicted_proba_xgb']= best_pipeline_xgb.predict_proba(test_predictions_xgb_2.drop(y, axis=1))[:, 1]
best_threshold_xgb, AMC_xgb, lowest_cost_xgb = compute_best_threshold(test_predictions_xgb_2, best_pipeline_xgb, y, cb_column, y_predicted_proba_col_name="y_predicted_proba_xgb", instance_dependent_cost_type= 'fraud_2' )
# Out:
# Decision Threshold: 0.01, Test cost/loss = -7168.75
# Decision Threshold: 0.02, Test cost/loss = -5518.75
# Decision Threshold: 0.03, Test cost/loss = -4460.61
# Decision Threshold: 0.04, Test cost/loss = -3760.71
# Decision Threshold: 0.05, Test cost/loss = -3201.71
# Decision Threshold: 0.06, Test cost/loss = -2782.45
# Decision Threshold: 0.07, Test cost/loss = -2435.45
# Decision Threshold: 0.08, Test cost/loss = -2164.91
# Decision Threshold: 0.09, Test cost/loss = -1942.91
# Decision Threshold: 0.10, Test cost/loss = -1735.91
# Decision Threshold: 0.11, Test cost/loss = -1556.91
# Decision Threshold: 0.12, Test cost/loss = -1817.56
# Decision Threshold: 0.13, Test cost/loss = -1698.56
# Decision Threshold: 0.14, Test cost/loss = -1597.56
# Decision Threshold: 0.15, Test cost/loss = -1503.56
# Decision Threshold: 0.16, Test cost/loss = -1425.56
# Decision Threshold: 0.17, Test cost/loss = -1386.02
# Decision Threshold: 0.18, Test cost/loss = -1331.02
# Decision Threshold: 0.19, Test cost/loss = -2133.32
# Decision Threshold: 0.20, Test cost/loss = -2083.32
# Decision Threshold: 0.21, Test cost/loss = -2027.32
# Decision Threshold: 0.22, Test cost/loss = -1975.32
# Decision Threshold: 0.23, Test cost/loss = -1931.32
# Decision Threshold: 0.24, Test cost/loss = -1899.32
# Decision Threshold: 0.25, Test cost/loss = -1867.32
# Decision Threshold: 0.26, Test cost/loss = -1836.32
# Decision Threshold: 0.27, Test cost/loss = -1808.32
# Decision Threshold: 0.28, Test cost/loss = -1783.32
# Decision Threshold: 0.29, Test cost/loss = -1765.32
# Decision Threshold: 0.30, Test cost/loss = -1741.32
# Decision Threshold: 0.31, Test cost/loss = -1742.32
# Decision Threshold: 0.32, Test cost/loss = -1723.32
# Decision Threshold: 0.33, Test cost/loss = -1696.32
# Decision Threshold: 0.34, Test cost/loss = -1675.32
# Decision Threshold: 0.35, Test cost/loss = -1661.32
# Decision Threshold: 0.36, Test cost/loss = -1658.13
# Decision Threshold: 0.37, Test cost/loss = -1644.13
# Decision Threshold: 0.38, Test cost/loss = -1625.13
# Decision Threshold: 0.39, Test cost/loss = -1618.13
# Decision Threshold: 0.40, Test cost/loss = -1610.13
# Decision Threshold: 0.41, Test cost/loss = -1600.13
# Decision Threshold: 0.42, Test cost/loss = -1593.13
# Decision Threshold: 0.43, Test cost/loss = -1584.13
# Decision Threshold: 0.44, Test cost/loss = -1573.13
# Decision Threshold: 0.45, Test cost/loss = -1565.13
# Decision Threshold: 0.46, Test cost/loss = -1560.13
# Decision Threshold: 0.47, Test cost/loss = -1551.13
# Decision Threshold: 0.48, Test cost/loss = -1545.13
# Decision Threshold: 0.49, Test cost/loss = -1542.13
# Decision Threshold: 0.50, Test cost/loss = -1539.13
# Decision Threshold: 0.51, Test cost/loss = -1534.13
# Decision Threshold: 0.52, Test cost/loss = -1795.14
# Decision Threshold: 0.53, Test cost/loss = -1791.14
# Decision Threshold: 0.54, Test cost/loss = -1789.14
# Decision Threshold: 0.55, Test cost/loss = -1784.14
# Decision Threshold: 0.56, Test cost/loss = -2551.69
# Decision Threshold: 0.57, Test cost/loss = -3174.58
# Decision Threshold: 0.58, Test cost/loss = -3169.58
# Decision Threshold: 0.59, Test cost/loss = -3164.58
# Decision Threshold: 0.60, Test cost/loss = -3158.58
# Decision Threshold: 0.61, Test cost/loss = -3156.58
# Decision Threshold: 0.62, Test cost/loss = -3154.58
# Decision Threshold: 0.63, Test cost/loss = -3151.58
# Decision Threshold: 0.64, Test cost/loss = -3151.58
# Decision Threshold: 0.65, Test cost/loss = -3150.58
# Decision Threshold: 0.66, Test cost/loss = -3147.58
# Decision Threshold: 0.67, Test cost/loss = -3144.58
# Decision Threshold: 0.68, Test cost/loss = -3139.58
# Decision Threshold: 0.69, Test cost/loss = -3134.58
# Decision Threshold: 0.70, Test cost/loss = -4422.87
# Decision Threshold: 0.71, Test cost/loss = -4417.87
# Decision Threshold: 0.72, Test cost/loss = -4415.87
# Decision Threshold: 0.73, Test cost/loss = -4411.87
# Decision Threshold: 0.74, Test cost/loss = -4410.87
# Decision Threshold: 0.75, Test cost/loss = -4406.87
# Decision Threshold: 0.76, Test cost/loss = -4403.87
# Decision Threshold: 0.77, Test cost/loss = -4948.66
# Decision Threshold: 0.78, Test cost/loss = -5669.34
# Decision Threshold: 0.79, Test cost/loss = -5668.34
# Decision Threshold: 0.80, Test cost/loss = -5665.34
# Decision Threshold: 0.81, Test cost/loss = -6442.96
# Decision Threshold: 0.82, Test cost/loss = -6440.96
# Decision Threshold: 0.83, Test cost/loss = -6440.96
# Decision Threshold: 0.84, Test cost/loss = -6439.96
# Decision Threshold: 0.85, Test cost/loss = -6436.96
# Decision Threshold: 0.86, Test cost/loss = -6721.34
# Decision Threshold: 0.87, Test cost/loss = -6718.34
# Decision Threshold: 0.88, Test cost/loss = -7370.79
# Decision Threshold: 0.89, Test cost/loss = -7370.79
# Decision Threshold: 0.90, Test cost/loss = -7367.79
# Decision Threshold: 0.91, Test cost/loss = -7367.79
# Decision Threshold: 0.92, Test cost/loss = -7365.79
# Decision Threshold: 0.93, Test cost/loss = -7363.79
# Decision Threshold: 0.94, Test cost/loss = -7361.79
# Decision Threshold: 0.95, Test cost/loss = -7359.79
# Decision Threshold: 0.96, Test cost/loss = -7642.66
# Decision Threshold: 0.97, Test cost/loss = -7991.86
# Decision Threshold: 0.98, Test cost/loss = -9609.41
# Decision Threshold: 0.99, Test cost/loss = -13601.03
# Best Decision Threshold: 0.99, Lowest Test cost/loss = -13601.03, Lowest AMC = -1.01

# %% [markdown]
# # E-MP metric

# %%
test_predictions_log_2 = add_eap_ep(
    train=train, 
    test=test_predictions_log_2, 
    y_col_name=y, 
    best_pipeline=best_pipeline_log_reg, 
    cb_column=cb_column, 
    predicted_proba_col_name='y_predicted_proba_log', 
    churn_label= 1, 
    instance_dependent_cost_type="fraud_2")
test_predictions_xgb_2 = add_eap_ep(
    train=train, 
    test=test_predictions_xgb_2, 
    y_col_name=y, 
    best_pipeline=best_pipeline_xgb, 
    cb_column=cb_column, 
    predicted_proba_col_name="y_predicted_proba_xgb", 
    churn_label=1, 
    instance_dependent_cost_type="fraud_2")
# Out:
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:329: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_0['EAP'] = test_actual_label_0[predicted_proba_col_name]*test_actual_label_0['FP'] + \
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:331: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_0['EP'] = estimated_p_1*test_actual_label_0['FP']+estimated_p_0*test_actual_label_0['TN']
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:333: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_1['EAP'] = test_actual_label_1[predicted_proba_col_name]*test_actual_label_1['TP'] + \
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:335: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_1['EP'] = estimated_p_1 * test_actual_label_1['TP'] + estimated_p_0 * test_actual_label_1['FN']
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:329: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_0['EAP'] = test_actual_label_0[predicted_proba_col_name]*test_actual_label_0['FP'] + \
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:331: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_0['EP'] = estimated_p_1*test_actual_label_0['FP']+estimated_p_0*test_actual_label_0['TN']
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:333: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_1['EAP'] = test_actual_label_1[predicted_proba_col_name]*test_actual_label_1['TP'] + \
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:335: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_1['EP'] = estimated_p_1 * test_actual_label_1['TP'] + estimated_p_0 * test_actual_label_1['FN']

# %%
print(test_predictions_log_2['EAP'].sum())
print(test_predictions_log_2['EP'].sum())


print('EAP : ', test_predictions_log_2['EAP'].sum()/len(test_predictions_log_2))
print('EP : ', test_predictions_log_2['EP'].sum()/len(test_predictions_log_2))
# Out:
# -4657.305176861655
# -26764.409593942415
# EAP :  -0.34444975792187377
# EP :  -1.979469683746943

# %%
print(test_predictions_xgb_2['EAP'].sum())
print(test_predictions_xgb_2['EP'].sum())


print('EAP : ', test_predictions_xgb_2['EAP'].sum()/len(test_predictions_xgb_2))
print('EP : ', test_predictions_xgb_2['EP'].sum()/len(test_predictions_xgb_2))
# Out:
# -3697.8995977861573
# -26764.409593942415
# EAP :  -0.2734930550836593
# EP :  -1.979469683746943

# %%
test_predictions_log_2
# Out:
#                       cc_num        category      amt gender state  city_pop  \
# 377359      3540210836308425     food_dining    62.63      M    TX        53
# 343471          639030014711   entertainment    67.01      M    IL       639
# 858312       377264520876399   personal_care    17.55      F    SC      4424
# 653694       213157767990030  health_fitness    32.14      F    WY     27971
# 485688        30408301059761       kids_pets    68.74      M    SC      4471
# ...                      ...             ...      ...    ...   ...       ...
# 1202685      374821819075109  health_fitness    19.34      M    NY      9565
# 670176      4266200684857219    shopping_net  1083.88      M    NE       732
# 1131211  4810789809665942990   entertainment   544.79      F    OH       338
# 90178          4195740185974     grocery_pos   314.36      M    OR    841711
# 670559      6011542681743618     grocery_pos   358.98      F    VA       863
#
#                                     job   unix_time  is_fraud     lat_x  \
# 377359                Fisheries officer  1384536888         0  0.386883
# 343471              Mechanical engineer  1383260389         0  0.374299
# 858312                           Lawyer  1355689325         0 -0.370872
# 653694                  Music therapist  1349466301         0  0.539446
# 485688           Occupational hygienist  1343748738         0 -0.025769
# ...                                 ...         ...       ...       ...
# 1202685             Exhibition designer  1368835137         1 -0.151494
# 670176   Television/film/video producer  1350086058         1  0.624315
# 1131211               Quantity surveyor  1366066429         1  0.134441
# 90178       Engineer, building services  1374463871         1 -0.022418
# 670559                 Engineer, mining  1350099543         1 -0.432334
#
#            long_y     lat_z  merch_lat_x  merch_long_y  merch_lat_z  \
# 377359   0.903359 -0.185107     0.974763      0.171631    -0.142757
# 343471  -0.790767 -0.484343    -0.101118     -0.751755    -0.651644
# 858312  -0.903818  0.213464    -0.117634     -0.817296    -0.564083
# 653694   0.478639 -0.692750    -0.001038     -0.002552    -0.999996
# 485688  -0.341624  0.939483     0.190030     -0.354266     0.915633
# ...           ...       ...          ...           ...          ...
# 1202685 -0.586493 -0.795660     0.420107     -0.862442    -0.282320
# 670176  -0.503856  0.596958     0.691758      0.004403     0.722116
# 1131211  0.269255  0.953639    -0.021650      0.099756     0.994776
# 90178    0.004107  0.999740    -0.325970     -0.031024     0.944871
# 670559   0.104784  0.895604    -0.223838     -0.005511     0.974611
#
#          y_predicted  churn_encoded          A  instance_cost  \
# 377359             0              0   125260.0           0.00
# 343471             0              0   134020.0           0.00
# 858312             0              0    35100.0           0.00
# 653694             0              0    64280.0           0.00
# 485688             0              0   137480.0           0.00
# ...              ...            ...        ...            ...
# 1202685            0              1    38680.0         -19.34
# 670176             1              1  2167760.0           1.00
# 1131211            1              1  1089580.0        -544.79
# 90178              1              1   628720.0        -314.36
# 670559             1              1   717960.0        -358.98
#
#          y_predicted_decoded  y_predicted_proba_log  TN       FN  FP  TP  \
# 377359                     0               0.136093   0   -62.63  -1   1
# 343471                     0               0.013334   0   -67.01  -1   1
# 858312                     0               0.249659   0   -17.55  -1   1
# 653694                     0               0.241324   0   -32.14  -1   1
# 485688                     0               0.326600   0   -68.74  -1   1
# ...                      ...                    ...  ..      ...  ..  ..
# 1202685                    0               0.219136   0   -19.34  -1   1
# 670176                     1               0.997513   0 -1083.88  -1   1
# 1131211                    1               0.953016   0  -544.79  -1   1
# 90178                      1               0.806133   0  -314.36  -1   1
# 670559                     1               0.911498   0  -358.98  -1   1
#
#                EAP           EP
# 377359   -0.136093    -0.005658
# 343471   -0.013334    -0.005658
# 858312   -0.249659    -0.005658
# 653694   -0.241324    -0.005658
# 485688   -0.326600    -0.005658
# ...            ...          ...
# 1202685 -14.882770   -19.224913
# 670176   -1.698163 -1077.741554
# 1131211 -24.643199  -541.701822
# 90178   -60.137808  -312.575637
# 670559  -30.858864  -356.943169
#
# [13521 rows x 27 columns]

# %% [markdown]
# # cost- curves

# %%
len(test_predictions_log['FP'])
# Out:
# 13521

# %%
total_fp_log = 0

for i in range(0,13521):
    if test_predictions_log['churn_encoded'].iloc[i] == 0 and test_predictions_log['y_predicted'].iloc[i]==1:
        total_fp_log += test_predictions_log['FP'].iloc[i]
    else:
        total_fp_log += 0

print(total_fp_log)

average_fp_log = total_fp_log/13521
print( average_fp_log)
# Out:
# 1353
# 0.10006656312402928

# %%
total_fn_log = 0

for i in range(0,13521):
    if test_predictions_log['churn_encoded'].iloc[i] == 1 and test_predictions_log['y_predicted'].iloc[i]==0:
        total_fn_log += test_predictions_log['FN'].iloc[i]
    else:
        total_fn_log += 0

print(total_fn_log)

average_fn_log = total_fn_log/13521
print( average_fn_log)
# Out:
# 192.18
# 0.014213445751053917

# %%
# C(-|+)
cost_fn_log = average_fn_log
# C(+|-)
cost_fp_log = average_fp_log

# Ground truth
truth = test_predictions_log['churn_encoded']
#  <a list of 0 (negative class) or 1 (positive class)>
# Predictions from a classifier
score = test_predictions_log['y_predicted']
# best_pipeline_log_reg.predict_proba(test.drop(y_encoded_col_name, axis=1))[:, 1]
# <a list of [0,1] class probabilities>

# %% OUTPUTS

# 1D-array of x-axis values (normalized PC)
pc = None
# list of lines as (slope, intercept)
lines = []
# lower envelope of the list of lines as a 1D-array of y-axis values (NEC)
lower_envelope = []
# area under the lower envelope (the smaller, the better)
area = None

# %% COMPUTATION

# points from the roc curve, because a point in the ROC space <=> a line in the cost space
roc_fpr, roc_tpr, _ = roc_curve(truth, score)

# compute the normalized p(+)*C(-|+)
thresholds = np.arange(0, 1.01, .01)
pc = (thresholds*cost_fn_log) / (thresholds*cost_fn_log + (1-thresholds)*cost_fp_log)

# compute a line in the cost space for each point in the roc space
for fpr, tpr in zip(roc_fpr, roc_tpr):
    slope = (1-tpr-fpr)
    intercept = fpr
    lines.append((slope, intercept))

# compute the lower envelope
for x_value in pc:
    y_value = min([slope*x_value+intercept for slope, intercept in lines])
    lower_envelope.append(max(0, y_value))
lower_envelope = np.array(lower_envelope)

# compute the area under the lower envelope using the composite trapezoidal rule
area = np.trapz(lower_envelope, pc)

# %% EXAMPLE OF PLOT

# display each line as a thin dashed line
for slope, intercept in lines:
    plt.plot(pc, slope*pc+intercept, color="grey", lw=1, linestyle="--")

# display the lower envelope as a thicker black line
plt.plot(pc, lower_envelope, color="black", lw=3, label="area={:.3f}".format(area))

# plot parameters
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05*max(lower_envelope)])
plt.xlabel("Probability Cost Function")
plt.ylabel("Normalized Expected Cost")
plt.title("Cost curve")
plt.legend(loc="lower right")

plt.show()

# %%
total_fp_xgb = 0

for i in range(0,13521):
    if test_predictions_xgb['churn_encoded'].iloc[i] == 0 and test_predictions_xgb['y_predicted'].iloc[i]==1:
        total_fp_xgb += test_predictions_xgb['FP'].iloc[i]
    else:
        total_fp_xgb += 0

print(total_fp_xgb)

average_fp_xgb = total_fp_xgb/13521
print( average_fp_xgb)
# Out:
# 150
# 0.011093854004881295

# %%
total_fn_xgb = 0

for i in range(0,13521):
    if test_predictions_xgb['churn_encoded'].iloc[i] == 1 and test_predictions_xgb['y_predicted'].iloc[i]==0:
        total_fn_xgb += test_predictions_xgb['FN'].iloc[i]
    else:
        total_fn_xgb += 0

print(total_fn_xgb)

average_fn_xgb = total_fn_xgb/13521
print( average_fn_xgb)
# Out:
# 1426.1299999999999
# 0.10547518674654241

# %%
# C(-|+)
cost_fn_xgb = average_fn_xgb
# C(+|-)
cost_fp_xgb = average_fp_xgb

# Ground truth
truth = test_predictions_xgb['churn_encoded']
#  <a list of 0 (negative class) or 1 (positive class)>
# Predictions from a classifier
score = test_predictions_xgb['y_predicted']
# best_pipeline_log_reg.predict_proba(test.drop(y_encoded_col_name, axis=1))[:, 1]
# <a list of [0,1] class probabilities>

# %% OUTPUTS

# 1D-array of x-axis values (normalized PC)
pc = None
# list of lines as (slope, intercept)
lines = []
# lower envelope of the list of lines as a 1D-array of y-axis values (NEC)
lower_envelope = []
# area under the lower envelope (the smaller, the better)
area = None

# %% COMPUTATION

# points from the roc curve, because a point in the ROC space <=> a line in the cost space
roc_fpr, roc_tpr, _ = roc_curve(truth, score)

# compute the normalized p(+)*C(-|+)
thresholds = np.arange(0, 1.01, .01)
pc = (thresholds*cost_fn_xgb) / (thresholds*cost_fn_xgb + (1-thresholds)*cost_fp_xgb)

# compute a line in the cost space for each point in the roc space
for fpr, tpr in zip(roc_fpr, roc_tpr):
    slope = (1-tpr-fpr)
    intercept = fpr
    lines.append((slope, intercept))

# compute the lower envelope
for x_value in pc:
    y_value = min([slope*x_value+intercept for slope, intercept in lines])
    lower_envelope.append(max(0, y_value))
lower_envelope = np.array(lower_envelope)

# compute the area under the lower envelope using the composite trapezoidal rule
area = np.trapz(lower_envelope, pc)

# %% EXAMPLE OF PLOT

# display each line as a thin dashed line
for slope, intercept in lines:
    plt.plot(pc, slope*pc+intercept, color="grey", lw=1, linestyle="--")

# display the lower envelope as a thicker black line
plt.plot(pc, lower_envelope, color="black", lw=3, label="area={:.3f}".format(area))

# plot parameters
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05*max(lower_envelope)])
plt.xlabel("Probability Cost Function")
plt.ylabel("Normalized Expected Cost")
plt.title("Cost curve")
plt.legend(loc="lower right")

plt.show()

# %% [markdown]
# # from here on we calculate the amc, e-amc, mp and emp but with the churn prediction cost and benefit matrices

# %% [markdown]
# # total cost 50% decision threshold

# %%
test_predictions_log_churn = test.copy(deep=True)
test_predictions_log_churn["y_predicted"] = best_pipeline_log_reg.predict(test_predictions_log_churn.drop(y, axis=1))
test_predictions_log_churn["churn_encoded"] = fit_le.transform(test_predictions_log_churn["is_fraud"])

# first check if customers have multiple rows => if so check if we can take other if this instance-based cost
impute = SimpleImputer(strategy='median')
test_predictions_log_churn['A'] = impute.fit_transform(
    (test_predictions_log["amt"]).to_frame())[:, 0]
# scaler = MinMaxScaler()

# Fit and transform the cb_cyolumn using the scaler
# test_predictions_log['A'] = scaler.fit_transform(test_predictions_log['A'].values.reshape(-1, 1))


# Step 3: Apply the function to calculate the cost for each instance and create the instance-dependent cost matrix
test_predictions_log_churn['instance_cost'] = test_predictions_log_churn.apply(lambda row: instance_dependent_cost_churn(
    row['y_predicted'], row["churn_encoded"], row["A"]), axis=1)

test_predictions_log_churn["y_predicted_decoded"] = fit_le.inverse_transform(
    test_predictions_log_churn["y_predicted"])

# Print the DataFrame with the instance-dependent cost matrix
test_predictions_log_churn[['is_fraud', 'y_predicted_decoded', "A", 'instance_cost']]

print(f"Test cost/loss = {test_predictions_log_churn['instance_cost'].sum():.0f}.")
print(' total cost/loss average : ' , test_predictions_log_churn['instance_cost'].sum()/len(test_predictions_log_churn))
# Out:
# Test cost/loss = 207248.
#  total cost/loss average :  15.327870719621329

# %%
test_predictions_xgb_churn = test.copy(deep=True)
test_predictions_xgb_churn["y_predicted"] = best_pipeline_xgb.predict(test_predictions_xgb_churn.drop(y, axis=1))
test_predictions_xgb_churn["churn_encoded"] = fit_le.transform(test_predictions_xgb_churn["is_fraud"])

# first check if customers have multiple rows => if so check if we can take other if this instance-based cost
impute = SimpleImputer(strategy='median')
test_predictions_xgb_churn['A'] = impute.fit_transform(
    (test_predictions_xgb_churn["amt"]).to_frame())[:, 0]
# scaler = MinMaxScaler()

# # Fit and transform the cb_column using the scaler
# test_predictions_xgb_churn['A'] = scaler.fit_transform(test_predictions_xgb_churn['A'].values.reshape(-1, 1))


# Step 3: Apply the function to calculate the cost for each instance and create the instance-dependent cost matrix
test_predictions_xgb_churn['instance_cost'] = test_predictions_xgb_churn.apply(lambda row: instance_dependent_cost_churn(
    row['y_predicted'], row["churn_encoded"], row["A"]), axis=1)

test_predictions_xgb_churn["y_predicted_decoded"] = fit_le.inverse_transform(
    test_predictions_xgb_churn["y_predicted"])

# Print the DataFrame with the instance-dependent cost matrix
test_predictions_xgb_churn[['is_fraud', 'y_predicted_decoded', "A", 'instance_cost']]

print(f"Test cost/loss = {test_predictions_xgb_churn['instance_cost'].sum():.0f}.")
print(' total cost/loss average : ' , test_predictions_xgb_churn['instance_cost'].sum()/len(test_predictions_xgb_churn))
# Out:
# Test cost/loss = 146872.
#  total cost/loss average :  10.86247614821389

# %% [markdown]
# # amc metric

# %%
cb_column = 'A'
test_predictions_log_churn['y_predicted_proba_log']= best_pipeline_log_reg.predict_proba(test_predictions_log_churn.drop(y, axis=1))[:, 1]
best_threshold_log, AMC_log, lowest_cost_log = compute_best_threshold(test_predictions_log_churn, best_pipeline_log_reg, y,cb_column, y_predicted_proba_col_name="y_predicted_proba_log", instance_dependent_cost_type = 'churn')
# Out:
# Decision Threshold: 0.01, Test cost/loss = 1647755.38
# Decision Threshold: 0.02, Test cost/loss = 1552624.50
# Decision Threshold: 0.03, Test cost/loss = 1492377.86
# Decision Threshold: 0.04, Test cost/loss = 1446588.22
# Decision Threshold: 0.05, Test cost/loss = 1409276.92
# Decision Threshold: 0.06, Test cost/loss = 1382461.00
# Decision Threshold: 0.07, Test cost/loss = 1348587.88
# Decision Threshold: 0.08, Test cost/loss = 1318313.22
# Decision Threshold: 0.09, Test cost/loss = 1288452.30
# Decision Threshold: 0.10, Test cost/loss = 1256554.10
# Decision Threshold: 0.11, Test cost/loss = 1225492.30
# Decision Threshold: 0.12, Test cost/loss = 1193689.20
# Decision Threshold: 0.13, Test cost/loss = 1157381.16
# Decision Threshold: 0.14, Test cost/loss = 1125742.56
# Decision Threshold: 0.15, Test cost/loss = 1084580.26
# Decision Threshold: 0.16, Test cost/loss = 1042590.66
# Decision Threshold: 0.17, Test cost/loss = 1007048.44
# Decision Threshold: 0.18, Test cost/loss = 974905.84
# Decision Threshold: 0.19, Test cost/loss = 942488.18
# Decision Threshold: 0.20, Test cost/loss = 907942.14
# Decision Threshold: 0.21, Test cost/loss = 873148.66
# Decision Threshold: 0.22, Test cost/loss = 845983.18
# Decision Threshold: 0.23, Test cost/loss = 807881.86
# Decision Threshold: 0.24, Test cost/loss = 775811.94
# Decision Threshold: 0.25, Test cost/loss = 749141.36
# Decision Threshold: 0.26, Test cost/loss = 722995.12
# Decision Threshold: 0.27, Test cost/loss = 693320.00
# Decision Threshold: 0.28, Test cost/loss = 664641.34
# Decision Threshold: 0.29, Test cost/loss = 637401.78
# Decision Threshold: 0.30, Test cost/loss = 604611.36
# Decision Threshold: 0.31, Test cost/loss = 579120.62
# Decision Threshold: 0.32, Test cost/loss = 557766.50
# Decision Threshold: 0.33, Test cost/loss = 540740.58
# Decision Threshold: 0.34, Test cost/loss = 514512.36
# Decision Threshold: 0.35, Test cost/loss = 489740.38
# Decision Threshold: 0.36, Test cost/loss = 468595.62
# Decision Threshold: 0.37, Test cost/loss = 444627.86
# Decision Threshold: 0.38, Test cost/loss = 419071.96
# Decision Threshold: 0.39, Test cost/loss = 398064.12
# Decision Threshold: 0.40, Test cost/loss = 381091.78
# Decision Threshold: 0.41, Test cost/loss = 363104.68
# Decision Threshold: 0.42, Test cost/loss = 342942.90
# Decision Threshold: 0.43, Test cost/loss = 324963.80
# Decision Threshold: 0.44, Test cost/loss = 304393.42
# Decision Threshold: 0.45, Test cost/loss = 289990.50
# Decision Threshold: 0.46, Test cost/loss = 269935.10
# Decision Threshold: 0.47, Test cost/loss = 252869.00
# Decision Threshold: 0.48, Test cost/loss = 234475.28
# Decision Threshold: 0.49, Test cost/loss = 220390.94
# Decision Threshold: 0.50, Test cost/loss = 207248.14
# Decision Threshold: 0.51, Test cost/loss = 195813.38
# Decision Threshold: 0.52, Test cost/loss = 180693.46
# Decision Threshold: 0.53, Test cost/loss = 167289.20
# Decision Threshold: 0.54, Test cost/loss = 158873.14
# Decision Threshold: 0.55, Test cost/loss = 147802.78
# Decision Threshold: 0.56, Test cost/loss = 137027.74
# Decision Threshold: 0.57, Test cost/loss = 130391.40
# Decision Threshold: 0.58, Test cost/loss = 124654.58
# Decision Threshold: 0.59, Test cost/loss = 116072.18
# Decision Threshold: 0.60, Test cost/loss = 109795.42
# Decision Threshold: 0.61, Test cost/loss = 100442.96
# Decision Threshold: 0.62, Test cost/loss = 97382.68
# Decision Threshold: 0.63, Test cost/loss = 90660.50
# Decision Threshold: 0.64, Test cost/loss = 85486.00
# Decision Threshold: 0.65, Test cost/loss = 69573.16
# Decision Threshold: 0.66, Test cost/loss = 66522.64
# Decision Threshold: 0.67, Test cost/loss = 60857.96
# Decision Threshold: 0.68, Test cost/loss = 58190.40
# Decision Threshold: 0.69, Test cost/loss = 55999.44
# Decision Threshold: 0.70, Test cost/loss = 53836.18
# Decision Threshold: 0.71, Test cost/loss = 51812.28
# Decision Threshold: 0.72, Test cost/loss = 51242.48
# Decision Threshold: 0.73, Test cost/loss = 47628.68
# Decision Threshold: 0.74, Test cost/loss = 44402.24
# Decision Threshold: 0.75, Test cost/loss = 41148.00
# Decision Threshold: 0.76, Test cost/loss = 39844.72
# Decision Threshold: 0.77, Test cost/loss = 40767.20
# Decision Threshold: 0.78, Test cost/loss = 39396.50
# Decision Threshold: 0.79, Test cost/loss = 38362.80
# Decision Threshold: 0.80, Test cost/loss = 38504.28
# Decision Threshold: 0.81, Test cost/loss = 38267.04
# Decision Threshold: 0.82, Test cost/loss = 37428.20
# Decision Threshold: 0.83, Test cost/loss = 40728.60
# Decision Threshold: 0.84, Test cost/loss = 41302.12
# Decision Threshold: 0.85, Test cost/loss = 41576.52
# Decision Threshold: 0.86, Test cost/loss = 41644.28
# Decision Threshold: 0.87, Test cost/loss = 41451.48
# Decision Threshold: 0.88, Test cost/loss = 40822.02
# Decision Threshold: 0.89, Test cost/loss = 40382.12
# Decision Threshold: 0.90, Test cost/loss = 39966.34
# Decision Threshold: 0.91, Test cost/loss = 40922.58
# Decision Threshold: 0.92, Test cost/loss = 39895.44
# Decision Threshold: 0.93, Test cost/loss = 40594.00
# Decision Threshold: 0.94, Test cost/loss = 39626.02
# Decision Threshold: 0.95, Test cost/loss = 39108.26
# Decision Threshold: 0.96, Test cost/loss = 40247.38
# Decision Threshold: 0.97, Test cost/loss = 38990.98
# Decision Threshold: 0.98, Test cost/loss = 36840.72
# Decision Threshold: 0.99, Test cost/loss = 38671.22
# Best Decision Threshold: 0.98, Lowest Test cost/loss = 36840.72, Lowest AMC = 2.72

# %%
test_predictions_xgb_churn['y_predicted_proba_xgb']= best_pipeline_xgb.predict_proba(test_predictions_xgb_churn.drop(y, axis=1))[:, 1]
best_threshold_xgb, AMC_xgb, lowest_cost_xgb = compute_best_threshold(test_predictions_xgb_churn, best_pipeline_xgb, y, cb_column, y_predicted_proba_col_name="y_predicted_proba_xgb", instance_dependent_cost_type= 'churn' )
# Out:
# Decision Threshold: 0.01, Test cost/loss = 1112386.46
# Decision Threshold: 0.02, Test cost/loss = 911730.62
# Decision Threshold: 0.03, Test cost/loss = 781820.40
# Decision Threshold: 0.04, Test cost/loss = 697635.06
# Decision Threshold: 0.05, Test cost/loss = 616206.48
# Decision Threshold: 0.06, Test cost/loss = 556893.18
# Decision Threshold: 0.07, Test cost/loss = 513857.26
# Decision Threshold: 0.08, Test cost/loss = 474096.74
# Decision Threshold: 0.09, Test cost/loss = 448114.74
# Decision Threshold: 0.10, Test cost/loss = 423380.84
# Decision Threshold: 0.11, Test cost/loss = 393278.30
# Decision Threshold: 0.12, Test cost/loss = 377682.90
# Decision Threshold: 0.13, Test cost/loss = 355659.10
# Decision Threshold: 0.14, Test cost/loss = 341123.32
# Decision Threshold: 0.15, Test cost/loss = 329090.08
# Decision Threshold: 0.16, Test cost/loss = 317623.38
# Decision Threshold: 0.17, Test cost/loss = 303268.40
# Decision Threshold: 0.18, Test cost/loss = 293065.98
# Decision Threshold: 0.19, Test cost/loss = 290161.40
# Decision Threshold: 0.20, Test cost/loss = 281756.80
# Decision Threshold: 0.21, Test cost/loss = 272440.56
# Decision Threshold: 0.22, Test cost/loss = 264834.22
# Decision Threshold: 0.23, Test cost/loss = 259306.72
# Decision Threshold: 0.24, Test cost/loss = 251530.98
# Decision Threshold: 0.25, Test cost/loss = 246483.40
# Decision Threshold: 0.26, Test cost/loss = 236530.70
# Decision Threshold: 0.27, Test cost/loss = 230016.80
# Decision Threshold: 0.28, Test cost/loss = 225420.98
# Decision Threshold: 0.29, Test cost/loss = 220240.22
# Decision Threshold: 0.30, Test cost/loss = 214282.50
# Decision Threshold: 0.31, Test cost/loss = 211623.52
# Decision Threshold: 0.32, Test cost/loss = 207622.06
# Decision Threshold: 0.33, Test cost/loss = 200517.14
# Decision Threshold: 0.34, Test cost/loss = 191118.26
# Decision Threshold: 0.35, Test cost/loss = 187222.22
# Decision Threshold: 0.36, Test cost/loss = 185020.12
# Decision Threshold: 0.37, Test cost/loss = 180323.68
# Decision Threshold: 0.38, Test cost/loss = 175202.34
# Decision Threshold: 0.39, Test cost/loss = 172462.10
# Decision Threshold: 0.40, Test cost/loss = 170264.92
# Decision Threshold: 0.41, Test cost/loss = 168010.66
# Decision Threshold: 0.42, Test cost/loss = 165505.48
# Decision Threshold: 0.43, Test cost/loss = 163937.42
# Decision Threshold: 0.44, Test cost/loss = 159851.02
# Decision Threshold: 0.45, Test cost/loss = 155432.14
# Decision Threshold: 0.46, Test cost/loss = 153533.30
# Decision Threshold: 0.47, Test cost/loss = 149112.18
# Decision Threshold: 0.48, Test cost/loss = 148086.38
# Decision Threshold: 0.49, Test cost/loss = 147475.66
# Decision Threshold: 0.50, Test cost/loss = 146871.54
# Decision Threshold: 0.51, Test cost/loss = 145477.60
# Decision Threshold: 0.52, Test cost/loss = 144274.48
# Decision Threshold: 0.53, Test cost/loss = 142949.78
# Decision Threshold: 0.54, Test cost/loss = 142054.38
# Decision Threshold: 0.55, Test cost/loss = 140422.82
# Decision Threshold: 0.56, Test cost/loss = 147691.18
# Decision Threshold: 0.57, Test cost/loss = 154800.44
# Decision Threshold: 0.58, Test cost/loss = 152670.64
# Decision Threshold: 0.59, Test cost/loss = 150116.30
# Decision Threshold: 0.60, Test cost/loss = 147644.68
# Decision Threshold: 0.61, Test cost/loss = 146013.44
# Decision Threshold: 0.62, Test cost/loss = 145728.26
# Decision Threshold: 0.63, Test cost/loss = 144667.64
# Decision Threshold: 0.64, Test cost/loss = 144667.64
# Decision Threshold: 0.65, Test cost/loss = 144323.88
# Decision Threshold: 0.66, Test cost/loss = 142336.70
# Decision Threshold: 0.67, Test cost/loss = 139161.28
# Decision Threshold: 0.68, Test cost/loss = 132998.82
# Decision Threshold: 0.69, Test cost/loss = 130164.78
# Decision Threshold: 0.70, Test cost/loss = 143960.04
# Decision Threshold: 0.71, Test cost/loss = 137763.66
# Decision Threshold: 0.72, Test cost/loss = 135990.88
# Decision Threshold: 0.73, Test cost/loss = 131398.38
# Decision Threshold: 0.74, Test cost/loss = 131025.02
# Decision Threshold: 0.75, Test cost/loss = 126882.70
# Decision Threshold: 0.76, Test cost/loss = 125887.90
# Decision Threshold: 0.77, Test cost/loss = 131619.34
# Decision Threshold: 0.78, Test cost/loss = 136460.00
# Decision Threshold: 0.79, Test cost/loss = 135075.88
# Decision Threshold: 0.80, Test cost/loss = 133320.72
# Decision Threshold: 0.81, Test cost/loss = 137414.32
# Decision Threshold: 0.82, Test cost/loss = 136551.66
# Decision Threshold: 0.83, Test cost/loss = 136551.66
# Decision Threshold: 0.84, Test cost/loss = 136108.06
# Decision Threshold: 0.85, Test cost/loss = 133435.26
# Decision Threshold: 0.86, Test cost/loss = 135596.94
# Decision Threshold: 0.87, Test cost/loss = 132074.02
# Decision Threshold: 0.88, Test cost/loss = 134771.60
# Decision Threshold: 0.89, Test cost/loss = 134771.60
# Decision Threshold: 0.90, Test cost/loss = 132487.48
# Decision Threshold: 0.91, Test cost/loss = 132487.48
# Decision Threshold: 0.92, Test cost/loss = 129365.12
# Decision Threshold: 0.93, Test cost/loss = 127577.00
# Decision Threshold: 0.94, Test cost/loss = 125132.96
# Decision Threshold: 0.95, Test cost/loss = 122059.78
# Decision Threshold: 0.96, Test cost/loss = 123438.02
# Decision Threshold: 0.97, Test cost/loss = 122960.24
# Decision Threshold: 0.98, Test cost/loss = 133618.54
# Decision Threshold: 0.99, Test cost/loss = 170674.16
# Best Decision Threshold: 0.95, Lowest Test cost/loss = 122059.78, Lowest AMC = 9.03

# %% [markdown]
# # E-amc metric

# %%
test_predictions_log_churn = add_eap_ep(
    train=train, 
    test=test_predictions_log_churn, 
    y_col_name=y, 
    best_pipeline=best_pipeline_log_reg, 
    cb_column=cb_column, 
    predicted_proba_col_name='y_predicted_proba_log', 
    churn_label= 1, 
    instance_dependent_cost_type="churn")
test_predictions_xgb_churn = add_eap_ep(
    train=train, 
    test=test_predictions_xgb_churn, 
    y_col_name=y, 
    best_pipeline=best_pipeline_xgb, 
    cb_column=cb_column, 
    predicted_proba_col_name="y_predicted_proba_xgb", 
    churn_label=1, 
    instance_dependent_cost_type="churn")
# Out:
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:329: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_0['EAP'] = test_actual_label_0[predicted_proba_col_name]*test_actual_label_0['FP'] + \
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:331: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_0['EP'] = estimated_p_1*test_actual_label_0['FP']+estimated_p_0*test_actual_label_0['TN']
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:333: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_1['EAP'] = test_actual_label_1[predicted_proba_col_name]*test_actual_label_1['TP'] + \
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:335: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_1['EP'] = estimated_p_1 * test_actual_label_1['TP'] + estimated_p_0 * test_actual_label_1['FN']
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:329: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_0['EAP'] = test_actual_label_0[predicted_proba_col_name]*test_actual_label_0['FP'] + \
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:331: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_0['EP'] = estimated_p_1*test_actual_label_0['FP']+estimated_p_0*test_actual_label_0['TN']
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:333: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_1['EAP'] = test_actual_label_1[predicted_proba_col_name]*test_actual_label_1['TP'] + \
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:335: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_1['EP'] = estimated_p_1 * test_actual_label_1['TP'] + estimated_p_0 * test_actual_label_1['FN']

# %%
test_predictions_log_churn
# Out:
#                       cc_num        category      amt gender state  city_pop  \
# 377359      3540210836308425     food_dining    62.63      M    TX        53
# 343471          639030014711   entertainment    67.01      M    IL       639
# 858312       377264520876399   personal_care    17.55      F    SC      4424
# 653694       213157767990030  health_fitness    32.14      F    WY     27971
# 485688        30408301059761       kids_pets    68.74      M    SC      4471
# ...                      ...             ...      ...    ...   ...       ...
# 1202685      374821819075109  health_fitness    19.34      M    NY      9565
# 670176      4266200684857219    shopping_net  1083.88      M    NE       732
# 1131211  4810789809665942990   entertainment   544.79      F    OH       338
# 90178          4195740185974     grocery_pos   314.36      M    OR    841711
# 670559      6011542681743618     grocery_pos   358.98      F    VA       863
#
#                                     job   unix_time  is_fraud     lat_x  \
# 377359                Fisheries officer  1384536888         0  0.386883
# 343471              Mechanical engineer  1383260389         0  0.374299
# 858312                           Lawyer  1355689325         0 -0.370872
# 653694                  Music therapist  1349466301         0  0.539446
# 485688           Occupational hygienist  1343748738         0 -0.025769
# ...                                 ...         ...       ...       ...
# 1202685             Exhibition designer  1368835137         1 -0.151494
# 670176   Television/film/video producer  1350086058         1  0.624315
# 1131211               Quantity surveyor  1366066429         1  0.134441
# 90178       Engineer, building services  1374463871         1 -0.022418
# 670559                 Engineer, mining  1350099543         1 -0.432334
#
#            long_y     lat_z  merch_lat_x  merch_long_y  merch_lat_z  \
# 377359   0.903359 -0.185107     0.974763      0.171631    -0.142757
# 343471  -0.790767 -0.484343    -0.101118     -0.751755    -0.651644
# 858312  -0.903818  0.213464    -0.117634     -0.817296    -0.564083
# 653694   0.478639 -0.692750    -0.001038     -0.002552    -0.999996
# 485688  -0.341624  0.939483     0.190030     -0.354266     0.915633
# ...           ...       ...          ...           ...          ...
# 1202685 -0.586493 -0.795660     0.420107     -0.862442    -0.282320
# 670176  -0.503856  0.596958     0.691758      0.004403     0.722116
# 1131211  0.269255  0.953639    -0.021650      0.099756     0.994776
# 90178    0.004107  0.999740    -0.325970     -0.031024     0.944871
# 670559   0.104784  0.895604    -0.223838     -0.005511     0.974611
#
#          y_predicted  churn_encoded       A  instance_cost  \
# 377359             0              0   62.63           0.00
# 343471             0              0   67.01           0.00
# 858312             0              0   17.55           0.00
# 653694             0              0   32.14           0.00
# 485688             0              0   68.74           0.00
# ...              ...            ...     ...            ...
# 1202685            0              1  153.09        1837.08
# 670176             1              1   52.01           0.00
# 1131211            1              1  148.83        1785.96
# 90178              1              1   87.86        1054.32
# 670559             1              1   84.80        1017.60
#
#          y_predicted_decoded  y_predicted_proba_log  TN       FN      FP  TP  \
# 377359                     0               0.136093   0   751.56  125.26   0
# 343471                     0               0.013334   0   804.12  134.02   0
# 858312                     0               0.249659   0   210.60   35.10   0
# 653694                     0               0.241324   0   385.68   64.28   0
# 485688                     0               0.326600   0   824.88  137.48   0
# ...                      ...                    ...  ..      ...     ...  ..
# 1202685                    0               0.219136   0  1837.08  306.18   0
# 670176                     1               0.997513   0   624.12  104.02   0
# 1131211                    1               0.953016   0  1785.96  297.66   0
# 90178                      1               0.806133   0  1054.32  175.72   0
# 670559                     1               0.911498   0  1017.60  169.60   0
#
#                  EAP           EP
# 377359     17.047046     0.708744
# 343471      1.786973     0.758309
# 858312      8.763031     0.198602
# 653694     15.512296     0.363708
# 485688     44.900917     0.777887
# ...              ...          ...
# 1202685  1434.509295  1826.685472
# 670176      1.552224   620.588617
# 1131211    83.910895  1775.854718
# 90178     204.397556  1048.354468
# 670559     90.059391  1011.842237
#
# [13521 rows x 27 columns]

# %%
test_predictions_xgb_churn
# Out:
#                       cc_num        category      amt gender state  city_pop  \
# 377359      3540210836308425     food_dining    62.63      M    TX        53
# 343471          639030014711   entertainment    67.01      M    IL       639
# 858312       377264520876399   personal_care    17.55      F    SC      4424
# 653694       213157767990030  health_fitness    32.14      F    WY     27971
# 485688        30408301059761       kids_pets    68.74      M    SC      4471
# ...                      ...             ...      ...    ...   ...       ...
# 1202685      374821819075109  health_fitness    19.34      M    NY      9565
# 670176      4266200684857219    shopping_net  1083.88      M    NE       732
# 1131211  4810789809665942990   entertainment   544.79      F    OH       338
# 90178          4195740185974     grocery_pos   314.36      M    OR    841711
# 670559      6011542681743618     grocery_pos   358.98      F    VA       863
#
#                                     job   unix_time  is_fraud     lat_x  \
# 377359                Fisheries officer  1384536888         0  0.386883
# 343471              Mechanical engineer  1383260389         0  0.374299
# 858312                           Lawyer  1355689325         0 -0.370872
# 653694                  Music therapist  1349466301         0  0.539446
# 485688           Occupational hygienist  1343748738         0 -0.025769
# ...                                 ...         ...       ...       ...
# 1202685             Exhibition designer  1368835137         1 -0.151494
# 670176   Television/film/video producer  1350086058         1  0.624315
# 1131211               Quantity surveyor  1366066429         1  0.134441
# 90178       Engineer, building services  1374463871         1 -0.022418
# 670559                 Engineer, mining  1350099543         1 -0.432334
#
#            long_y     lat_z  merch_lat_x  merch_long_y  merch_lat_z  \
# 377359   0.903359 -0.185107     0.974763      0.171631    -0.142757
# 343471  -0.790767 -0.484343    -0.101118     -0.751755    -0.651644
# 858312  -0.903818  0.213464    -0.117634     -0.817296    -0.564083
# 653694   0.478639 -0.692750    -0.001038     -0.002552    -0.999996
# 485688  -0.341624  0.939483     0.190030     -0.354266     0.915633
# ...           ...       ...          ...           ...          ...
# 1202685 -0.586493 -0.795660     0.420107     -0.862442    -0.282320
# 670176  -0.503856  0.596958     0.691758      0.004403     0.722116
# 1131211  0.269255  0.953639    -0.021650      0.099756     0.994776
# 90178    0.004107  0.999740    -0.325970     -0.031024     0.944871
# 670559   0.104784  0.895604    -0.223838     -0.005511     0.974611
#
#          y_predicted  churn_encoded        A  instance_cost  \
# 377359             0              0    62.63           0.00
# 343471             0              0    67.01           0.00
# 858312             0              0    17.55           0.00
# 653694             0              0    32.14           0.00
# 485688             0              0    68.74           0.00
# ...              ...            ...      ...            ...
# 1202685            0              1    19.34         232.08
# 670176             1              1  1083.88           0.00
# 1131211            1              1   544.79        6537.48
# 90178              1              1   314.36        3772.32
# 670559             1              1   358.98           0.00
#
#          y_predicted_decoded  y_predicted_proba_xgb  TN        FN       FP  \
# 377359                     0               0.030850   0    751.56   125.26
# 343471                     0               0.000839   0    804.12   134.02
# 858312                     0               0.139900   0    210.60    35.10
# 653694                     0               0.133361   0    385.68    64.28
# 485688                     0               0.008483   0    824.88   137.48
# ...                      ...                    ...  ..       ...      ...
# 1202685                    0               0.009055   0    232.08    38.68
# 670176                     1               0.995325   0  13006.56  2167.76
# 1131211                    1               0.767989   0   6537.48  1089.58
# 90178                      1               0.874957   0   3772.32   628.72
# 670559                     1               0.991703   0   4307.76   717.96
#
#          TP          EAP            EP
# 377359    0     3.864284      0.708744
# 343471    0     0.112477      0.758309
# 858312    0     4.910475      0.198602
# 653694    0     8.572444      0.363708
# 485688    0     1.166282      0.777887
# ...      ..          ...           ...
# 1202685   0   229.978484    230.766850
# 670176    0    60.810719  12932.966550
# 1131211   0  1516.767404   6500.489765
# 90178     0   471.703689   3750.975537
# 670559    0    35.742624   4283.385921
#
# [13521 rows x 27 columns]

# %%
print(test_predictions_log_churn['EAP'].sum())
print(test_predictions_log_churn['EP'].sum())


print('EAP : ', test_predictions_log_churn['EAP'].sum()/len(test_predictions_log_churn))
print('EP : ', test_predictions_log_churn['EP'].sum()/len(test_predictions_log_churn))
# Out:
# 441431.2066873113
# 52192.918708603764
# EAP :  32.64782240125074
# EP :  3.8601374682792517

# %%
print(test_predictions_xgb_churn['EAP'].sum())
print(test_predictions_xgb_churn['EP'].sum())


print('EAP : ', test_predictions_xgb_churn['EAP'].sum()/len(test_predictions_xgb_churn))
print('EP : ', test_predictions_xgb_churn['EP'].sum()/len(test_predictions_xgb_churn))
# Out:
# 233646.78379566816
# 330540.7564985855
# EAP :  17.28028872092805
# EP :  24.446472635055507

# %% [markdown]
# # mp at 50% threshold

# %%
test_predictions_log_churn_2 = test.copy(deep=True)
test_predictions_log_churn_2["y_predicted"] = best_pipeline_log_reg.predict(test_predictions_log_churn_2.drop(y, axis=1))
test_predictions_log_churn_2["churn_encoded"] = fit_le.transform(test_predictions_log_churn_2["is_fraud"])

# First check if customers have multiple rows => if so check if we can take other if this instance-based cost
impute = SimpleImputer(strategy='median')
test_predictions_log_churn_2['A'] = impute.fit_transform(
    (test_predictions_log_churn_2["amt"]).to_frame())[:, 0]
# Step 3: Apply the function to calculate the cost for each instance and create the instance-dependent cost matrix
test_predictions_log_churn_2['instance_cost'] = test_predictions_log_churn_2.apply(lambda row: instance_dependent_cost_churn_2(
    row['y_predicted'], row["churn_encoded"], row["A"]), axis=1)

test_predictions_log_churn_2["y_predicted_decoded"] = fit_le.inverse_transform(
    test_predictions_log_churn_2["y_predicted"])

# Print the DataFrame with the instance-dependent cost matrix
test_predictions_log_churn_2[['is_fraud', 'y_predicted_decoded', "A", 'instance_cost']]

print(f"Test cost/loss = {test_predictions_log_churn_2['instance_cost'].sum():.0f}.")
print(' total cost/loss average : ' , test_predictions_log_churn_2['instance_cost'].sum()/len(test_predictions_log_churn_2))
# Out:
# Test cost/loss = -532280.
#  total cost/loss average :  -39.36690185637157

# %%
test_predictions_xgb_churn_2 = test.copy(deep=True)
test_predictions_xgb_churn_2["y_predicted"] = best_pipeline_xgb.predict(test_predictions_xgb_churn_2.drop(y, axis=1))
test_predictions_xgb_churn_2["churn_encoded"] = fit_le.transform(test_predictions_xgb_churn_2["is_fraud"])

# First check if customers have multiple rows => if so check if we can take other if this instance-based cost
impute = SimpleImputer(strategy='median')
test_predictions_xgb_churn_2['A'] = impute.fit_transform(
    (test_predictions_xgb_churn_2["amt"]).to_frame())[:, 0]

# Step 3: Apply the function to calculate the cost for each instance and create the instance-dependent cost matrix
test_predictions_xgb_churn_2['instance_cost'] = test_predictions_xgb_churn_2.apply(lambda row: instance_dependent_cost_churn_2(
    row['y_predicted'], row["churn_encoded"], row["A"]), axis=1)

test_predictions_xgb_churn_2["y_predicted_decoded"] = fit_le.inverse_transform(
    test_predictions_xgb_churn_2["y_predicted"])

# Print the DataFrame with the instance-dependent cost matrix
test_predictions_xgb_churn_2[['is_fraud', 'y_predicted_decoded', "A", 'instance_cost']]

print(f"Test cost/loss = {test_predictions_xgb_churn_2['instance_cost'].sum():.0f}.")
# Out:
# Test cost/loss = -96043.

# %% [markdown]
# # mp metric

# %%
cb_column = 'A'
test_predictions_log_churn_2['y_predicted_proba_log']= best_pipeline_log_reg.predict_proba(test_predictions_log_churn_2.drop(y, axis=1))[:, 1]
best_threshold_log, AMC_log, lowest_cost_log = compute_best_threshold_2(test_predictions_log_churn_2, best_pipeline_log_reg, y,cb_column, y_predicted_proba_col_name="y_predicted_proba_log", instance_dependent_cost_type = 'churn_2')
# Out:
# Decision Threshold: 0.01, Test cost/loss = -1733341.44
# Decision Threshold: 0.02, Test cost/loss = -1680709.46
# Decision Threshold: 0.03, Test cost/loss = -1640014.56
# Decision Threshold: 0.04, Test cost/loss = -1606718.46
# Decision Threshold: 0.05, Test cost/loss = -1576117.08
# Decision Threshold: 0.06, Test cost/loss = -1547243.24
# Decision Threshold: 0.07, Test cost/loss = -1523686.58
# Decision Threshold: 0.08, Test cost/loss = -1499563.12
# Decision Threshold: 0.09, Test cost/loss = -1477360.32
# Decision Threshold: 0.10, Test cost/loss = -1460647.08
# Decision Threshold: 0.11, Test cost/loss = -1440636.82
# Decision Threshold: 0.12, Test cost/loss = -1419767.00
# Decision Threshold: 0.13, Test cost/loss = -1398577.50
# Decision Threshold: 0.14, Test cost/loss = -1377712.16
# Decision Threshold: 0.15, Test cost/loss = -1354466.02
# Decision Threshold: 0.16, Test cost/loss = -1325571.26
# Decision Threshold: 0.17, Test cost/loss = -1303885.22
# Decision Threshold: 0.18, Test cost/loss = -1277637.66
# Decision Threshold: 0.19, Test cost/loss = -1256765.10
# Decision Threshold: 0.20, Test cost/loss = -1232335.48
# Decision Threshold: 0.21, Test cost/loss = -1208347.08
# Decision Threshold: 0.22, Test cost/loss = -1186151.18
# Decision Threshold: 0.23, Test cost/loss = -1160984.90
# Decision Threshold: 0.24, Test cost/loss = -1137304.88
# Decision Threshold: 0.25, Test cost/loss = -1115764.06
# Decision Threshold: 0.26, Test cost/loss = -1091207.42
# Decision Threshold: 0.27, Test cost/loss = -1066134.34
# Decision Threshold: 0.28, Test cost/loss = -1043787.32
# Decision Threshold: 0.29, Test cost/loss = -1021662.58
# Decision Threshold: 0.30, Test cost/loss = -995562.24
# Decision Threshold: 0.31, Test cost/loss = -971911.46
# Decision Threshold: 0.32, Test cost/loss = -950190.76
# Decision Threshold: 0.33, Test cost/loss = -926500.52
# Decision Threshold: 0.34, Test cost/loss = -902479.18
# Decision Threshold: 0.35, Test cost/loss = -880781.20
# Decision Threshold: 0.36, Test cost/loss = -857267.60
# Decision Threshold: 0.37, Test cost/loss = -831348.60
# Decision Threshold: 0.38, Test cost/loss = -806836.44
# Decision Threshold: 0.39, Test cost/loss = -782844.46
# Decision Threshold: 0.40, Test cost/loss = -759427.76
# Decision Threshold: 0.41, Test cost/loss = -732166.10
# Decision Threshold: 0.42, Test cost/loss = -708543.34
# Decision Threshold: 0.43, Test cost/loss = -688544.44
# Decision Threshold: 0.44, Test cost/loss = -663232.62
# Decision Threshold: 0.45, Test cost/loss = -643584.40
# Decision Threshold: 0.46, Test cost/loss = -617146.04
# Decision Threshold: 0.47, Test cost/loss = -595555.28
# Decision Threshold: 0.48, Test cost/loss = -574021.24
# Decision Threshold: 0.49, Test cost/loss = -554838.28
# Decision Threshold: 0.50, Test cost/loss = -532279.88
# Decision Threshold: 0.51, Test cost/loss = -515150.74
# Decision Threshold: 0.52, Test cost/loss = -496450.10
# Decision Threshold: 0.53, Test cost/loss = -478141.72
# Decision Threshold: 0.54, Test cost/loss = -461329.28
# Decision Threshold: 0.55, Test cost/loss = -446877.78
# Decision Threshold: 0.56, Test cost/loss = -432493.50
# Decision Threshold: 0.57, Test cost/loss = -422129.18
# Decision Threshold: 0.58, Test cost/loss = -416012.84
# Decision Threshold: 0.59, Test cost/loss = -406585.14
# Decision Threshold: 0.60, Test cost/loss = -392239.12
# Decision Threshold: 0.61, Test cost/loss = -379930.36
# Decision Threshold: 0.62, Test cost/loss = -371052.42
# Decision Threshold: 0.63, Test cost/loss = -358939.44
# Decision Threshold: 0.64, Test cost/loss = -346420.42
# Decision Threshold: 0.65, Test cost/loss = -335256.92
# Decision Threshold: 0.66, Test cost/loss = -327808.82
# Decision Threshold: 0.67, Test cost/loss = -314195.88
# Decision Threshold: 0.68, Test cost/loss = -305662.12
# Decision Threshold: 0.69, Test cost/loss = -299200.50
# Decision Threshold: 0.70, Test cost/loss = -289414.78
# Decision Threshold: 0.71, Test cost/loss = -280038.68
# Decision Threshold: 0.72, Test cost/loss = -281370.62
# Decision Threshold: 0.73, Test cost/loss = -273443.00
# Decision Threshold: 0.74, Test cost/loss = -262982.06
# Decision Threshold: 0.75, Test cost/loss = -254109.82
# Decision Threshold: 0.76, Test cost/loss = -247776.36
# Decision Threshold: 0.77, Test cost/loss = -247863.42
# Decision Threshold: 0.78, Test cost/loss = -242802.16
# Decision Threshold: 0.79, Test cost/loss = -234975.68
# Decision Threshold: 0.80, Test cost/loss = -233951.92
# Decision Threshold: 0.81, Test cost/loss = -232987.88
# Decision Threshold: 0.82, Test cost/loss = -230133.06
# Decision Threshold: 0.83, Test cost/loss = -236415.98
# Decision Threshold: 0.84, Test cost/loss = -239700.10
# Decision Threshold: 0.85, Test cost/loss = -241834.02
# Decision Threshold: 0.86, Test cost/loss = -246587.54
# Decision Threshold: 0.87, Test cost/loss = -243478.90
# Decision Threshold: 0.88, Test cost/loss = -237131.04
# Decision Threshold: 0.89, Test cost/loss = -235602.02
# Decision Threshold: 0.90, Test cost/loss = -233496.46
# Decision Threshold: 0.91, Test cost/loss = -233453.00
# Decision Threshold: 0.92, Test cost/loss = -232636.28
# Decision Threshold: 0.93, Test cost/loss = -236264.76
# Decision Threshold: 0.94, Test cost/loss = -231176.78
# Decision Threshold: 0.95, Test cost/loss = -222564.76
# Decision Threshold: 0.96, Test cost/loss = -220349.54
# Decision Threshold: 0.97, Test cost/loss = -214602.76
# Decision Threshold: 0.98, Test cost/loss = -218612.82
# Decision Threshold: 0.99, Test cost/loss = -239404.10
# Best Decision Threshold: 0.97, Lowest Test cost/loss = -214602.76, Lowest AMC = -15.87

# %%
test_predictions_xgb_churn_2['y_predicted_proba_xgb']= best_pipeline_xgb.predict_proba(test_predictions_xgb_churn_2.drop(y, axis=1))[:, 1]
best_threshold_xgb, AMC_xgb, lowest_cost_xgb = compute_best_threshold_2(test_predictions_xgb_churn_2, best_pipeline_xgb, y, cb_column, y_predicted_proba_col_name="y_predicted_proba_xgb", instance_dependent_cost_type= 'churn_2' )
# Out:
# Decision Threshold: 0.01, Test cost/loss = -1058821.26
# Decision Threshold: 0.02, Test cost/loss = -858165.42
# Decision Threshold: 0.03, Test cost/loss = -728294.92
# Decision Threshold: 0.04, Test cost/loss = -644153.78
# Decision Threshold: 0.05, Test cost/loss = -562725.20
# Decision Threshold: 0.06, Test cost/loss = -503451.38
# Decision Threshold: 0.07, Test cost/loss = -460415.46
# Decision Threshold: 0.08, Test cost/loss = -420697.86
# Decision Threshold: 0.09, Test cost/loss = -394715.86
# Decision Threshold: 0.10, Test cost/loss = -369981.96
# Decision Threshold: 0.11, Test cost/loss = -339879.42
# Decision Threshold: 0.12, Test cost/loss = -325039.32
# Decision Threshold: 0.13, Test cost/loss = -303015.52
# Decision Threshold: 0.14, Test cost/loss = -288479.74
# Decision Threshold: 0.15, Test cost/loss = -276446.50
# Decision Threshold: 0.16, Test cost/loss = -264979.80
# Decision Threshold: 0.17, Test cost/loss = -250661.74
# Decision Threshold: 0.18, Test cost/loss = -240459.32
# Decision Threshold: 0.19, Test cost/loss = -239267.34
# Decision Threshold: 0.20, Test cost/loss = -230862.74
# Decision Threshold: 0.21, Test cost/loss = -221546.50
# Decision Threshold: 0.22, Test cost/loss = -213940.16
# Decision Threshold: 0.23, Test cost/loss = -208412.66
# Decision Threshold: 0.24, Test cost/loss = -200654.92
# Decision Threshold: 0.25, Test cost/loss = -195607.34
# Decision Threshold: 0.26, Test cost/loss = -185654.64
# Decision Threshold: 0.27, Test cost/loss = -179140.74
# Decision Threshold: 0.28, Test cost/loss = -174544.92
# Decision Threshold: 0.29, Test cost/loss = -169364.16
# Decision Threshold: 0.30, Test cost/loss = -163406.44
# Decision Threshold: 0.31, Test cost/loss = -160775.46
# Decision Threshold: 0.32, Test cost/loss = -156774.00
# Decision Threshold: 0.33, Test cost/loss = -149669.08
# Decision Threshold: 0.34, Test cost/loss = -140270.20
# Decision Threshold: 0.35, Test cost/loss = -136374.16
# Decision Threshold: 0.36, Test cost/loss = -134191.68
# Decision Threshold: 0.37, Test cost/loss = -129495.24
# Decision Threshold: 0.38, Test cost/loss = -124373.90
# Decision Threshold: 0.39, Test cost/loss = -121633.66
# Decision Threshold: 0.40, Test cost/loss = -119436.48
# Decision Threshold: 0.41, Test cost/loss = -117182.22
# Decision Threshold: 0.42, Test cost/loss = -114677.04
# Decision Threshold: 0.43, Test cost/loss = -113108.98
# Decision Threshold: 0.44, Test cost/loss = -109022.58
# Decision Threshold: 0.45, Test cost/loss = -104603.70
# Decision Threshold: 0.46, Test cost/loss = -102704.86
# Decision Threshold: 0.47, Test cost/loss = -98283.74
# Decision Threshold: 0.48, Test cost/loss = -97257.94
# Decision Threshold: 0.49, Test cost/loss = -96647.22
# Decision Threshold: 0.50, Test cost/loss = -96043.10
# Decision Threshold: 0.51, Test cost/loss = -94649.16
# Decision Threshold: 0.52, Test cost/loss = -93984.06
# Decision Threshold: 0.53, Test cost/loss = -92659.36
# Decision Threshold: 0.54, Test cost/loss = -91763.96
# Decision Threshold: 0.55, Test cost/loss = -90132.40
# Decision Threshold: 0.56, Test cost/loss = -98947.86
# Decision Threshold: 0.57, Test cost/loss = -107304.90
# Decision Threshold: 0.58, Test cost/loss = -105175.10
# Decision Threshold: 0.59, Test cost/loss = -102620.76
# Decision Threshold: 0.60, Test cost/loss = -100149.14
# Decision Threshold: 0.61, Test cost/loss = -98517.90
# Decision Threshold: 0.62, Test cost/loss = -98232.72
# Decision Threshold: 0.63, Test cost/loss = -97172.10
# Decision Threshold: 0.64, Test cost/loss = -97172.10
# Decision Threshold: 0.65, Test cost/loss = -96828.34
# Decision Threshold: 0.66, Test cost/loss = -94841.16
# Decision Threshold: 0.67, Test cost/loss = -91665.74
# Decision Threshold: 0.68, Test cost/loss = -85503.28
# Decision Threshold: 0.69, Test cost/loss = -82669.24
# Decision Threshold: 0.70, Test cost/loss = -99041.08
# Decision Threshold: 0.71, Test cost/loss = -92844.70
# Decision Threshold: 0.72, Test cost/loss = -91071.92
# Decision Threshold: 0.73, Test cost/loss = -86479.42
# Decision Threshold: 0.74, Test cost/loss = -86106.06
# Decision Threshold: 0.75, Test cost/loss = -81963.74
# Decision Threshold: 0.76, Test cost/loss = -80968.94
# Decision Threshold: 0.77, Test cost/loss = -87789.96
# Decision Threshold: 0.78, Test cost/loss = -94075.98
# Decision Threshold: 0.79, Test cost/loss = -92691.86
# Decision Threshold: 0.80, Test cost/loss = -90936.70
# Decision Threshold: 0.81, Test cost/loss = -96589.54
# Decision Threshold: 0.82, Test cost/loss = -95726.88
# Decision Threshold: 0.83, Test cost/loss = -95726.88
# Decision Threshold: 0.84, Test cost/loss = -95283.28
# Decision Threshold: 0.85, Test cost/loss = -92610.48
# Decision Threshold: 0.86, Test cost/loss = -95342.92
# Decision Threshold: 0.87, Test cost/loss = -91820.00
# Decision Threshold: 0.88, Test cost/loss = -95824.48
# Decision Threshold: 0.89, Test cost/loss = -95824.48
# Decision Threshold: 0.90, Test cost/loss = -93540.36
# Decision Threshold: 0.91, Test cost/loss = -93540.36
# Decision Threshold: 0.92, Test cost/loss = -90418.00
# Decision Threshold: 0.93, Test cost/loss = -88629.88
# Decision Threshold: 0.94, Test cost/loss = -86185.84
# Decision Threshold: 0.95, Test cost/loss = -83112.66
# Decision Threshold: 0.96, Test cost/loss = -85056.64
# Decision Threshold: 0.97, Test cost/loss = -85281.26
# Decision Threshold: 0.98, Test cost/loss = -99178.66
# Decision Threshold: 0.99, Test cost/loss = -144217.52
# Best Decision Threshold: 0.76, Lowest Test cost/loss = -80968.94, Lowest AMC = -5.99

# %% [markdown]
# # E-MP metric

# %%
test_predictions_log_churn_2 = add_eap_ep(
    train=train, 
    test=test_predictions_log_churn_2, 
    y_col_name=y, 
    best_pipeline=best_pipeline_log_reg, 
    cb_column=cb_column, 
    predicted_proba_col_name='y_predicted_proba_log', 
    churn_label= 1.0, 
    instance_dependent_cost_type="churn_2")
test_predictions_xgb_churn_2 = add_eap_ep(
    train=train, 
    test=test_predictions_xgb_churn_2, 
    y_col_name=y, 
    best_pipeline=best_pipeline_xgb, 
    cb_column=cb_column, 
    predicted_proba_col_name="y_predicted_proba_xgb", 
    churn_label=1.0, 
    instance_dependent_cost_type="churn_2")
# Out:
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:329: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_0['EAP'] = test_actual_label_0[predicted_proba_col_name]*test_actual_label_0['FP'] + \
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:331: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_0['EP'] = estimated_p_1*test_actual_label_0['FP']+estimated_p_0*test_actual_label_0['TN']
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:333: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_1['EAP'] = test_actual_label_1[predicted_proba_col_name]*test_actual_label_1['TP'] + \
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:335: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_1['EP'] = estimated_p_1 * test_actual_label_1['TP'] + estimated_p_0 * test_actual_label_1['FN']
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:329: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_0['EAP'] = test_actual_label_0[predicted_proba_col_name]*test_actual_label_0['FP'] + \
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:331: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_0['EP'] = estimated_p_1*test_actual_label_0['FP']+estimated_p_0*test_actual_label_0['TN']
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:333: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_1['EAP'] = test_actual_label_1[predicted_proba_col_name]*test_actual_label_1['TP'] + \
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:335: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_1['EP'] = estimated_p_1 * test_actual_label_1['TP'] + estimated_p_0 * test_actual_label_1['FN']

# %%
print(test_predictions_log_churn_2['EAP'].sum())
print(test_predictions_log_churn_2['EP'].sum())


print('EAP : ', test_predictions_log_churn_2['EAP'].sum()/len(test_predictions_log_churn_2))
print('EP : ', test_predictions_log_churn_2['EP'].sum()/len(test_predictions_log_churn_2))
# Out:
# -709804.8250400309
# -330237.0214677984
# EAP :  -52.49647400636276
# EP :  -24.424008687804037

# %%
print(test_predictions_xgb_churn_2['EAP'].sum())
print(test_predictions_xgb_churn_2['EP'].sum())


print('EAP : ', test_predictions_xgb_churn_2['EAP'].sum()/len(test_predictions_xgb_churn_2))
print('EP : ', test_predictions_xgb_churn_2['EP'].sum()/len(test_predictions_xgb_churn_2))
# Out:
# -186168.0855490486
# -330237.0214677984
# EAP :  -13.768810409662644
# EP :  -24.424008687804037

# %% [markdown]
# # cost curves

# %%
total_fp_log_2 = 0

for i in range(0,13521):
    if test_predictions_log_churn['churn_encoded'].iloc[i] == 0 and test_predictions_log_churn['y_predicted'].iloc[i]==1:
        total_fp_log_2 += test_predictions_log_churn['FP'].iloc[i]
    else:
        total_fp_log_2 += 0

print(total_fp_log_2)

average_fp_log_2 = total_fp_log_2/13521
print( average_fp_log_2)
# Out:
# 197001.34000000008
# 14.570027364839884

# %%
total_fn_log_2 = 0

for i in range(0,13521):
    if test_predictions_log_churn['churn_encoded'].iloc[i] == 1 and test_predictions_log_churn['y_predicted'].iloc[i]==0:
        total_fn_log_2 += test_predictions_log_churn['FN'].iloc[i]
    else:
        total_fn_log_2 += 0

print(total_fn_log_2)

average_fn_log_2 = total_fn_log_2/13521
print( average_fn_log_2)
# Out:
# 10246.8
# 0.757843354781451

# %%
cost_fn_log_2 = average_fn_log_2
# C(+|-)
cost_fp_log_2 = average_fp_log_2

# Ground truth
truth = test_predictions_log_churn['churn_encoded']
#  <a list of 0 (negative class) or 1 (positive class)>
# Predictions from a classifier
score = test_predictions_log_churn['y_predicted']
# best_pipeline_log_reg.predict_proba(test.drop(y_encoded_col_name, axis=1))[:, 1]
# <a list of [0,1] class probabilities>

# %% OUTPUTS

# 1D-array of x-axis values (normalized PC)
pc = None
# list of lines as (slope, intercept)
lines = []
# lower envelope of the list of lines as a 1D-array of y-axis values (NEC)
lower_envelope = []
# area under the lower envelope (the smaller, the better)
area = None

# %% COMPUTATION

# points from the roc curve, because a point in the ROC space <=> a line in the cost space
roc_fpr, roc_tpr, _ = roc_curve(truth, score)

# compute the normalized p(+)*C(-|+)
thresholds = np.arange(0, 1.01, .01)
pc = (thresholds*cost_fn_log_2) / (thresholds*cost_fn_log_2 + (1-thresholds)*cost_fp_log_2)

# compute a line in the cost space for each point in the roc space
for fpr, tpr in zip(roc_fpr, roc_tpr):
    slope = (1-tpr-fpr)
    intercept = fpr
    lines.append((slope, intercept))

# compute the lower envelope
for x_value in pc:
    y_value = min([slope*x_value+intercept for slope, intercept in lines])
    lower_envelope.append(max(0, y_value))
lower_envelope = np.array(lower_envelope)

# compute the area under the lower envelope using the composite trapezoidal rule
area = np.trapz(lower_envelope, pc)

# %% EXAMPLE OF PLOT

# display each line as a thin dashed line
for slope, intercept in lines:
    plt.plot(pc, slope*pc+intercept, color="grey", lw=1, linestyle="--")

# display the lower envelope as a thicker black line
plt.plot(pc, lower_envelope, color="black", lw=3, label="area={:.3f}".format(area))

# plot parameters
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05*max(lower_envelope)])
plt.xlabel("Probability Cost Function")
plt.ylabel("Normalized Expected Cost")
plt.title("Cost curve")
plt.legend(loc="lower right")

plt.show()

# %%
total_fp_xgb_2 = 0

for i in range(0,13521):
    if test_predictions_xgb_churn['churn_encoded'].iloc[i] == 0 and test_predictions_xgb_churn['y_predicted'].iloc[i]==1:
        total_fp_xgb_2 += test_predictions_xgb_churn['FP'].iloc[i]
    else:
        total_fp_xgb_2 += 0

print(total_fp_xgb_2)

average_fp_xgb_2 = total_fp_xgb_2/13521
print( average_fp_xgb_2)
# Out:
# 129757.98000000003
# 9.596773907255383

# %%
total_fn_xgb_2 = 0

for i in range(0,13521):
    if test_predictions_xgb_churn['churn_encoded'].iloc[i] == 1 and test_predictions_xgb_churn['y_predicted'].iloc[i]==0:
        total_fn_xgb_2 += test_predictions_xgb_churn['FN'].iloc[i]
    else:
        total_fn_xgb_2 += 0

print(total_fn_xgb_2)

average_fn_xgb_2 = total_fn_xgb_2/13521
print( average_fn_xgb_2)
# Out:
# 17113.56
# 1.265702240958509

# %%
#C(-|+)
cost_fn_xgb_2 = average_fn_xgb_2
# C(+|-)
cost_fp_xgb_2 = average_fp_xgb_2

# Ground truth
truth = test_predictions_xgb_churn['churn_encoded']
#  <a list of 0 (negative class) or 1 (positive class)>
# Predictions from a classifier
score = test_predictions_xgb_churn['y_predicted']
# best_pipeline_log_reg.predict_proba(test.drop(y_encoded_col_name, axis=1))[:, 1]
# <a list of [0,1] class probabilities>

# %% OUTPUTS

# 1D-array of x-axis values (normalized PC)
pc = None
# list of lines as (slope, intercept)
lines = []
# lower envelope of the list of lines as a 1D-array of y-axis values (NEC)
lower_envelope = []
# area under the lower envelope (the smaller, the better)
area = None

# %% COMPUTATION

# points from the roc curve, because a point in the ROC space <=> a line in the cost space
roc_fpr, roc_tpr, _ = roc_curve(truth, score)

# compute the normalized p(+)*C(-|+)
thresholds = np.arange(0, 1.01, .01)
pc = (thresholds*cost_fn_xgb_2) / (thresholds*cost_fn_xgb_2 + (1-thresholds)*cost_fp_xgb_2)

# compute a line in the cost space for each point in the roc space
for fpr, tpr in zip(roc_fpr, roc_tpr):
    slope = (1-tpr-fpr)
    intercept = fpr
    lines.append((slope, intercept))

# compute the lower envelope
for x_value in pc:
    y_value = min([slope*x_value+intercept for slope, intercept in lines])
    lower_envelope.append(max(0, y_value))
lower_envelope = np.array(lower_envelope)

# compute the area under the lower envelope using the composite trapezoidal rule
area = np.trapz(lower_envelope, pc)

# %% EXAMPLE OF PLOT

# display each line as a thin dashed line
for slope, intercept in lines:
    plt.plot(pc, slope*pc+intercept, color="grey", lw=1, linestyle="--")

# display the lower envelope as a thicker black line
plt.plot(pc, lower_envelope, color="black", lw=3, label="area={:.3f}".format(area))

# plot parameters
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05*max(lower_envelope)])
plt.xlabel("Probability Cost Function")
plt.ylabel("Normalized Expected Cost")
plt.title("Cost curve")
plt.legend(loc="lower right")

plt.show()

# %% [markdown]
# # from here on we calculate the amc, e-amc, mp and emp but with the churn prediction cost and benefit matrices

# %% [markdown]
# # total cost at 50% decision threshold

# %%
test_predictions_log_churn = test.copy(deep=True)
test_predictions_log_churn["y_predicted"] = best_pipeline_log_reg.predict(test_predictions_log_churn.drop(y, axis=1))
test_predictions_log_churn["churn_encoded"] = fit_le.transform(test_predictions_log_churn["is_fraud"])

# first check if customers have multiple rows => if so check if we can take other if this instance-based cost
impute = SimpleImputer(strategy='median')
test_predictions_log_churn['A'] = impute.fit_transform(
    (test_predictions_log["amt"]).to_frame())[:, 0]
# scaler = MinMaxScaler()

# Fit and transform the cb_cyolumn using the scaler
# test_predictions_log['A'] = scaler.fit_transform(test_predictions_log['A'].values.reshape(-1, 1))


# Step 3: Apply the function to calculate the cost for each instance and create the instance-dependent cost matrix
test_predictions_log_churn['instance_cost'] = test_predictions_log_churn.apply(lambda row: instance_dependent_cost_churn(
    row['y_predicted'], row["churn_encoded"], row["A"]), axis=1)

test_predictions_log_churn["y_predicted_decoded"] = fit_le.inverse_transform(
    test_predictions_log_churn["y_predicted"])

# Print the DataFrame with the instance-dependent cost matrix
test_predictions_log_churn[['is_fraud', 'y_predicted_decoded', "A", 'instance_cost']]

print(f"Test cost/loss = {test_predictions_log_churn['instance_cost'].sum():.0f}.")
print(' total cost/loss average : ' , test_predictions_log_churn['instance_cost'].sum()/len(test_predictions_log_churn))
# Out:
# Test cost/loss = 207248.
#  total cost/loss average :  15.327870719621329

# %%
test_predictions_xgb_churn = test.copy(deep=True)
test_predictions_xgb_churn["y_predicted"] = best_pipeline_xgb.predict(test_predictions_xgb_churn.drop(y, axis=1))
test_predictions_xgb_churn["churn_encoded"] = fit_le.transform(test_predictions_xgb_churn["is_fraud"])

# first check if customers have multiple rows => if so check if we can take other if this instance-based cost
impute = SimpleImputer(strategy='median')
test_predictions_xgb_churn['A'] = impute.fit_transform(
    (test_predictions_xgb_churn["amt"]).to_frame())[:, 0]
# scaler = MinMaxScaler()

# # Fit and transform the cb_column using the scaler
# test_predictions_xgb_churn['A'] = scaler.fit_transform(test_predictions_xgb_churn['A'].values.reshape(-1, 1))


# Step 3: Apply the function to calculate the cost for each instance and create the instance-dependent cost matrix
test_predictions_xgb_churn['instance_cost'] = test_predictions_xgb_churn.apply(lambda row: instance_dependent_cost_churn(
    row['y_predicted'], row["churn_encoded"], row["A"]), axis=1)

test_predictions_xgb_churn["y_predicted_decoded"] = fit_le.inverse_transform(
    test_predictions_xgb_churn["y_predicted"])

# Print the DataFrame with the instance-dependent cost matrix
test_predictions_xgb_churn[['is_fraud', 'y_predicted_decoded', "A", 'instance_cost']]

print(f"Test cost/loss = {test_predictions_xgb_churn['instance_cost'].sum():.0f}.")
print(' total cost/loss average : ' , test_predictions_xgb_churn['instance_cost'].sum()/len(test_predictions_xgb_churn))
# Out:
# Test cost/loss = 146872.
#  total cost/loss average :  10.86247614821389

# %% [markdown]
# # amc metric

# %%
cb_column = 'A'
test_predictions_log_churn['y_predicted_proba_log']= best_pipeline_log_reg.predict_proba(test_predictions_log_churn.drop(y, axis=1))[:, 1]
best_threshold_log, AMC_log, lowest_cost_log = compute_best_threshold(test_predictions_log_churn, best_pipeline_log_reg, y,cb_column, y_predicted_proba_col_name="y_predicted_proba_log", instance_dependent_cost_type = 'churn')
# Out:
# Decision Threshold: 0.01, Test cost/loss = 1647755.38
# Decision Threshold: 0.02, Test cost/loss = 1552624.50
# Decision Threshold: 0.03, Test cost/loss = 1492377.86
# Decision Threshold: 0.04, Test cost/loss = 1446588.22
# Decision Threshold: 0.05, Test cost/loss = 1409276.92
# Decision Threshold: 0.06, Test cost/loss = 1382461.00
# Decision Threshold: 0.07, Test cost/loss = 1348587.88
# Decision Threshold: 0.08, Test cost/loss = 1318313.22
# Decision Threshold: 0.09, Test cost/loss = 1288452.30
# Decision Threshold: 0.10, Test cost/loss = 1256554.10
# Decision Threshold: 0.11, Test cost/loss = 1225492.30
# Decision Threshold: 0.12, Test cost/loss = 1193689.20
# Decision Threshold: 0.13, Test cost/loss = 1157381.16
# Decision Threshold: 0.14, Test cost/loss = 1125742.56
# Decision Threshold: 0.15, Test cost/loss = 1084580.26
# Decision Threshold: 0.16, Test cost/loss = 1042590.66
# Decision Threshold: 0.17, Test cost/loss = 1007048.44
# Decision Threshold: 0.18, Test cost/loss = 974905.84
# Decision Threshold: 0.19, Test cost/loss = 942488.18
# Decision Threshold: 0.20, Test cost/loss = 907942.14
# Decision Threshold: 0.21, Test cost/loss = 873148.66
# Decision Threshold: 0.22, Test cost/loss = 845983.18
# Decision Threshold: 0.23, Test cost/loss = 807881.86
# Decision Threshold: 0.24, Test cost/loss = 775811.94
# Decision Threshold: 0.25, Test cost/loss = 749141.36
# Decision Threshold: 0.26, Test cost/loss = 722995.12
# Decision Threshold: 0.27, Test cost/loss = 693320.00
# Decision Threshold: 0.28, Test cost/loss = 664641.34
# Decision Threshold: 0.29, Test cost/loss = 637401.78
# Decision Threshold: 0.30, Test cost/loss = 604611.36
# Decision Threshold: 0.31, Test cost/loss = 579120.62
# Decision Threshold: 0.32, Test cost/loss = 557766.50
# Decision Threshold: 0.33, Test cost/loss = 540740.58
# Decision Threshold: 0.34, Test cost/loss = 514512.36
# Decision Threshold: 0.35, Test cost/loss = 489740.38
# Decision Threshold: 0.36, Test cost/loss = 468595.62
# Decision Threshold: 0.37, Test cost/loss = 444627.86
# Decision Threshold: 0.38, Test cost/loss = 419071.96
# Decision Threshold: 0.39, Test cost/loss = 398064.12
# Decision Threshold: 0.40, Test cost/loss = 381091.78
# Decision Threshold: 0.41, Test cost/loss = 363104.68
# Decision Threshold: 0.42, Test cost/loss = 342942.90
# Decision Threshold: 0.43, Test cost/loss = 324963.80
# Decision Threshold: 0.44, Test cost/loss = 304393.42
# Decision Threshold: 0.45, Test cost/loss = 289990.50
# Decision Threshold: 0.46, Test cost/loss = 269935.10
# Decision Threshold: 0.47, Test cost/loss = 252869.00
# Decision Threshold: 0.48, Test cost/loss = 234475.28
# Decision Threshold: 0.49, Test cost/loss = 220390.94
# Decision Threshold: 0.50, Test cost/loss = 207248.14
# Decision Threshold: 0.51, Test cost/loss = 195813.38
# Decision Threshold: 0.52, Test cost/loss = 180693.46
# Decision Threshold: 0.53, Test cost/loss = 167289.20
# Decision Threshold: 0.54, Test cost/loss = 158873.14
# Decision Threshold: 0.55, Test cost/loss = 147802.78
# Decision Threshold: 0.56, Test cost/loss = 137027.74
# Decision Threshold: 0.57, Test cost/loss = 130391.40
# Decision Threshold: 0.58, Test cost/loss = 124654.58
# Decision Threshold: 0.59, Test cost/loss = 116072.18
# Decision Threshold: 0.60, Test cost/loss = 109795.42
# Decision Threshold: 0.61, Test cost/loss = 100442.96
# Decision Threshold: 0.62, Test cost/loss = 97382.68
# Decision Threshold: 0.63, Test cost/loss = 90660.50
# Decision Threshold: 0.64, Test cost/loss = 85486.00
# Decision Threshold: 0.65, Test cost/loss = 69573.16
# Decision Threshold: 0.66, Test cost/loss = 66522.64
# Decision Threshold: 0.67, Test cost/loss = 60857.96
# Decision Threshold: 0.68, Test cost/loss = 58190.40
# Decision Threshold: 0.69, Test cost/loss = 55999.44
# Decision Threshold: 0.70, Test cost/loss = 53836.18
# Decision Threshold: 0.71, Test cost/loss = 51812.28
# Decision Threshold: 0.72, Test cost/loss = 51242.48
# Decision Threshold: 0.73, Test cost/loss = 47628.68
# Decision Threshold: 0.74, Test cost/loss = 44402.24
# Decision Threshold: 0.75, Test cost/loss = 41148.00
# Decision Threshold: 0.76, Test cost/loss = 39844.72
# Decision Threshold: 0.77, Test cost/loss = 40767.20
# Decision Threshold: 0.78, Test cost/loss = 39396.50
# Decision Threshold: 0.79, Test cost/loss = 38362.80
# Decision Threshold: 0.80, Test cost/loss = 38504.28
# Decision Threshold: 0.81, Test cost/loss = 38267.04
# Decision Threshold: 0.82, Test cost/loss = 37428.20
# Decision Threshold: 0.83, Test cost/loss = 40728.60
# Decision Threshold: 0.84, Test cost/loss = 41302.12
# Decision Threshold: 0.85, Test cost/loss = 41576.52
# Decision Threshold: 0.86, Test cost/loss = 41644.28
# Decision Threshold: 0.87, Test cost/loss = 41451.48
# Decision Threshold: 0.88, Test cost/loss = 40822.02
# Decision Threshold: 0.89, Test cost/loss = 40382.12
# Decision Threshold: 0.90, Test cost/loss = 39966.34
# Decision Threshold: 0.91, Test cost/loss = 40922.58
# Decision Threshold: 0.92, Test cost/loss = 39895.44
# Decision Threshold: 0.93, Test cost/loss = 40594.00
# Decision Threshold: 0.94, Test cost/loss = 39626.02
# Decision Threshold: 0.95, Test cost/loss = 39108.26
# Decision Threshold: 0.96, Test cost/loss = 40247.38
# Decision Threshold: 0.97, Test cost/loss = 38990.98
# Decision Threshold: 0.98, Test cost/loss = 36840.72
# Decision Threshold: 0.99, Test cost/loss = 38671.22
# Best Decision Threshold: 0.98, Lowest Test cost/loss = 36840.72, Lowest AMC = 2.72

# %%
test_predictions_xgb_churn['y_predicted_proba_xgb']= best_pipeline_xgb.predict_proba(test_predictions_xgb_churn.drop(y, axis=1))[:, 1]
best_threshold_xgb, AMC_xgb, lowest_cost_xgb = compute_best_threshold(test_predictions_xgb_churn, best_pipeline_xgb, y, cb_column, y_predicted_proba_col_name="y_predicted_proba_xgb", instance_dependent_cost_type= 'churn' )
# Out:
# Decision Threshold: 0.01, Test cost/loss = 1112386.46
# Decision Threshold: 0.02, Test cost/loss = 911730.62
# Decision Threshold: 0.03, Test cost/loss = 781820.40
# Decision Threshold: 0.04, Test cost/loss = 697635.06
# Decision Threshold: 0.05, Test cost/loss = 616206.48
# Decision Threshold: 0.06, Test cost/loss = 556893.18
# Decision Threshold: 0.07, Test cost/loss = 513857.26
# Decision Threshold: 0.08, Test cost/loss = 474096.74
# Decision Threshold: 0.09, Test cost/loss = 448114.74
# Decision Threshold: 0.10, Test cost/loss = 423380.84
# Decision Threshold: 0.11, Test cost/loss = 393278.30
# Decision Threshold: 0.12, Test cost/loss = 377682.90
# Decision Threshold: 0.13, Test cost/loss = 355659.10
# Decision Threshold: 0.14, Test cost/loss = 341123.32
# Decision Threshold: 0.15, Test cost/loss = 329090.08
# Decision Threshold: 0.16, Test cost/loss = 317623.38
# Decision Threshold: 0.17, Test cost/loss = 303268.40
# Decision Threshold: 0.18, Test cost/loss = 293065.98
# Decision Threshold: 0.19, Test cost/loss = 290161.40
# Decision Threshold: 0.20, Test cost/loss = 281756.80
# Decision Threshold: 0.21, Test cost/loss = 272440.56
# Decision Threshold: 0.22, Test cost/loss = 264834.22
# Decision Threshold: 0.23, Test cost/loss = 259306.72
# Decision Threshold: 0.24, Test cost/loss = 251530.98
# Decision Threshold: 0.25, Test cost/loss = 246483.40
# Decision Threshold: 0.26, Test cost/loss = 236530.70
# Decision Threshold: 0.27, Test cost/loss = 230016.80
# Decision Threshold: 0.28, Test cost/loss = 225420.98
# Decision Threshold: 0.29, Test cost/loss = 220240.22
# Decision Threshold: 0.30, Test cost/loss = 214282.50
# Decision Threshold: 0.31, Test cost/loss = 211623.52
# Decision Threshold: 0.32, Test cost/loss = 207622.06
# Decision Threshold: 0.33, Test cost/loss = 200517.14
# Decision Threshold: 0.34, Test cost/loss = 191118.26
# Decision Threshold: 0.35, Test cost/loss = 187222.22
# Decision Threshold: 0.36, Test cost/loss = 185020.12
# Decision Threshold: 0.37, Test cost/loss = 180323.68
# Decision Threshold: 0.38, Test cost/loss = 175202.34
# Decision Threshold: 0.39, Test cost/loss = 172462.10
# Decision Threshold: 0.40, Test cost/loss = 170264.92
# Decision Threshold: 0.41, Test cost/loss = 168010.66
# Decision Threshold: 0.42, Test cost/loss = 165505.48
# Decision Threshold: 0.43, Test cost/loss = 163937.42
# Decision Threshold: 0.44, Test cost/loss = 159851.02
# Decision Threshold: 0.45, Test cost/loss = 155432.14
# Decision Threshold: 0.46, Test cost/loss = 153533.30
# Decision Threshold: 0.47, Test cost/loss = 149112.18
# Decision Threshold: 0.48, Test cost/loss = 148086.38
# Decision Threshold: 0.49, Test cost/loss = 147475.66
# Decision Threshold: 0.50, Test cost/loss = 146871.54
# Decision Threshold: 0.51, Test cost/loss = 145477.60
# Decision Threshold: 0.52, Test cost/loss = 144274.48
# Decision Threshold: 0.53, Test cost/loss = 142949.78
# Decision Threshold: 0.54, Test cost/loss = 142054.38
# Decision Threshold: 0.55, Test cost/loss = 140422.82
# Decision Threshold: 0.56, Test cost/loss = 147691.18
# Decision Threshold: 0.57, Test cost/loss = 154800.44
# Decision Threshold: 0.58, Test cost/loss = 152670.64
# Decision Threshold: 0.59, Test cost/loss = 150116.30
# Decision Threshold: 0.60, Test cost/loss = 147644.68
# Decision Threshold: 0.61, Test cost/loss = 146013.44
# Decision Threshold: 0.62, Test cost/loss = 145728.26
# Decision Threshold: 0.63, Test cost/loss = 144667.64
# Decision Threshold: 0.64, Test cost/loss = 144667.64
# Decision Threshold: 0.65, Test cost/loss = 144323.88
# Decision Threshold: 0.66, Test cost/loss = 142336.70
# Decision Threshold: 0.67, Test cost/loss = 139161.28
# Decision Threshold: 0.68, Test cost/loss = 132998.82
# Decision Threshold: 0.69, Test cost/loss = 130164.78
# Decision Threshold: 0.70, Test cost/loss = 143960.04
# Decision Threshold: 0.71, Test cost/loss = 137763.66
# Decision Threshold: 0.72, Test cost/loss = 135990.88
# Decision Threshold: 0.73, Test cost/loss = 131398.38
# Decision Threshold: 0.74, Test cost/loss = 131025.02
# Decision Threshold: 0.75, Test cost/loss = 126882.70
# Decision Threshold: 0.76, Test cost/loss = 125887.90
# Decision Threshold: 0.77, Test cost/loss = 131619.34
# Decision Threshold: 0.78, Test cost/loss = 136460.00
# Decision Threshold: 0.79, Test cost/loss = 135075.88
# Decision Threshold: 0.80, Test cost/loss = 133320.72
# Decision Threshold: 0.81, Test cost/loss = 137414.32
# Decision Threshold: 0.82, Test cost/loss = 136551.66
# Decision Threshold: 0.83, Test cost/loss = 136551.66
# Decision Threshold: 0.84, Test cost/loss = 136108.06
# Decision Threshold: 0.85, Test cost/loss = 133435.26
# Decision Threshold: 0.86, Test cost/loss = 135596.94
# Decision Threshold: 0.87, Test cost/loss = 132074.02
# Decision Threshold: 0.88, Test cost/loss = 134771.60
# Decision Threshold: 0.89, Test cost/loss = 134771.60
# Decision Threshold: 0.90, Test cost/loss = 132487.48
# Decision Threshold: 0.91, Test cost/loss = 132487.48
# Decision Threshold: 0.92, Test cost/loss = 129365.12
# Decision Threshold: 0.93, Test cost/loss = 127577.00
# Decision Threshold: 0.94, Test cost/loss = 125132.96
# Decision Threshold: 0.95, Test cost/loss = 122059.78
# Decision Threshold: 0.96, Test cost/loss = 123438.02
# Decision Threshold: 0.97, Test cost/loss = 122960.24
# Decision Threshold: 0.98, Test cost/loss = 133618.54
# Decision Threshold: 0.99, Test cost/loss = 170674.16
# Best Decision Threshold: 0.95, Lowest Test cost/loss = 122059.78, Lowest AMC = 9.03

# %% [markdown]
# # e- amc metric

# %%
test_predictions_log_churn = add_eap_ep(
    train=train, 
    test=test_predictions_log_churn, 
    y_col_name=y, 
    best_pipeline=best_pipeline_log_reg, 
    cb_column=cb_column, 
    predicted_proba_col_name='y_predicted_proba_log', 
    churn_label= 1.0, 
    instance_dependent_cost_type="churn")
test_predictions_xgb_churn = add_eap_ep(
    train=train, 
    test=test_predictions_xgb_churn, 
    y_col_name=y, 
    best_pipeline=best_pipeline_xgb, 
    cb_column=cb_column, 
    predicted_proba_col_name="y_predicted_proba_xgb", 
    churn_label=1.0, 
    instance_dependent_cost_type="churn")
# Out:
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:329: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_0['EAP'] = test_actual_label_0[predicted_proba_col_name]*test_actual_label_0['FP'] + \
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:331: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_0['EP'] = estimated_p_1*test_actual_label_0['FP']+estimated_p_0*test_actual_label_0['TN']
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:333: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_1['EAP'] = test_actual_label_1[predicted_proba_col_name]*test_actual_label_1['TP'] + \
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:335: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_1['EP'] = estimated_p_1 * test_actual_label_1['TP'] + estimated_p_0 * test_actual_label_1['FN']
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:329: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_0['EAP'] = test_actual_label_0[predicted_proba_col_name]*test_actual_label_0['FP'] + \
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:331: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_0['EP'] = estimated_p_1*test_actual_label_0['FP']+estimated_p_0*test_actual_label_0['TN']
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:333: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_1['EAP'] = test_actual_label_1[predicted_proba_col_name]*test_actual_label_1['TP'] + \
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:335: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_1['EP'] = estimated_p_1 * test_actual_label_1['TP'] + estimated_p_0 * test_actual_label_1['FN']

# %%
print(test_predictions_log_churn['EAP'].sum())
print(test_predictions_log_churn['EP'].sum())


print('EAP : ', test_predictions_log_churn['EAP'].sum()/len(test_predictions_log_churn))
print('EP : ', test_predictions_log_churn['EP'].sum()/len(test_predictions_log_churn))
# Out:
# 441431.2066873113
# 52192.918708603764
# EAP :  32.64782240125074
# EP :  3.8601374682792517

# %%
print(test_predictions_xgb_churn['EAP'].sum())
print(test_predictions_xgb_churn['EP'].sum())


print('EAP : ', test_predictions_xgb_churn['EAP'].sum()/len(test_predictions_xgb_churn))
print('EP : ', test_predictions_xgb_churn['EP'].sum()/len(test_predictions_xgb_churn))
# Out:
# 233646.78379566816
# 330540.7564985855
# EAP :  17.28028872092805
# EP :  24.446472635055507

# %% [markdown]
# # mp at 50% threshold

# %%
test_predictions_log_churn_2 = test.copy(deep=True)
test_predictions_log_churn_2["y_predicted"] = best_pipeline_log_reg.predict(test_predictions_log_churn_2.drop(y, axis=1))
test_predictions_log_churn_2["churn_encoded"] = fit_le.transform(test_predictions_log_churn_2["is_fraud"])

# First check if customers have multiple rows => if so check if we can take other if this instance-based cost
impute = SimpleImputer(strategy='median')
test_predictions_log_churn_2['A'] = impute.fit_transform(
    (test_predictions_log_churn_2["amt"]).to_frame())[:, 0]
# Step 3: Apply the function to calculate the cost for each instance and create the instance-dependent cost matrix
test_predictions_log_churn_2['instance_cost'] = test_predictions_log_churn_2.apply(lambda row: instance_dependent_cost_churn_2(
    row['y_predicted'], row["churn_encoded"], row["A"]), axis=1)

test_predictions_log_churn_2["y_predicted_decoded"] = fit_le.inverse_transform(
    test_predictions_log_churn_2["y_predicted"])

# Print the DataFrame with the instance-dependent cost matrix
test_predictions_log_churn_2[['is_fraud', 'y_predicted_decoded', "A", 'instance_cost']]

print(f"Test cost/loss = {test_predictions_log_churn_2['instance_cost'].sum():.0f}.")
print(' total cost/loss average : ' , test_predictions_log_churn_2['instance_cost'].sum()/len(test_predictions_log_churn_2))
# Out:
# Test cost/loss = -532280.
#  total cost/loss average :  -39.36690185637157

# %%
test_predictions_xgb_churn_2 = test.copy(deep=True)
test_predictions_xgb_churn_2["y_predicted"] = best_pipeline_xgb.predict(test_predictions_xgb_churn_2.drop(y, axis=1))
test_predictions_xgb_churn_2["churn_encoded"] = fit_le.transform(test_predictions_xgb_churn_2["is_fraud"])

# First check if customers have multiple rows => if so check if we can take other if this instance-based cost
impute = SimpleImputer(strategy='median')
test_predictions_xgb_churn_2['A'] = impute.fit_transform(
    (test_predictions_xgb_churn_2["amt"]).to_frame())[:, 0]

# Step 3: Apply the function to calculate the cost for each instance and create the instance-dependent cost matrix
test_predictions_xgb_churn_2['instance_cost'] = test_predictions_xgb_churn_2.apply(lambda row: instance_dependent_cost_churn_2(
    row['y_predicted'], row["churn_encoded"], row["A"]), axis=1)

test_predictions_xgb_churn_2["y_predicted_decoded"] = fit_le.inverse_transform(
    test_predictions_xgb_churn_2["y_predicted"])

# Print the DataFrame with the instance-dependent cost matrix
test_predictions_xgb_churn_2[['is_fraud', 'y_predicted_decoded', "A", 'instance_cost']]

print(f"Test cost/loss = {test_predictions_xgb_churn_2['instance_cost'].sum():.0f}.")
# Out:
# Test cost/loss = -96043.

# %%
test_predictions_xgb_churn_2
# Out:
#                   cc_num        category     amt gender state  city_pop  \
# 377359  3540210836308425     food_dining   62.63      M    TX        53
# 343471      639030014711   entertainment   67.01      M    IL       639
# 858312   377264520876399   personal_care   17.55      F    SC      4424
# 653694   213157767990030  health_fitness   32.14      F    WY     27971
# 485688    30408301059761       kids_pets   68.74      M    SC      4471
# ...                  ...             ...     ...    ...   ...       ...
# 681119  3597926034019603        misc_pos  103.97      M    TN      9496
# 216844  2254917871818484    shopping_net    1.92      F    MD       313
# 6122    3586955669388457    shopping_pos  137.68      M    PA      1770
# 37347   3559160581764413   entertainment   85.12      M    NY      1453
# 80760       676369110710   entertainment    4.49      M    MI     75830
#
#                                     job   unix_time  is_fraud     lat_x  \
# 377359                Fisheries officer  1384536888         0  0.386883
# 343471              Mechanical engineer  1383260389         0  0.374299
# 858312                           Lawyer  1355689325         0 -0.370872
# 653694                  Music therapist  1349466301         0  0.539446
# 485688           Occupational hygienist  1343748738         0 -0.025769
# ...                                 ...         ...       ...       ...
# 681119   Furniture conservator/restorer  1350504417         0  0.012908
# 216844            Insurance underwriter  1334945628         0  0.539784
# 6122    Administrator, local government  1371946103         0  0.724015
# 37347                      Toxicologist  1327246546         0  0.139454
# 80760              Engineer, automotive  1329495958         0 -0.003317
#
#           long_y     lat_z  merch_lat_x  merch_long_y  merch_lat_z  \
# 377359  0.903359 -0.185107     0.974763      0.171631    -0.142757
# 343471 -0.790767 -0.484343    -0.101118     -0.751755    -0.651644
# 858312 -0.903818  0.213464    -0.117634     -0.817296    -0.564083
# 653694  0.478639 -0.692750    -0.001038     -0.002552    -0.999996
# 485688 -0.341624  0.939483     0.190030     -0.354266     0.915633
# ...          ...       ...          ...           ...          ...
# 681119  0.786576 -0.617359    -0.060673     -0.039846    -0.997362
# 216844 -0.753990  0.374343     0.405536     -0.876989     0.257743
# 6122   -0.517629  0.455919     0.874663      0.283635    -0.393084
# 37347  -0.020347 -0.990020     0.236203     -0.099020    -0.966645
# 80760  -0.085231 -0.996356     0.553350      0.336696    -0.761866
#
#         y_predicted  churn_encoded       A  instance_cost  y_predicted_decoded
# 377359            0              0   62.63            0.0                    0
# 343471            0              0   67.01            0.0                    0
# 858312            0              0   17.55            0.0                    0
# 653694            0              0   32.14            0.0                    0
# 485688            0              0   68.74            0.0                    0
# ...             ...            ...     ...            ...                  ...
# 681119            0              0  103.97            0.0                    0
# 216844            0              0    1.92            0.0                    0
# 6122              0              0  137.68            0.0                    0
# 37347             0              0   85.12            0.0                    0
# 80760             0              0    4.49            0.0                    0
#
# [13521 rows x 20 columns]

# %% [markdown]
# # MP metric

# %%
cb_column = 'A'
test_predictions_log_churn_2['y_predicted_proba_log']= best_pipeline_log_reg.predict_proba(test_predictions_log_churn_2.drop(y, axis=1))[:, 1]
best_threshold_log, AMC_log, lowest_cost_log = compute_best_threshold_2(test_predictions_log_churn_2, best_pipeline_log_reg, y,cb_column, y_predicted_proba_col_name="y_predicted_proba_log", instance_dependent_cost_type = 'churn_2')
# Out:
# Decision Threshold: 0.01, Test cost/loss = -1733341.44
# Decision Threshold: 0.02, Test cost/loss = -1680709.46
# Decision Threshold: 0.03, Test cost/loss = -1640014.56
# Decision Threshold: 0.04, Test cost/loss = -1606718.46
# Decision Threshold: 0.05, Test cost/loss = -1576117.08
# Decision Threshold: 0.06, Test cost/loss = -1547243.24
# Decision Threshold: 0.07, Test cost/loss = -1523686.58
# Decision Threshold: 0.08, Test cost/loss = -1499563.12
# Decision Threshold: 0.09, Test cost/loss = -1477360.32
# Decision Threshold: 0.10, Test cost/loss = -1460647.08
# Decision Threshold: 0.11, Test cost/loss = -1440636.82
# Decision Threshold: 0.12, Test cost/loss = -1419767.00
# Decision Threshold: 0.13, Test cost/loss = -1398577.50
# Decision Threshold: 0.14, Test cost/loss = -1377712.16
# Decision Threshold: 0.15, Test cost/loss = -1354466.02
# Decision Threshold: 0.16, Test cost/loss = -1325571.26
# Decision Threshold: 0.17, Test cost/loss = -1303885.22
# Decision Threshold: 0.18, Test cost/loss = -1277637.66
# Decision Threshold: 0.19, Test cost/loss = -1256765.10
# Decision Threshold: 0.20, Test cost/loss = -1232335.48
# Decision Threshold: 0.21, Test cost/loss = -1208347.08
# Decision Threshold: 0.22, Test cost/loss = -1186151.18
# Decision Threshold: 0.23, Test cost/loss = -1160984.90
# Decision Threshold: 0.24, Test cost/loss = -1137304.88
# Decision Threshold: 0.25, Test cost/loss = -1115764.06
# Decision Threshold: 0.26, Test cost/loss = -1091207.42
# Decision Threshold: 0.27, Test cost/loss = -1066134.34
# Decision Threshold: 0.28, Test cost/loss = -1043787.32
# Decision Threshold: 0.29, Test cost/loss = -1021662.58
# Decision Threshold: 0.30, Test cost/loss = -995562.24
# Decision Threshold: 0.31, Test cost/loss = -971911.46
# Decision Threshold: 0.32, Test cost/loss = -950190.76
# Decision Threshold: 0.33, Test cost/loss = -926500.52
# Decision Threshold: 0.34, Test cost/loss = -902479.18
# Decision Threshold: 0.35, Test cost/loss = -880781.20
# Decision Threshold: 0.36, Test cost/loss = -857267.60
# Decision Threshold: 0.37, Test cost/loss = -831348.60
# Decision Threshold: 0.38, Test cost/loss = -806836.44
# Decision Threshold: 0.39, Test cost/loss = -782844.46
# Decision Threshold: 0.40, Test cost/loss = -759427.76
# Decision Threshold: 0.41, Test cost/loss = -732166.10
# Decision Threshold: 0.42, Test cost/loss = -708543.34
# Decision Threshold: 0.43, Test cost/loss = -688544.44
# Decision Threshold: 0.44, Test cost/loss = -663232.62
# Decision Threshold: 0.45, Test cost/loss = -643584.40
# Decision Threshold: 0.46, Test cost/loss = -617146.04
# Decision Threshold: 0.47, Test cost/loss = -595555.28
# Decision Threshold: 0.48, Test cost/loss = -574021.24
# Decision Threshold: 0.49, Test cost/loss = -554838.28
# Decision Threshold: 0.50, Test cost/loss = -532279.88
# Decision Threshold: 0.51, Test cost/loss = -515150.74
# Decision Threshold: 0.52, Test cost/loss = -496450.10
# Decision Threshold: 0.53, Test cost/loss = -478141.72
# Decision Threshold: 0.54, Test cost/loss = -461329.28
# Decision Threshold: 0.55, Test cost/loss = -446877.78
# Decision Threshold: 0.56, Test cost/loss = -432493.50
# Decision Threshold: 0.57, Test cost/loss = -422129.18
# Decision Threshold: 0.58, Test cost/loss = -416012.84
# Decision Threshold: 0.59, Test cost/loss = -406585.14
# Decision Threshold: 0.60, Test cost/loss = -392239.12
# Decision Threshold: 0.61, Test cost/loss = -379930.36
# Decision Threshold: 0.62, Test cost/loss = -371052.42
# Decision Threshold: 0.63, Test cost/loss = -358939.44
# Decision Threshold: 0.64, Test cost/loss = -346420.42
# Decision Threshold: 0.65, Test cost/loss = -335256.92
# Decision Threshold: 0.66, Test cost/loss = -327808.82
# Decision Threshold: 0.67, Test cost/loss = -314195.88
# Decision Threshold: 0.68, Test cost/loss = -305662.12
# Decision Threshold: 0.69, Test cost/loss = -299200.50
# Decision Threshold: 0.70, Test cost/loss = -289414.78
# Decision Threshold: 0.71, Test cost/loss = -280038.68
# Decision Threshold: 0.72, Test cost/loss = -281370.62
# Decision Threshold: 0.73, Test cost/loss = -273443.00
# Decision Threshold: 0.74, Test cost/loss = -262982.06
# Decision Threshold: 0.75, Test cost/loss = -254109.82
# Decision Threshold: 0.76, Test cost/loss = -247776.36
# Decision Threshold: 0.77, Test cost/loss = -247863.42
# Decision Threshold: 0.78, Test cost/loss = -242802.16
# Decision Threshold: 0.79, Test cost/loss = -234975.68
# Decision Threshold: 0.80, Test cost/loss = -233951.92
# Decision Threshold: 0.81, Test cost/loss = -232987.88
# Decision Threshold: 0.82, Test cost/loss = -230133.06
# Decision Threshold: 0.83, Test cost/loss = -236415.98
# Decision Threshold: 0.84, Test cost/loss = -239700.10
# Decision Threshold: 0.85, Test cost/loss = -241834.02
# Decision Threshold: 0.86, Test cost/loss = -246587.54
# Decision Threshold: 0.87, Test cost/loss = -243478.90
# Decision Threshold: 0.88, Test cost/loss = -237131.04
# Decision Threshold: 0.89, Test cost/loss = -235602.02
# Decision Threshold: 0.90, Test cost/loss = -233496.46
# Decision Threshold: 0.91, Test cost/loss = -233453.00
# Decision Threshold: 0.92, Test cost/loss = -232636.28
# Decision Threshold: 0.93, Test cost/loss = -236264.76
# Decision Threshold: 0.94, Test cost/loss = -231176.78
# Decision Threshold: 0.95, Test cost/loss = -222564.76
# Decision Threshold: 0.96, Test cost/loss = -220349.54
# Decision Threshold: 0.97, Test cost/loss = -214602.76
# Decision Threshold: 0.98, Test cost/loss = -218612.82
# Decision Threshold: 0.99, Test cost/loss = -239404.10
# Best Decision Threshold: 0.97, Lowest Test cost/loss = -214602.76, Lowest AMC = -15.87

# %%
test_predictions_xgb_churn_2['y_predicted_proba_xgb']= best_pipeline_xgb.predict_proba(test_predictions_xgb_churn_2.drop(y, axis=1))[:, 1]
best_threshold_xgb, AMC_xgb, lowest_cost_xgb = compute_best_threshold_2(test_predictions_xgb_churn_2, best_pipeline_xgb, y, cb_column, y_predicted_proba_col_name="y_predicted_proba_xgb", instance_dependent_cost_type= 'churn_2' )
# Out:
# Decision Threshold: 0.01, Test cost/loss = -1058821.26
# Decision Threshold: 0.02, Test cost/loss = -858165.42
# Decision Threshold: 0.03, Test cost/loss = -728294.92
# Decision Threshold: 0.04, Test cost/loss = -644153.78
# Decision Threshold: 0.05, Test cost/loss = -562725.20
# Decision Threshold: 0.06, Test cost/loss = -503451.38
# Decision Threshold: 0.07, Test cost/loss = -460415.46
# Decision Threshold: 0.08, Test cost/loss = -420697.86
# Decision Threshold: 0.09, Test cost/loss = -394715.86
# Decision Threshold: 0.10, Test cost/loss = -369981.96
# Decision Threshold: 0.11, Test cost/loss = -339879.42
# Decision Threshold: 0.12, Test cost/loss = -325039.32
# Decision Threshold: 0.13, Test cost/loss = -303015.52
# Decision Threshold: 0.14, Test cost/loss = -288479.74
# Decision Threshold: 0.15, Test cost/loss = -276446.50
# Decision Threshold: 0.16, Test cost/loss = -264979.80
# Decision Threshold: 0.17, Test cost/loss = -250661.74
# Decision Threshold: 0.18, Test cost/loss = -240459.32
# Decision Threshold: 0.19, Test cost/loss = -239267.34
# Decision Threshold: 0.20, Test cost/loss = -230862.74
# Decision Threshold: 0.21, Test cost/loss = -221546.50
# Decision Threshold: 0.22, Test cost/loss = -213940.16
# Decision Threshold: 0.23, Test cost/loss = -208412.66
# Decision Threshold: 0.24, Test cost/loss = -200654.92
# Decision Threshold: 0.25, Test cost/loss = -195607.34
# Decision Threshold: 0.26, Test cost/loss = -185654.64
# Decision Threshold: 0.27, Test cost/loss = -179140.74
# Decision Threshold: 0.28, Test cost/loss = -174544.92
# Decision Threshold: 0.29, Test cost/loss = -169364.16
# Decision Threshold: 0.30, Test cost/loss = -163406.44
# Decision Threshold: 0.31, Test cost/loss = -160775.46
# Decision Threshold: 0.32, Test cost/loss = -156774.00
# Decision Threshold: 0.33, Test cost/loss = -149669.08
# Decision Threshold: 0.34, Test cost/loss = -140270.20
# Decision Threshold: 0.35, Test cost/loss = -136374.16
# Decision Threshold: 0.36, Test cost/loss = -134191.68
# Decision Threshold: 0.37, Test cost/loss = -129495.24
# Decision Threshold: 0.38, Test cost/loss = -124373.90
# Decision Threshold: 0.39, Test cost/loss = -121633.66
# Decision Threshold: 0.40, Test cost/loss = -119436.48
# Decision Threshold: 0.41, Test cost/loss = -117182.22
# Decision Threshold: 0.42, Test cost/loss = -114677.04
# Decision Threshold: 0.43, Test cost/loss = -113108.98
# Decision Threshold: 0.44, Test cost/loss = -109022.58
# Decision Threshold: 0.45, Test cost/loss = -104603.70
# Decision Threshold: 0.46, Test cost/loss = -102704.86
# Decision Threshold: 0.47, Test cost/loss = -98283.74
# Decision Threshold: 0.48, Test cost/loss = -97257.94
# Decision Threshold: 0.49, Test cost/loss = -96647.22
# Decision Threshold: 0.50, Test cost/loss = -96043.10
# Decision Threshold: 0.51, Test cost/loss = -94649.16
# Decision Threshold: 0.52, Test cost/loss = -93984.06
# Decision Threshold: 0.53, Test cost/loss = -92659.36
# Decision Threshold: 0.54, Test cost/loss = -91763.96
# Decision Threshold: 0.55, Test cost/loss = -90132.40
# Decision Threshold: 0.56, Test cost/loss = -98947.86
# Decision Threshold: 0.57, Test cost/loss = -107304.90
# Decision Threshold: 0.58, Test cost/loss = -105175.10
# Decision Threshold: 0.59, Test cost/loss = -102620.76
# Decision Threshold: 0.60, Test cost/loss = -100149.14
# Decision Threshold: 0.61, Test cost/loss = -98517.90
# Decision Threshold: 0.62, Test cost/loss = -98232.72
# Decision Threshold: 0.63, Test cost/loss = -97172.10
# Decision Threshold: 0.64, Test cost/loss = -97172.10
# Decision Threshold: 0.65, Test cost/loss = -96828.34
# Decision Threshold: 0.66, Test cost/loss = -94841.16
# Decision Threshold: 0.67, Test cost/loss = -91665.74
# Decision Threshold: 0.68, Test cost/loss = -85503.28
# Decision Threshold: 0.69, Test cost/loss = -82669.24
# Decision Threshold: 0.70, Test cost/loss = -99041.08
# Decision Threshold: 0.71, Test cost/loss = -92844.70
# Decision Threshold: 0.72, Test cost/loss = -91071.92
# Decision Threshold: 0.73, Test cost/loss = -86479.42
# Decision Threshold: 0.74, Test cost/loss = -86106.06
# Decision Threshold: 0.75, Test cost/loss = -81963.74
# Decision Threshold: 0.76, Test cost/loss = -80968.94
# Decision Threshold: 0.77, Test cost/loss = -87789.96
# Decision Threshold: 0.78, Test cost/loss = -94075.98
# Decision Threshold: 0.79, Test cost/loss = -92691.86
# Decision Threshold: 0.80, Test cost/loss = -90936.70
# Decision Threshold: 0.81, Test cost/loss = -96589.54
# Decision Threshold: 0.82, Test cost/loss = -95726.88
# Decision Threshold: 0.83, Test cost/loss = -95726.88
# Decision Threshold: 0.84, Test cost/loss = -95283.28
# Decision Threshold: 0.85, Test cost/loss = -92610.48
# Decision Threshold: 0.86, Test cost/loss = -95342.92
# Decision Threshold: 0.87, Test cost/loss = -91820.00
# Decision Threshold: 0.88, Test cost/loss = -95824.48
# Decision Threshold: 0.89, Test cost/loss = -95824.48
# Decision Threshold: 0.90, Test cost/loss = -93540.36
# Decision Threshold: 0.91, Test cost/loss = -93540.36
# Decision Threshold: 0.92, Test cost/loss = -90418.00
# Decision Threshold: 0.93, Test cost/loss = -88629.88
# Decision Threshold: 0.94, Test cost/loss = -86185.84
# Decision Threshold: 0.95, Test cost/loss = -83112.66
# Decision Threshold: 0.96, Test cost/loss = -85056.64
# Decision Threshold: 0.97, Test cost/loss = -85281.26
# Decision Threshold: 0.98, Test cost/loss = -99178.66
# Decision Threshold: 0.99, Test cost/loss = -144217.52
# Best Decision Threshold: 0.76, Lowest Test cost/loss = -80968.94, Lowest AMC = -5.99

# %% [markdown]
# # E-MP metric

# %%
test_predictions_log_churn_2 = add_eap_ep(
    train=train, 
    test=test_predictions_log_churn_2, 
    y_col_name=y, 
    best_pipeline=best_pipeline_log_reg, 
    cb_column=cb_column, 
    predicted_proba_col_name='y_predicted_proba_log', 
    churn_label= 1.0, 
    instance_dependent_cost_type="churn_2")
test_predictions_xgb_churn_2 = add_eap_ep(
    train=train, 
    test=test_predictions_xgb_churn_2, 
    y_col_name=y, 
    best_pipeline=best_pipeline_xgb, 
    cb_column=cb_column, 
    predicted_proba_col_name="y_predicted_proba_xgb", 
    churn_label=1.0, 
    instance_dependent_cost_type="churn_2")
# Out:
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:329: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_0['EAP'] = test_actual_label_0[predicted_proba_col_name]*test_actual_label_0['FP'] + \
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:331: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_0['EP'] = estimated_p_1*test_actual_label_0['FP']+estimated_p_0*test_actual_label_0['TN']
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:333: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_1['EAP'] = test_actual_label_1[predicted_proba_col_name]*test_actual_label_1['TP'] + \
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:335: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_1['EP'] = estimated_p_1 * test_actual_label_1['TP'] + estimated_p_0 * test_actual_label_1['FN']
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:329: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_0['EAP'] = test_actual_label_0[predicted_proba_col_name]*test_actual_label_0['FP'] + \
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:331: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_0['EP'] = estimated_p_1*test_actual_label_0['FP']+estimated_p_0*test_actual_label_0['TN']
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:333: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_1['EAP'] = test_actual_label_1[predicted_proba_col_name]*test_actual_label_1['TP'] + \
# c:\Users\stijn\OneDrive\Bureaublad\TEW 1ste jaar\python thesis\End-to-end-project---Customer-churn\notebooks\..\src\common_functions.py:335: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_actual_label_1['EP'] = estimated_p_1 * test_actual_label_1['TP'] + estimated_p_0 * test_actual_label_1['FN']

# %%
print(test_predictions_log_churn_2['EAP'].sum())
print(test_predictions_log_churn_2['EP'].sum())


print('EAP : ', test_predictions_log_churn_2['EAP'].sum()/len(test_predictions_log_churn_2))
print('EP : ', test_predictions_log_churn_2['EP'].sum()/len(test_predictions_log_churn_2))
# Out:
# -709804.8250400309
# -330237.0214677984
# EAP :  -52.49647400636276
# EP :  -24.424008687804037

# %%
print(test_predictions_xgb_churn_2['EAP'].sum())
print(test_predictions_xgb_churn_2['EP'].sum())


print('EAP : ', test_predictions_xgb_churn_2['EAP'].sum()/len(test_predictions_xgb_churn_2))
print('EP : ', test_predictions_xgb_churn_2['EP'].sum()/len(test_predictions_xgb_churn_2))
# Out:
# -186168.0855490486
# -330237.0214677984
# EAP :  -13.768810409662644
# EP :  -24.424008687804037

# %% [markdown]
# # cost curves

# %%
total_fp_log_2 = 0

for i in range(0,13521):
    if test_predictions_log_churn['churn_encoded'].iloc[i] == 0 and test_predictions_log_churn['y_predicted'].iloc[i]==1:
        total_fp_log_2 += test_predictions_log_churn['FP'].iloc[i]
    else:
        total_fp_log_2 += 0

print(total_fp_log_2)

average_fp_log_2 = total_fp_log_2/13521
print( average_fp_log_2)
# Out:
# 197001.34000000008
# 14.570027364839884

# %%
total_fn_log_2 = 0

for i in range(0,13521):
    if test_predictions_log_churn['churn_encoded'].iloc[i] == 1 and test_predictions_log_churn['y_predicted'].iloc[i]==0:
        total_fn_log_2 += test_predictions_log_churn['FN'].iloc[i]
    else:
        total_fn_log_2 += 0

print(total_fn_log_2)

average_fn_log_2 = total_fn_log_2/13521
print( average_fn_log_2)
# Out:
# 10246.8
# 0.757843354781451

# %%
cost_fn_log_2 = average_fn_log_2
# C(+|-)
cost_fp_log_2 = average_fp_log_2

# Ground truth
truth = test_predictions_log_churn['churn_encoded']
#  <a list of 0 (negative class) or 1 (positive class)>
# Predictions from a classifier
score = test_predictions_log_churn['y_predicted']
# best_pipeline_log_reg.predict_proba(test.drop(y_encoded_col_name, axis=1))[:, 1]
# <a list of [0,1] class probabilities>

# %% OUTPUTS

# 1D-array of x-axis values (normalized PC)
pc = None
# list of lines as (slope, intercept)
lines = []
# lower envelope of the list of lines as a 1D-array of y-axis values (NEC)
lower_envelope = []
# area under the lower envelope (the smaller, the better)
area = None

# %% COMPUTATION

# points from the roc curve, because a point in the ROC space <=> a line in the cost space
roc_fpr, roc_tpr, _ = roc_curve(truth, score)

# compute the normalized p(+)*C(-|+)
thresholds = np.arange(0, 1.01, .01)
pc = (thresholds*cost_fn_log_2) / (thresholds*cost_fn_log_2 + (1-thresholds)*cost_fp_log_2)

# compute a line in the cost space for each point in the roc space
for fpr, tpr in zip(roc_fpr, roc_tpr):
    slope = (1-tpr-fpr)
    intercept = fpr
    lines.append((slope, intercept))

# compute the lower envelope
for x_value in pc:
    y_value = min([slope*x_value+intercept for slope, intercept in lines])
    lower_envelope.append(max(0, y_value))
lower_envelope = np.array(lower_envelope)

# compute the area under the lower envelope using the composite trapezoidal rule
area = np.trapz(lower_envelope, pc)

# %% EXAMPLE OF PLOT

# display each line as a thin dashed line
for slope, intercept in lines:
    plt.plot(pc, slope*pc+intercept, color="grey", lw=1, linestyle="--")

# display the lower envelope as a thicker black line
plt.plot(pc, lower_envelope, color="black", lw=3, label="area={:.3f}".format(area))

# plot parameters
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05*max(lower_envelope)])
plt.xlabel("Probability Cost Function")
plt.ylabel("Normalized Expected Cost")
plt.title("Cost curve")
plt.legend(loc="lower right")

plt.show()

# %%
total_fp_xgb_2 = 0

for i in range(0,13521):
    if test_predictions_xgb_churn['churn_encoded'].iloc[i] == 0 and test_predictions_xgb_churn['y_predicted'].iloc[i]==1:
        total_fp_xgb_2 += test_predictions_xgb_churn['FP'].iloc[i]
    else:
        total_fp_xgb_2 += 0

print(total_fp_xgb_2)

average_fp_xgb_2 = total_fp_xgb_2/13521
print( average_fp_xgb_2)
# Out:
# 129757.98000000003
# 9.596773907255383

# %%
total_fn_xgb_2 = 0

for i in range(0,13521):
    if test_predictions_xgb_churn['churn_encoded'].iloc[i] == 1 and test_predictions_xgb_churn['y_predicted'].iloc[i]==0:
        total_fn_xgb_2 += test_predictions_xgb_churn['FN'].iloc[i]
    else:
        total_fn_xgb_2 += 0

print(total_fn_xgb_2)

average_fn_xgb_2 = total_fn_xgb_2/13521
print( average_fn_xgb_2)
# Out:
# 17113.56
# 1.265702240958509

# %%
#C(-|+)
cost_fn_xgb_2 = average_fn_xgb_2
# C(+|-)
cost_fp_xgb_2 = average_fp_xgb_2

# Ground truth
truth = test_predictions_xgb_churn['churn_encoded']
#  <a list of 0 (negative class) or 1 (positive class)>
# Predictions from a classifier
score = test_predictions_xgb_churn['y_predicted']
# best_pipeline_log_reg.predict_proba(test.drop(y_encoded_col_name, axis=1))[:, 1]
# <a list of [0,1] class probabilities>

# %% OUTPUTS

# 1D-array of x-axis values (normalized PC)
pc = None
# list of lines as (slope, intercept)
lines = []
# lower envelope of the list of lines as a 1D-array of y-axis values (NEC)
lower_envelope = []
# area under the lower envelope (the smaller, the better)
area = None

# %% COMPUTATION

# points from the roc curve, because a point in the ROC space <=> a line in the cost space
roc_fpr, roc_tpr, _ = roc_curve(truth, score)

# compute the normalized p(+)*C(-|+)
thresholds = np.arange(0, 1.01, .01)
pc = (thresholds*cost_fn_xgb_2) / (thresholds*cost_fn_xgb_2 + (1-thresholds)*cost_fp_xgb_2)

# compute a line in the cost space for each point in the roc space
for fpr, tpr in zip(roc_fpr, roc_tpr):
    slope = (1-tpr-fpr)
    intercept = fpr
    lines.append((slope, intercept))

# compute the lower envelope
for x_value in pc:
    y_value = min([slope*x_value+intercept for slope, intercept in lines])
    lower_envelope.append(max(0, y_value))
lower_envelope = np.array(lower_envelope)

# compute the area under the lower envelope using the composite trapezoidal rule
area = np.trapz(lower_envelope, pc)

# %% EXAMPLE OF PLOT

# display each line as a thin dashed line
for slope, intercept in lines:
    plt.plot(pc, slope*pc+intercept, color="grey", lw=1, linestyle="--")

# display the lower envelope as a thicker black line
plt.plot(pc, lower_envelope, color="black", lw=3, label="area={:.3f}".format(area))

# plot parameters
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05*max(lower_envelope)])
plt.xlabel("Probability Cost Function")
plt.ylabel("Normalized Expected Cost")
plt.title("Cost curve")
plt.legend(loc="lower right")

plt.show()
